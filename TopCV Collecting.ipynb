# %%
import pandas as pd
import numpy as np
import os
import json
import requests
from bs4 import BeautifulSoup
import concurrent.futures
import time
from concurrent.futures import ProcessPoolExecutor 
from multiprocessing import cpu_count 
import asyncio 
import aiohttp

# %%
def save_json(file, filename):
    SAVE_DIR = "data/topcv/json"
    with open(f'{SAVE_DIR}/{filename}.json', 'w') as openfile:
        json.dump(file, openfile)

# %%
def read_json(filename):
    OPEN_DIR = "data/topcv/json"
    with open(f'{OPEN_DIR}/{filename}.json', 'r') as openfile:
        file = json.load(openfile)
    return file

# %%
def append_text(content, filename):
    OPEN_DIR = 'data/topcv/text'
    with open(f'{OPEN_DIR}/{filename}.txt', 'a') as openfile:
        openfile.write(f'{content}\n')

# %%
with open("data/topcv/json/industries_raw.json", 'r') as openfile:
    industries = json.load(openfile)

# %% [markdown]
# # Collect industries

# %% [markdown]
# ### Sample record

# %%
resp = requests.get("https://www.topcv.vn/categories/list-top")
inds_js = json.loads(resp.text)

# %%
industries_js = inds_js['data']['categories']

# %%
industries_js[0]
# Out:
# {'id': 10001,
#  'name': 'Kinh doanh / Bán hàng',
#  'alias': 'kinh-doanh-ban-hang',
#  'access_url': '/tim-viec-lam-kinh-doanh-ban-hang-c10001',
#  'job_category_count': '11.119'}

# %%
# with open("data/topcv/json/industries_raw.json", 'w') as openfile:
#     json.dump(industries_js, openfile)

# %%
resp = requests.get("https://www.topcv.vn/tim-viec-lam-kinh-doanh-ban-hang-c10001")
pg_bs = BeautifulSoup(resp.text, 'html.parser')

# %%
job_body = pg_bs.find("div",{'class':'job-body'})
job_list = job_body.find('div', {'class':'job-list-default'})
job_items = job_list.find_all('div',{'class':'job-item-default'})
job_item_ = job_items[0].find('div',{'class':'body'})
job_url = job_item_.find('a').get('href')
job_url
# Out:
# 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-telesales-tu-van-luong-cung-tu-7-trieu-den-12-trieu-hoa-hong/1021535.html?ta_source=JobSearchList'

# %%
resp = requests.get(job_url)
jb_bs = BeautifulSoup(resp.text, 'html.parser')

# %%
job_header = jb_bs.find('div',{'class':'box-detail-job'}).find('div',{'class':'box-header'})
company_name = job_header.find('a',{'class':'company-logo'}).get('title')
job_title = job_header.find('div',{'class':'box-info-job'}).find('h1',{'class':'job-title'}).getText().strip()
job_deadline = job_header.find('div',{'class':'job-deadline'}).getText().strip()

# %%
jb_bs.find('div',{'class':'box-header'})
# Out:
# <div class="box-header">
# <a class="company-logo" href="https://www.topcv.vn/cong-ty/cong-ty-tnhh-giai-phap-mui-huong-eco-life-viet-nam/18567.html" title="Công ty TNHH Giải pháp mùi hương Eco Life Việt Nam">
# <div class="box-company-logo">
# <img alt="Công ty TNHH Giải pháp mùi hương Eco Life Việt Nam" class="img-responsive" src="https://cdn.topcv.vn/80/company_logos/cong-ty-tnhh-giai-phap-mui-huong-eco-life-viet-nam-5c88cfef106fa_rs.jpg"/>
# </div>
# </a>
# <div class="box-info-job">
# <h1 class="job-title text-highlight bold" style="overflow-wrap:break-word;">
# <a class="text-highlight" href="https://www.topcv.vn/tim-viec-lam-nhan-vien-kinh-doanh" target="_blank">Nhân Viên Kinh Doanh</a> / Telesales, Tư Vấn Lương Cứng Từ 7 Triệu Đến 12 Triệu + Hoa Hồng
# </h1>
# <div class="company-title">
# <a class="text-dark-blue" href="https://www.topcv.vn/cong-ty/cong-ty-tnhh-giai-phap-mui-huong-eco-life-viet-nam/18567.html">Công ty TNHH Giải pháp mùi hương Eco Life Việt Nam</a>
# </div>
# <div class="job-deadline">
# <i class="fa-regular fa-clock"></i> Hạn nộp hồ sơ: 30/06/2023
# </div>
# </div>
# <div class="box-apply-current">
# <div class="text-center">
# <p class="mb-16"><a class="btn btn-topcv-primary btn-primary-hover btn-apply" href="javascript:showLoginPopup('https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-telesales-tu-van-luong-cung-tu-7-trieu-den-12-trieu-hoa-hong/1021535.html?apply-form=1', 'Đăng nhập hoặc Đăng ký để ứng tuyển công việc này!')"> <i class="fa-regular fa-paper-plane"></i> ỨNG TUYỂN NGAY</a></p>
# <div class="box-save-job job-notsave">
# <a class="btn save btn-outline-hover" href="javascript:showLoginPopup(null, 'Đăng nhập hoặc Đăng ký để lưu tin tuyển dụng')"><i class="fa-regular fa-heart"></i> LƯU TIN</a>
# </div>
# </div>
# </div>
# <div class="box-apply-success">
# <div class="text-center">
# <p><a class="btn btn-topcv-primary btn-primary-hover open-apply-modal" data-toggle="modal" href="#"><i class="fa-solid fa-arrow-rotate-right"></i> ỨNG TUYỂN LẠI</a></p>
# <p><a class="btn btn-connect btn-outline-hover" href="http://candidate.topcvconnect.com/conversations/new/36224" target="_blank"><i class="fa-solid fa-comments"></i> NHẮN TIN</a></p>
# </div>
# </div>
# </div>

# %%
job_info = jb_bs.find('div',{'id':'tab-info'})
general_info = job_info.find_all('div',{'class':'box-info'})[-1].find_all('div',{'class':'box-item'})
job_salary = general_info[0].find('span').getText().strip()
job_type = general_info[2].find('span').getText().strip()
job_level = general_info[3].find('span').getText().strip()
job_yoe = general_info[-1].find('span').getText().strip()

# %%
job_addresses = [item.text.strip() for item in job_info.find('div',{'class':'box-address'}).find_all('div')[1:]]

# %%
job_addresses
# Out:
# ['- Hà Nội: Tầng 04, tòa nhà Sapphire Building số 163 Bà Triệu, P. Lê Đại Hành, Q. Hai Bà Trưng, TP. Hà Nội, Hai Bà Trưng',
#  '- Hồ Chí Minh: 29/23A Đoàn Thị Điểm, Phường 1, Phú Nhuận']

# %%
job_data = job_info.find('div',{'class':'job-data'})
job_details = job_data.find_all('div',{'class':'content-tab'})
job_desc = str(job_details[0])
job_req = str(job_details[1])

# %%
job_dict_arr = []
job_dict = {}
job_dict['job_desc'] = job_desc
job_dict['job_req'] = job_req
job_dict_arr.append(job_dict)
with open("data/topcv/json/topcv_industry_1", 'w') as outputfile:
    json.dump(job_dict_arr, outputfile)

# %%
max_page = int(pg_bs.find('ul',{'class':'pagination'}).find_all('li')[-2].text.strip())
max_page
# Out:
# 400

# %% [markdown]
# ### Loop through each industries and get all jobs of that industries

# %%
def get_jobs_by_industry(industry_name, industry_url, max_count=1000, save_name=None):
    except_urls = []
    if save_name is None:
        save_name = industry_name
    SAVE_DIR = "data/topcv/json"
    count = 0
    jobs_by_industries = {}
    base_url = "https://www.topcv.vn"
    print("Collecting industry: ", industry_name)
    jobs_by_industries[industry_name] = []
    ind_url = industry_url
    
    resp = requests.get(f'{base_url}{ind_url}')
    pg_bs = BeautifulSoup(resp.text, 'html.parser')
    try:
        max_page = int(pg_bs.find('ul',{'class':'pagination'}).find_all('li')[-2].text.strip())
    except Exception as e:
        max_page = 1
    print("Total page: ", max_page)
    for i in range(1,max_page+1):
        resp = requests.get(f'{base_url}{ind_url}?page={i}')
        print(f'{base_url}{ind_url}?page={i}')
        pg_bs = BeautifulSoup(resp.text, 'html.parser')
        job_body = pg_bs.find("div",{'class':'job-body'})
        job_list = job_body.find('div', {'class':'job-list-default'})
        job_items = job_list.find_all('div',{'class':'job-item-default'})
        for job_item in job_items:
            job_dict = {}
            job_item_ = job_item.find('div',{'class':'body'})
            job_url = job_item_.find('a').get('href')
            try:
                job_dict['url'] = job_url
                resp1 = requests.get(job_url)
                jb_bs = BeautifulSoup(resp1.text, 'html.parser')
                job_header = jb_bs.find('div',{'class':'box-detail-job'}).find('div',{'class':'box-header'})
                company_name = job_header.find('a',{'class':'company-logo'}).get('title')
                job_title = job_header.find('div',{'class':'box-info-job'}).find('h1',{'class':'job-title'}).getText().strip()
                job_deadline = job_header.find('div',{'class':'job-deadline'}).getText().strip()
                job_info = jb_bs.find('div',{'id':'tab-info'})

                general_info = job_info.find_all('div',{'class':'box-info'})[-1].find_all('div',{'class':'box-item'})
                job_salary = general_info[0].find('span').getText().strip()
                job_type = general_info[2].find('span').getText().strip()
                job_level = general_info[3].find('span').getText().strip()
                job_yoe = general_info[-1].find('span').getText().strip()
                job_addresses = [item.text.strip() for item in job_info.find('div',{'class':'box-address'}).find_all('div')[1:]]

                job_data = job_info.find('div',{'class':'job-data'})
                job_details = job_data.find_all('div',{'class':'content-tab'})
                job_desc = str(job_details[0])
                job_req = str(job_details[1])

                job_dict['job_title'] = job_title
                job_dict['job_deadline'] = job_deadline
                job_dict['company_name'] = company_name
                job_dict['job_salary'] = job_salary
                job_dict['job_type'] = job_type
                job_dict['job_yoe'] = job_yoe
                job_dict['job_addresses'] = job_addresses
                job_dict['job_desc'] = job_desc
                job_dict['job_req'] = job_req
                jobs_by_industries[industry_name].append(job_dict)
                count += 1
                if count % max_count == 0:
                    with open(f'{SAVE_DIR}/topcv_{save_name}_raw.json', 'w') as openfile:
                        json.dump(jobs_by_industries, openfile)
                    print(f"----------------Saved {count} records.----------------")
#                 print(f'{len(job_title)} - {len(job_salary)} - {len(job_type)} - {len(job_addresses)} - {len(job_desc)} - {len(job_req)}')
            except Exception as e:
                except_urls.append(job_url)
                
        print(f"Finished page {i} / {max_page}")
        
    with open(f'{SAVE_DIR}/topcv_{save_name}_raw.json', 'w') as openfile:
                        json.dump(jobs_by_industries, openfile)
    print(f"----------------Saved all {industry_name} records.----------------")
    return jobs_by_industries, except_urls

# %%
# time_start = time.time()
# total_lengths = []
# for industry in industries_js:
#     output = get_jobs_by_industry(industry['name'], industry['access_url'])
#     total_lengths.append(len(output))
# time_end = time.time()
# print("Finished collecting all jobs")
# print("Total time: ", (time_end - time_start))

# %%
exe_urls_dict = {}

# %% [markdown]
# Collecting Hàng cao cấp

# %%
luxury_goods_raw, exc_urls = get_jobs_by_industry('Hàng cao cấp', '/tim-viec-lam-hang-cao-cap-c10113')
# Out:
# Collecting industry:  Hàng cao cấp
# Total page:  3
# https://www.topcv.vn/tim-viec-lam-hang-cao-cap-c10113?page=1
# Finished page 1 / 3
# https://www.topcv.vn/tim-viec-lam-hang-cao-cap-c10113?page=2
# Finished page 2 / 3
# https://www.topcv.vn/tim-viec-lam-hang-cao-cap-c10113?page=3
# Finished page 3 / 3
# ----------------Saved all Hàng cao cấp records.----------------

# %%
exe_urls_dict['Hàng cao cấp'] = exc_urls

# %% [markdown]
# Collecting Sản phẩm công nghiệp

# %%
industrial_prods_raw, exc_urls_prod = get_jobs_by_industry('Sản phẩm công nghiệp', '/tim-viec-lam-san-pham-cong-nghiep-c10125')
save_json(exc_urls_prod, 'exc_urls_prod')
# Out:
# Collecting industry:  Sản phẩm công nghiệp
# Total page:  8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=1
# Finished page 1 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=2
# Finished page 2 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=3
# Finished page 3 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=4
# Finished page 4 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=5
# Finished page 5 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=6
# Finished page 6 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=7
# Finished page 7 / 8
# https://www.topcv.vn/tim-viec-lam-san-pham-cong-nghiep-c10125?page=8
# Finished page 8 / 8
# ----------------Saved all Sản phẩm công nghiệp records.----------------

# %%
testjs = read_json('topcv_Sản phẩm công nghiệp_raw')
testjs
# Out:
# {'Sản phẩm công nghiệp': [{'url': 'https://www.topcv.vn/viec-lam/nhan-vien-theo-doi-don-hang-biet-tieng-anh-hoac-tieng-hoa/1018936.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Theo Dõi Đơn Hàng - Biết Tiếng Anh Hoặc Tiếng Hoa',
#    'job_deadline': 'Hạn nộp hồ sơ: 15/06/2023',
#    'company_name': 'CÔNG TY TNHH JUWON VIỆT NAM',
#    'job_salary': '10 - 13 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Bình Dương: Lô C5-C6 (khu A2), đường D9, khu công nghiệp Rạch Bắp, Xã An Tây, Bến Cát'],
#    'job_desc': '<div class="content-tab"><ul><li>Tiếp nhận đơn hàng từ Khách hàng tìm kiếm, đặt mua và đăm vào về nguyên liệu</li><li>Quản lý PO và lịch giao hàng cho nhà cung cấp</li><li>Theo dõi sản phẩm trong từng giai đoạn</li><li>Làm việc với bộ phận sản xuất để xác nhận tiến độ sản xuất của lô hàng</li><li>Gửi chứng từ cho bộ phận xuất nhập khẩu để xuất hàng</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Thành thạo Tiếng Anh hoặc Tiếng Hoa</li><li>Ưu tiên ứng viên có kinh nghiệm nếu chưa có kinh nghiệm sẽ được đào tạo</li><li>Linh hoạt trong công việc</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-giam-sat-hien-truong-muc-luong-tu-11-18-trieu-tai-ha-noi/1006472.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Giám Sát Hiện Trường Mức Lương Từ 11- 18 Triệu Tại Hà Nội',
#    'job_deadline': 'Hạn nộp hồ sơ: 08/06/2023',
#    'company_name': 'Công Ty Cổ Phần Tường Kính TID',
#    'job_salary': '11 - 18 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hà Nội: Số 4 Liễu Giai, phường Cống Vị, Ba Đình'],
#    'job_desc': '<div class="content-tab"><p>-\tGiám sát công trình được giao\n</p><p>-\tLập biện pháp thi công\n</p><p>-\tLàm việc với các đội thợ\n</p><p>-\tLàm hồ sơ nghiệm thu quyết toán\n</p><p>-\tXử lý, giải quyết các vấn đề thi công, ATLĐ.</p></div>',
#    'job_req': '<div class="content-tab"><p>-\tTốt nghiệp từ cao đẳng trở lên các ngành nghề kỹ thuật, cơ khí, xây dựng, kiến trúc.\n</p><p>-\tƯu tiên có kinh nghiệm 1-2 năm về ngành nhôm kính, VLXD\n</p><p>-\tTrung thực, sẳn sàng đi công tác\n</p><p>-\tNhanh nhẹn, làm việc đội nhóm.</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-thiet-ke-jig-ga/1017273.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Thiết Kế (Jig, Gá,...)',
#    'job_deadline': 'Hạn nộp hồ sơ: 11/06/2023',
#    'company_name': 'Công ty TNHH Hit Tech System',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Bắc Ninh: Lô số 4, KCN Tiên Sơn ( khu mở rộng) P. Tân Hồng, Từ Sơn'],
#    'job_desc': '<div class="content-tab"><p>- Thiết kế jig, dụng cụ, thiết bị, bản vẽ sản phẩm trong dây chuyền sản xuất\n</p><p>-\tXây dựng ý tưởng\n</p><p>-\tChi tiết công việc trao đổi trong buổi phỏng vấn</p></div>',
#    'job_req': '<div class="content-tab"><p><b>-\tNam/Nữ: dưới 30 tuổi với ứng viên chưa Kinh nghiệm - Dưới 35 tuổi với ứng viên từ 2 năm Kinh nghiệm</b></p><p>-\tTốt nghiệp đại học, cao đẳng chuyên ngành cơ khí, cơ điện tử\n</p><p>-\tCó kiến thức về các bản vẽ cơ khí\n</p><p><b>- Với ứng viên trên 2 năm cần Sử dụng thành thạo Autocad, Soliword (ưu tiên ứng viên có hiểu biết về SMD và PCB), với chưa có Kinh nghiệm chỉ cần Biết sử dụng</b></p><p>-\tChăm chỉ, có tinh thần trách nhiệm cao với công việc\n</p><p>-\tLàm hành chính và có thể làm thêm giờ</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/thiet-ke-do-hoa-graphic-design/1021558.html?ta_source=JobSearchList',
#    'job_title': 'Thiết Kế Đồ Họa - Graphic Design',
#    'job_deadline': 'Hạn nộp hồ sơ: 20/06/2023',
#    'company_name': 'Công ty TNHH xuất nhập khẩu và dịch vụ Anh Minh',
#    'job_salary': '13 - 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hà Nội: 75 Láng Hạ, phường Thành Công, Ba Đình'],
#    'job_desc': '<div class="content-tab"><p>- Chịu trách nhiệm thiết kế, in ấn các ấn phẩm (Menu, banner, poster, standee, backdrop, …)<br>- Thiết kế các nội dung cập nhật trên các trang Social, Website,…<br>- Chụp hình &amp; chỉnh sửa hình ảnh món ăn, không gian nhà hàng.<br>- Lên ý tưởng, thực hiện biên tập, chỉnh sửa video phục vụ các hoạt động truyền thông, Marketing.</br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>+ Yêu cầu chung<br>- Có hiểu biết căn bản về mỹ thuật, đồ họa chuyên nghiệp. Có hiểu biết trong lĩnh vực thiết kế đồ họa số, đồ họa in ấn, chế bản,…<br>- Có tư duy sáng tạo và thẩm mỹ tốt, năng động, tỉ mỉ, chu đáo, nhiệt tình, chủ động trong công việc.<br>+ Kỹ năng<br/>- Sử dụng thành thạo các phần mềm: Photoshop, Illustrator, After Effect/Premiere.<br/>- Kỹ năng giao tiếp và làm việc nhóm tốt.<br/>- Kỹ năng giải quyết vấn đề.<br/>- Ưu tiên các bạn có khả năng dựng quay phim và edit video.</br></br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-thu-nhap-tu-15-trieu/1020285.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh Thu Nhập Từ 15 Triệu',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'CÔNG TY TNHH CÔNG NGHỆ FEDI',
#    'job_salary': '15 - 25 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: Hà Đông'],
#    'job_desc': '<div class="content-tab"><p>- Tư vấn, chăm sóc khách hàng có sẵn đang có nhu cầu sử dụng máy sản xuất cửa nhôm, máy gia công kính, máy cơ khí và các phụ kiện\n</p><p>- Tìm kiếm khách hàng mới, xây dựng nguồn khách hàng tiềm năng.\n</p><p>- Duy trì những quan hệ kinh doanh hiện có, nhận đơn đặt hàng và theo dõi đơn hàng\n</p><p>- Thực hiện lập đơn hàng, xử lý thắc mắc và khiếu nại của khách hàng. Theo dõi quá trình thanh lý hợp đồng, hỗ trợ phòng kế toán đốc thúc công nợ\n</p><p><br/></p></div>',
#    'job_req': '<div class="content-tab"><p>- Tuổi : 22-35 tuổi\n</p><p>- Tốt nghiệp trung cấp trở lên\n</p><p>- Ưu tiên ứng viên 1 năm trở lên trong lĩnh vực bán hàng, kinh doanh, cơ khí.</p><p>- Có khá năng giao tiếp tốt, nhanh nhẹn, chưa có kinh nghiệm sẽ được đào tạo</p><p>- Năng động, hòa đồng, có nhu cầu gắn bó lâu dài\n</p><p><br/></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/quan-doc-xuong-co-khi-thu-nhap-tu-20-25-trieu-gia-lam-ha-noi/1019193.html?ta_source=JobSearchList',
#    'job_title': 'Quản Đốc Xưởng Cơ Khí (Thu Nhập Từ 20 -25 Triệu) - Gia Lâm/Hà Nội',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/05/2023',
#    'company_name': 'CÔNG TY TNHH SX VÀ TM NAM Á',
#    'job_salary': '20 - 25 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hà Nội: Khu Công nghiệp Phú Thị (Cạnh khu đô thị Đặng Xá), Gia Lâm'],
#    'job_desc': '<div class="content-tab"><p>- Chuyên sản xuất về các loại bồn bể công nghiệp bằng inox</p><p>- Quản lý xưởng cơ khí chế tạo, thiết kế, bóc khối lượng từ bản vẽ, lập dự toán và kế hoạch mua bán đối với sản phẩm chế tạo.\n</p><p>- Thiết lập và kiểm soát quy trình hoạt động, sản xuất, đảm bảo quy trình sản xuất được diễn ra thuận lợi, có hiệu quả.\n</p><p>- Quản lý trang thiết bị, dụng cụ thi công và vật tư sản xuất một cách hợp lý.\n</p><p>- Quản lý, phân chia công việc cho các công nhân, phối hợp với bộ phận nhân sự của công ty để kiểm tra và xử lý những trường hợp vi phạm.\n</p><p>- Báo cáo tiến độ, tình hình sản xuất với cấp trên và các công việc khác theo phân công.</p><p>- Chi tiết trao đổi cụ thể khi phỏng vấn</p></div>',
#    'job_req': '<div class="content-tab"><p>- Trình độ Cao đẳng, đại học trở lên, học các chuyên ngành về Cơ khí, chế tạo</p><p>- Có kinh nghiệm trong lĩnh vực sản xuất cơ khí biết bản vẽ gia công cơ khí quản lý kiểm soát toàn bộ mặt hàng của công ty</p><p>- Ứng viên Có kinh nghiệm trong quản lý sản xuất cơ khí</p><p>- Có khả năng làm việc độc lập, chịu được áp lự</p><p>- Tác phong: nhanh nhẹn, hoạt bát, chuyên nghiệp, trình bày thuyết trình lưu loát, rõ ràng, mạch lạc, tự tin.</p><p>\n</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-qa-nhom-tieu-chuan-hoa-chat-luong/1019612.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên QA (Nhóm Tiêu Chuẩn Hóa Chất Lượng)',
#    'job_deadline': 'Hạn nộp hồ sơ: 15/06/2023',
#    'company_name': 'Công ty TNHH TOTO Việt Nam',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Dưới 1 năm',
#    'job_addresses': ['- Vĩnh Phúc: Nhà máy Vĩnh Phúc: Lô A2, KCN Thăng Long III, Bình Xuyên'],
#    'job_desc': '<div class="content-tab"><p>- Xây dựng và duy trì hệ thống quản lý chất lượng nhà máy sản xuất;\n</p><p>- Thực hiện thủ tục chứng nhận theo tiêu chuẩn ISO, tiêu chuẩn quốc gia;\n</p><p>- Cập nhật, triển khai các yêu cầu liên quan chất lượng sản phẩm theo luật Việt Nam, tiêu chuẩn quốc gia;</p><p>- Chuẩn hóa các tài liệu nội bộ nhằm đảm bảo tuân thủ quy định chất lượng, tiêu chuẩn quốc gia;</p><p>- Thực hiện đánh giá định kỳ để xác định mức độ tuân thủ liên quan chất lượng sản phẩm;</p><p>- Đưa ra điều chỉnh, đối sách hoặc cải tiến để đảm bảo mức độ tuân thủ quy định, tiêu chuẩn chất lượng;</p><p>- Thực hiện các công việc liên quan nhằm đảm bảo tuân thủ theo yêu cầu của luật, tiêu chuẩn quốc gia;</p><p>- Các công việc khác theo sự phân công của quản lý.</p></div>',
#    'job_req': '<div class="content-tab"><p>- Nam/Nữ 22-30 tuổi, tốt nghiệp Đại học trở lên, chuyên ngành Luật/ Kỹ thuật/ Ngôn ngữ… hoặc các ngành liên quan</p><p>- Có kiến thức, kinh nghiệm liên quan đến xây dựng hệ thống quản lý chất lượng theo ISO 9001 và đối ứng đánh giá chứng nhận;</p><p>- Có hiểu biết, kinh nghiệm liên quan đến cập nhật và triển khai văn bản pháp luật Việt Nam, tiêu chuẩn sản phẩm các quốc gia</p><p>- Có tinh thần làm việc tập thể và không ngại khó khăn, áp lực công việc;\n</p><p>- Thành thạo Word, Excel, Powerpoint;\n</p><p>- Tiếng Anh/ Tiếng Trung: đọc hiểu, giao tiếp cơ bản trong công việc.\n</p><p>- Kỹ năng giao tiếp, xử lý tình huống, làm việc nhóm tốt;\n</p><p>- Có kỹ năng tổ chức công việc và quản lý thời gian tốt;\n</p><p>- Tinh thần trách nhiệmn với công việc, chăm chỉ, khả năng học hỏi tốt, chủ động và suy nghĩ tích cực.</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-nien-kinh-doanh-khong-yeu-cau-kinh-nghiem/1022796.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Niên Kinh Doanh - Không Yêu Cầu Kinh Nghiệm',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'Công Ty Cổ Phần Đầu Tư Và Thương Mại Suối Giàng',
#    'job_salary': '6 - 10 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: 48 Lê Văn Lương, Thanh Xuân'],
#    'job_desc': '<div class="content-tab"><p>1. Đánh giá khách hàng tiềm năng</p><p>2. Lên phương án tiếp cận các khách hàng trong phân khúc bán.</p><p>3. Lập và bảo vệ kế hoạch bán hàng theo tháng, quý.</p><p>4. Duy trì các mối quan hệ kinh doanh đã có và thiết lập mối quan hệ với các khách hàng mới, khách hàng tiềm năng.</p><p>5. Nghiên cứu và thiết lập các kênh phân phối sản phẩm kinh doanh theo từng thời điểm (hệ thống Đại lý, cửa hàng; gian hàng trưng bày sản phẩm…)</p><p>6. Tổ chức các chương trình khuyến mãi, hội nghị khách hàng, tiếp xúc khách hàng</p><p>7. Tham gia các hội chợ quảng cáo giới thiệu sản phẩm Trà.</p><p>8. Đàm phán, kí kết hợp đồng với các đối tác</p><p>9. Phối hợp với bộ phận kinh doanh online và bộ phận liên quan, thúc đẩy doanh số; chốt đơn hàng và điều phối kho vận.</p><p>10. Thực hiện báo cáo doanh thu, báo cáo công việc cho trưởng bộ phận</p></div>',
#    'job_req': '<div class="content-tab"><p>- Có kinh nghiệm là một lợi thế.</p><p>- Ưu tiên ứng viên có kinh nghiệm về kinh doanh ngành quà tặng.</p><p>- Có sức khỏe tốt, nhanh nhẹn, nhạy bén, linh hoạt, nhiệt tình và có trách nhiệm cao trong công việc.</p><p>- Có khả năng giao tiếp, đàm phán, thuyết phục khách hàng tốt.</p><p>- Có tinh thần cầu tiến, ham học hỏi, trung thực.</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-thiet-ke-chieu-sang-thiet-ke-noi-that/1022915.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Thiết Kế Chiếu Sáng/ Thiết Kế Nội Thất',
#    'job_deadline': 'Hạn nộp hồ sơ: 18/06/2023',
#    'company_name': 'Công Ty Cổ Phần Thiết Bị Điện Simon Việt Nam',
#    'job_salary': '12 - 20 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hà Nội: Cầu Giấy'],
#    'job_desc': '<div class="content-tab"><ul><li>Tiếp nhận thông tin kỹ thuật về sản phẩm từ phòng R&amp;D</li><li>Lên ý tưởng chiếu sáng cho công trình chung cư, biệt thự, khách sạn, nhà xưởng công nghiệp...</li><li>Thiết kế chiếu sáng, tính toán mô phỏng độ rọi trên phầm mềm Dialux, xuất bản vẽ Soft Autocad</li><li>Thuyết trình, bảo vệ phương án đã thiết kế</li><li>Thiết kế sơ đồ lắp đặt đèn</li><li>Phối hợp với bộ thi công hoàn thiện công trình đã thiết kế Và một số công việc khác dưới sự chỉ đạo của Ban giám đốc.</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Nam, Độ tuổi: 25-45</li><li>Tốt nghiệp các trường Bách Khoa, Công nghiệp, Kiến trúc…</li><li>Có kinh nghiệm 1-3 năm vị trí Kỹ thuật - tư vấn ánh sáng.</li><li>Trung thực, cẩn thận và có trách nhiệm với công việc.</li><li>Thành thạo phầm mềm Autocard, Dialux, Excel, Word, Powerpoint, Ưu tiên biết dựng 3D</li><li>Ưu tiên sử dụng tốt Tiếng anh</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/ke-toan-tong-hop/916919.html?ta_source=JobSearchList',
#    'job_title': 'Kế Toán Tổng Hợp',
#    'job_deadline': 'Hạn nộp hồ sơ: 18/06/2023',
#    'company_name': 'CÔNG TY TNHH SINABRO',
#    'job_salary': 'Trên 12 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '2 năm',
#    'job_addresses': ['- Hà Nội: Số 24 Tòa nhà An Phú, Cầu Giấy'],
#    'job_desc': '<div class="content-tab"><p>- Thu thập, kiểm tra, sắp xếp các chứng từ, hóa đơn từ kế toán các dự án.<br>- Lập các tờ khai thuế gtgt, thuế tncn, báo cáo tình hình sử dụng hóa đơn...<br>- Hạch toán nghiệp vụ, cân đối số liệu vào sổ sách<br>- Lập Báo cáo tài chính theo năm<br>- Trực tiếp làm việc cùng các công ty kiểm toán cuối mỗi năm tài chính<br>- Hoàn thiện sổ sách,lưu trữ chứng từ theo quy định.<br>- Tham gia trực tiếp quyết toán thuế TNDN, TNCN, Hoàn thuế GTGT cho Công ty.<br/>- Chuẩn bị hồ sơ thanh toán nước ngoài, làm \xa0việc với bên Logistic để thông quan hàng hóa<br/>- Chuẩn bị hồ sơ vay vốn ngân hàng, hồ sơ mở bảo lãnh<br/>- Quản lý vật tư, hao phí, hồ sơ thanh toán các công trình<br/>- Làm các báo cáo khác theo yêu cầu của ban lãnh đạo.</br></br></br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>- Tốt nghiệp đại học, cao đẳng chuyên ngành liên quan<br/>- Sử dụng thành thạo Excel, Word, Power Point, phần mềm kế toán Misa<br/>- Ưu tiên ứng viên đã từng làm việc trong các công ty xây dựng hoặc nội thất<br/>- Ưu tiên ứng viên có kinh nghiệm 3 năm trở lên<br/>- Ưu tiên ứng viên có khả năng giao tiếp tiếng anh</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/tro-ly-kinh-doanh-khong-yeu-cau-kinh-nghiem/1022112.html?ta_source=JobSearchList',
#    'job_title': 'Trợ Lý Kinh Doanh - Không Yêu Cầu Kinh Nghiệm',
#    'job_deadline': 'Hạn nộp hồ sơ: 20/07/2023',
#    'company_name': 'Công ty CP Thiết bị & DV Đồng Lợi',
#    'job_salary': 'Trên 8 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: Lô 6-2 đường B2-B3, KCN Quang Minh, H Mê Linh, Hà Nội, Mê Linh'],
#    'job_desc': '<div class="content-tab"><p>- Hỗ trợ bộ phận Kinh doanh Soạn thảo văn bản, làm báo giá, hợp đồng, công văn, ... gửi đến Khách hàng<br>- Trực điện thoại, làm các công việc lễ tân: đón tiếp Khách đến VP,...<br>- Chấm công, \xa0tạo đơn đặt hàng theo quy định\xa0<br>- Các công việc khác có liên quan theo yêu cầu của cấp quản lý;<br>- Ưu tiên: Có khả năng giao tiếp Tiếng Anh</br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>Trình độ TC, CĐ hoặc ĐH</p><p>Thành thạo tin học văn phòng (word, excel, ppt...)</p><p>Có khả năng làm việc độc lập, sáng tạo</p><p>Có khả năng hòa đồng; xây dựng tinh thần làm việc theo nhóm</p><p>Có ý chí phấn đấu, tìm tòi, học hỏi.</p><p>Chấp nhận làm việc dưới áp lực cao.</p><p>Thành thạo sử dụng các phần mềm trong Kinh doanh</p><p>Cam kết làm việc lâu dài, gắn bó</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/tho-dung-may-san-xuat-lo-xo/1021903.html?ta_source=JobSearchList',
#    'job_title': 'Thợ Đứng Máy Sản Xuất Lò Xo',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'CÔNG TY CỔ PHẦN SẢN XUẤT VIVA TECH',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hà Nội: Ngõ 70, thôn Đản Dị, xã Uy Nỗ, huyện Đông Anh, thành phố Hà Nội, Đông Anh'],
#    'job_desc': '<div class="content-tab"><ul><li>Phụ trách đứng máy sản xuất lò xo</li><li>Đọc bản vẽ và phát triển sản phẩm mới của Công ty</li><li>Phụ trách chất lượng đầu ra của sản phẩm</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Có ít nhất 2-3 năm kinh nghiệm đứng máy sản xuất lò xo</li><li>Cẩn thận, ham học hỏi</li><li>Gắn bó lâu dài với Công ty</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-bot-da-thi-truong-trung-quoc/1021861.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh Bột Đá Thị Trường Trung Quốc',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'Công ty CP khoáng sản công nghiệp Yên Bái',
#    'job_salary': '12 - 17 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '2 năm',
#    'job_addresses': ['- Hà Nội: A60 Khu đấu giá 3ha Phúc Diễn - Bắc Từ Liêm - Hà Nội, Từ Liêm'],
#    'job_desc': '<div class="content-tab"><p>- Phát triển bán hàng bột đá siêu mịn CaCO3<br>- Đảm bảo mục tiêu doanh thu theo chỉ tiêu được giao.<br>- Thiết lập kế hoạch thực hiện mục tiêu.<br>- Báo cáo những thông tin phản hồi lại cho cấp trên, thu nhận những thông tin phản hồi từ phía khách hàng, cùng với đồng nghiệp và cấp trên xử lý thông tin liên quan đến phạm vi công việc được giao.<br>- Tìm kiếm khách hàng tiềm năng. Tiếp xúc với khách hàng để giới thiệu và bán sản phẩm.<br>- Thực hiện các công việc liên quan đến kí kết và triển khai hợp đồng.<br>- Thu thập thông tin về khách hàng và thị trường để xây dựng cơ sở dữ liệu khách hàng.<br/>- Theo dõi, thực hiện chăm sóc khách hàng giúp khách hàng cảm thấy hài lòng với sản phẩm, dịch vụ do công ty cung cấp, duy trì lòng trung thành của khách hàng với công ty.<br/>- Tổng hợp các báo cáo , đưa ra các hướng khắc phục, cải tiến( nếu có)<br/>- Theo dõi, cập nhật thông tin thị trường và đưa ra các ý kiến đề xuất với cấp trên<br/>- Tham gia, đóng góp ý kiến phối hợp với các phòng ban liên quan để cải tiến dịch vụ, quy trình triển khai ngày càng hoàn thiện và chất lượng hơn<br/>- Thực hiện báo cáo kết quả định kỳ và đột xuất theo yêu cầu của cấp trên.</br></br></br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><ul><li>Tốt nghiệp Cao đẳng trở lên chuyên ngành kinh tế, quản trị kinh doanh, thương mại hoặc tốt nghiệp ngành kỹ thuật về Hóa học yêu thích kinh doanh, hoặc có hiểu biết về ngành sx Bột đá, nhựa hoặc các phụ gia hóa chất công nghiệp …,</li><li>HSK 5 trở lên</li><li>Ưu tiên ứng viên có kinh nghiệm làm việc 01 năm về kinh doanh sản phẩn ngành bột đá hoặc hóa chất…</li><li>Thành thạo tin học văn phòng, đặc biệt Excell.</li><li>Có tư duy sáng tạo, nhạy bén trong công việc.</li><li>Nhiệt tình, sẵn sàng làm việc độc lập cũng như hợp tác theo nhóm.</li><li>Có cơ hội học hỏi, phát triển và khẳng định bản thân.</li><li>Chấp nhận công việc áp lực cao, sẵn sàng đi công tác.</li><li>Có tính kỷ luật cao và trách nhiệm với công việc.</li><li>Quản lý hiệu quả công việc tốt.</li><li>Ngoại hình dễ nhìn, giao tiếp tốt.</li><li>Khuyến khích ứng cử viên có thể đi làm ngay</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kho-nam/1021476.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kho (Nam)',
#    'job_deadline': 'Hạn nộp hồ sơ: 17/06/2023',
#    'company_name': 'Công ty TNHH Cao Su-Nhựa Thanh Bình (PERUBCO)',
#    'job_salary': '9 - 11 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hồ Chí Minh: Lô 18 Tân Tạo, KCN Tân Tạo, Bình Tân'],
#    'job_desc': '<div class="content-tab"><p>Kiểm tra các chứng từ yêu cầu nhập / xuất hàng theo đúng quy định.<br>Thực hiện việc nhập và xuất hàng cho cá nhân liên quan.<br>Nhận các chứng từ giao hàng, yêu cầu xuất hàng, lưu và chuyển cho bộ phận mua hàng hoặc kế toán theo quy định.<br>Theo dõi hàng hóa xuất nhập tồn<br>Ghi phiếu nhập, phiếu xuất kho.<br>Trực tiếp nhập phiếu xuất vào phần mềm.<br>Theo dõi số lượng xuất nhập tồn hàng ngày và đối chiếu với định mức tồn kho tối thiểu.<br/>Trực tiếp sắp xếp các loại hàng hóa trong kho.<br/>Sắp xếp hàng hóa tránh bị ướt, đổ vỡ…<br/>Lập sơ đồ kho và cập nhật sơ đồ kho khi có phát sinh hàng hóa.</br></br></br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>Tốt nghiệp Trung cấp trở lên<br/>Thành thạo máy tính<br/>Có kinh nghiệm làm tại vị trí Thủ kho<br/>Trung thực, cẩn thận, tỉ mỉ, hoạt bát, nhanh nhẹn<br/>Gắn bó lâu dài với Công ty<br/>Có sức khỏe tốt<br/>Giờ làm việc: Từ thứ 2 - thứ 7 (7.30 \xa0- 16.30, nghỉ trưa 11h30 -12h30).</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-san-xuat/994182.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kỹ Thuật Sản Xuất',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'CÔNG TY TNHH QUỐC TẾ HUY HOÀNG PHƯƠNG ĐÔNG',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '5 năm',
#    'job_addresses': ['- Hà Nam: Duy Tiên'],
#    'job_desc': '<div class="content-tab"><ul><li>Hỗ trợ bộ phận sản xuất giải quyết các vấn đề kỹ thuật liên quan đến quá trình sản xuất các sản phẩm trang sức mỹ nghệ của công ty</li><li>Hỗ trợ phá khuôn và cải tiến khuôn.</li><li>Lập báo cáo kỹ thuật cho khách hàng, thảo luận với khách hàng và nhà cung cấp.</li><li>Cải tiến kỹ thuật trong quá trình sản xuất</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Yêu cầu ngoại ngữ : tiếng anh hoặc tiếng trung\xa0</li><li>5 năm kinh nghiệm trong ngành kỹ thuật</li><li>Cẩn thận và có trách nhiệm;</li><li> Sử dụng thành thạo các phần mềm văn phòng.</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/dinh-duong-vien-suat-an-cong-nghiep/1021613.html?ta_source=JobSearchList',
#    'job_title': 'Dinh Dưỡng Viên Suất Ăn Công Nghiệp',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'TẬP ĐOÀN AN PHÁT HOLDINGS',
#    'job_salary': '8 - 10 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hải Dương: Địa chỉ: Khu Công Nghiệp Kỹ thuật cao An Phát, Km 47, Quốc Lộ 5, P. Việt Hòa, TP. Hải Dương, Hải Dương (Đối diện khách sạn Nam Cường), TP Hải Dương'],
#    'job_desc': '<div class="content-tab"><p>- Xây thực đơn, định lượng.</p><p>- Kiểm tra quá trình làm việc của các bộ phận để kiểm soát các vấn đề về VSATTP.</p><p>- Kiểm soát định lượng, chất lượng các món ăn.</p><p>- Phụ trách các vấn đề về vệ sinh an toàn thực phẩm, HACCP, ATLD, PCCC.</p><p>- Kiểm soát các mối nguy trong quá trình sơ chế, chế biến và bảo quản thực phẩm (vd: dị vật, nấm mốc, mầm bệnh, kiểm soát côn trùng gây hại.</p><p>- Tham mưu cho quản lý trực tiếp các vấn đề còn hạn chế trong quá trình vận hành nhằm nâng cao hiểu quả sản xuất và chất lượng công việc.</p></div>',
#    'job_req': '<div class="content-tab"><p>- Tốt nghiệp ngành công nghệ thực phẩm, dinh dưỡng.<br>- Sẵn sàng đi công tác<br>- Sử dụng tốt tin học văn phòng</br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-luong-cung-7-10tr/879489.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh Lương Cứng 7-10Tr',
#    'job_deadline': 'Hạn nộp hồ sơ: 17/06/2023',
#    'company_name': 'Công ty TNHH MTV Sản xuất kệ kho hàng BHD Việt Nam',
#    'job_salary': '7 - 10 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Quảng Nam: Lô 20, đường số 8, kcn Điện Nam, Điện Ngọc, Điện Bàn, Quảng Nam, Điện Bàn'],
#    'job_desc': '<div class="content-tab"><p>- Tiếp nhận và xử lý đơn hàng\xa0<br>- Tìm kiếm khách hàng mới, quảng cáo sản phẩm trên các nền tảng xã hội, Alibaba<br>- Thực hiện các công việc khác theo sự chỉ đạo của cấp trên...</br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>- Tiếng Anh thành thạo (nghe nói đọc viết), tiếng Trung cơ bản.<br>- Không yêu cầu kinh nghiệm.<br>- Có khả năng tư vấn, thuyết phục khách hàng.</br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh/1021659.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'CÔNG TY CỔ PHẦN CÔNG NGHỆ BISTECH VIỆT NAM',
#    'job_salary': 'Trên 10 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hà Nội: Số 6 Ngõ 95 Chùa Bộc, Trung Liệt, Đống Đa, Hà Nội, Đống Đa'],
#    'job_desc': '<div class="content-tab"><ul><li>Tìm kiếm, quảng bá và tư vấn cho đối tác về dịch vụ của công ty.</li><li>Triển khai chiến dịch thông qua các công cụ quảng cáo, marketing online (Facebook, SEO, Google Adword, QC Google, Banner,Web,diễn đàn…), phối hợp với phòng marketing để tìm kiếm và quảng bá dịch vụ của công ty đến các doanh nghiệp (sẽ được hướng dẫn cụ thể khi làm việc)</li><li>Trả lời và tư vấn cho khách hàng qua các kênh Online (Facebook, Website…)</li><li>Trực tiếp thực hiện hoạt động bán hàng, tìm kiếm khách hàng, duy trì mối quan hệ với khách hàng</li><li>Chi tiết trao đổi trực tiếp khi phỏng vấn.</li></ul></div>',
#    'job_req': '<div class="content-tab"><p>- Tốt nghiệp trung cấp trở lên chuyên ngành kinh tế, tài chính và các ngành thương mại liên quan.</p><p>- Tối thiểu 1 năm kinh nghiệm vị trí tương đương</p><p>- Giao tiếp tốt, lập kế hoạch phát triển sàn.</p><p>- Hòa đồng, biết lắng nghe &amp; Có sự tư duy và hiểu biết về sàn thương mại điện tử.</p><p>- Chủ động trong công việc và có tinh thần trách nhiệm trong việc.</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/ky-su-che-tao-may/975587.html?ta_source=JobSearchList',
#    'job_title': 'Kỹ Sư Chế Tạo Máy',
#    'job_deadline': 'Hạn nộp hồ sơ: 17/06/2023',
#    'company_name': 'CÔNG TY TNHH M.R.O BLAST & PAINT',
#    'job_salary': '15 - 20 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '2 năm',
#    'job_addresses': ['- Hồ Chí Minh: 21 Đường số 49B, Phường Tân Tạo, Quận Bình Tân, Bình Tân'],
#    'job_desc': '<div class="content-tab"><p>- Chịu trách nhiệm lập bản vẽ chi tiết, bản vẽ 2D, 3D theo yêu cầu của công ty và khách hàng.</p><p>- Tiếp nhận yêu cầu từ NV Kinh doanh, Ban lãnh đạo, tổng hợp thông tin.</p><p>- Lên bản vẽ thiết kế chi tiết, 2D, 3D theo yêu cầu từng đơn hàng.</p><p>- Tham gia khảo sát mặt bằng, nhu cầu của Khách hàng cùng bộ phận Kinh doanh.</p><p>- Tham gia khảo sát mặt bằng thực tế tại địa điểm của khách hàng theo yêu cầu của Bộ phận kinh doanh.</p><p>- Hỗ trợ Sale tư vấn, định hướng các vấn đề về bố cục bài trí và các thông số kỹ thuật khác phù hợp cho khách hàng để lên bản vẽ.</p><p>- Phối hợp cùng bộ phận kinh doanh và bộ phận sản xuất xử lý các vấn đề liên quan đến bản vẽ.</p><p>- Tư vấn, thuyết trình bản vẽ thiết kế với khách hàng, Phòng kinh doanh (nếu cần)</p><p>- Phối hợp giải quyết các vấn đề phát sinh trong quá trình triển khai.</p><p>- Thực hiện các công việc phát sinh khác theo chỉ đạo của Ban lãnh đạo.</p></div>',
#    'job_req': '<div class="content-tab"><p>- Tốt nghiệp Cao đẳng/Đại học chuyên ngành Kỹ sư Cơ khí, hoặc các chuyên ngành khác có liên quan.</p><p>- Kinh nghiệm liên quan tới vị trí: Ít nhất 2 năm kinh nghiệm tại vị trí tương đương.</p><p>- Sử dụng thành thạo thiết kế 2D, 3D, Solidworks, Auto Cad (yêu cầu bắt buộc).</p><p>- Ưu tiên ứng viên từng làm Công ty sản xuất cơ khí/ô tô,..</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/thuc-tap-sinh-seo-content-ha-noi-khong-yeu-cau-kinh-nghiem/1021282.html?ta_source=JobSearchList',
#    'job_title': 'Thực Tập Sinh SEO Content - Hà Nội (Không Yêu Cầu Kinh Nghiệm)',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'Công ty TNHH Hicotech Việt Nam',
#    'job_salary': '1.5 - 4 triệu',
#    'job_type': 'Thực tập',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: Liền kề 23-19 Ngô Thì Nhậm, Phường La Khê, Hà Đông'],
#    'job_desc': '<div class="content-tab"><ul><li>Xây dựng, phát triển, quản trị nội dung website của công ty</li><li>Hỗ trợ viết bài SEO, bài sản phẩm lên website</li><li>Lên kế hoạch phân tích từ khóa</li><li>Thực hiện các công việc khác theo sự phân công của cấp trên</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Sinh viên năm 1,2,3 các trường cao đẳng, đại học\xa0</li><li>Có laptop cá nhân\xa0</li><li>Không yêu cầu kinh nghiệm</li><li>Chăm chỉ, sáng tạo, chịu được áp lực trong công việc</li><li>Có thể đi làm tối thiểu 5 buổi/tuần</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-may-phu-kien-nganh-cong-nghiep/1020810.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh Máy/Phụ Kiện Ngành Công Nghiệp',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'Công ty CP Đầu Tư Hợp Lực 819 Việt Nam',
#    'job_salary': 'Trên 9 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: KĐT Pháp Vân, Hoàng Liệt, Hoàng Mai'],
#    'job_desc': '<div class="content-tab"><p>• Gọi điện để tìm kiếm khách hàng doanh nghiệp mới, chăm sóc khách hàng cũ.<br/></p><p>• Gọi điện giới thiệu sản phẩm, giá cả... với các khách hàng mới, được cung cấp data.\n</p><p>• Chăm sóc và giữ mối quan hệ tốt với khách hàng.\n</p><p>• Báo cáo kết quả định kỳ phản hồi của khách hàng với sếp sau mỗi lần công tác\n</p><p>• Hỗ trợ các công việc khác theo yêu cầu của Quản lý trực tiếp.</p></div>',
#    'job_req': '<div class="content-tab"><p>• Giao tiếp tốt, chịu được áp lực công việc.\n</p><p>• Khát khao học hỏi, khám phá năng lực và giới hạn của bản thân.\n</p><p>• Chưa có kinh nghiệm sẽ được đào tạo.\n</p><p>• Kỹ năng bán hàng, đàm phán, giao tiếp</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/cong-tac-vien-kinh-doanh/1020574.html?ta_source=JobSearchList',
#    'job_title': 'Cộng Tác Viên Kinh Doanh',
#    'job_deadline': 'Hạn nộp hồ sơ: 17/06/2023',
#    'company_name': 'Công ty CP Phát triển thương mại và Xuất nhập khẩu Á Châu',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Bán thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: Số 79 ngõ 1277 Giải Phóng, Thịnh Liệt, Hoàng Mai'],
#    'job_desc': '<div class="content-tab"><p>- Tư vấn, giới thiệu và chăm sóc khách hàng dựa trên danh sách khách hàng công ty cung cấp nhằm đạt được mục tiêu tăng doanh thu và lợi nhuận công ty.</p><p>- Chịu trách nhiệm về tình hình hoạt động kinh doanh trên địa bàn được bàn giao.</p><p>- Thường xuyên tiếp xúc khách hàng, nắm rõ các thông tin của khách hàng. Tiếp nhận các phản ánh và yêu cầu của khách hàng về sản phẩm của Công ty, công tác giao hàng…</p><p>- Hỗ trợ phòng kế toán đốc thúc khách hàng thanh toán công nợ cho đến khi khách hàng đã thanh toán xong.<br>- Chăm sóc khách hàng cũ, tìm kiếm thị trường, phát triển hệ thống khách hàng mới. Duy trì và phát triển tốt mối quan hệ khách hàng.<br>- Lập kế hoạch và báo cáo kết quả hàng tuần.<br>- Thực hiện các công việc khác theo chỉ thị của Ban lãnh đạo.</br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>\xa0</p><p>- Ưu tiên tốt nghiệp\xa0 các chuyên ngành liên quan đến xây dựng, giao thông hoặc kinh doanh.</p><p>- Kỹ năng giao tiếp tốt, biết word, excel ..</p><p>- Có thái độ làm việc nghiêm túc, luôn luôn lắng nghe, học hỏi các ý kiến từ đồng nghiệp trong công ty.</p><p>\xa0</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-dung-may/1020967.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Đứng Máy',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'CÔNG TY CỔ PHẦN THÉP ĐỈNH CAO',
#    'job_salary': '7 - 12 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: Cụm CN Lai Xá, Kim Chung, Hoài Đức'],
#    'job_desc': '<div class="content-tab"><p>- Nhân viên đứng máy vận hành các máy cơ khí trong xưởng (máy cắt, máy chấn, máy đột CNC, máy cắt laser, hàn…).<br>- \xa0Chịu trách nhiệm quản lý máy móc mình vận hành.<br>- \xa0Công việc khác theo yêu cầu của trưởng bộ phận.</br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>- \xa0Tốt nghiệp chuyên ngành cơ khí.<br>- \xa0Ưu tiên người có kinh nghiệm, chưa có được đào tạo.<br>- \xa0Trung thực, nhiệt tình, năng động, cầu tiến, ham học hỏi, có trách nhiệm với công việc, có nguyện vọng gắn bó lâu dài.</br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-nganh-cua-nhom-kinh/1020843.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kỹ Thuật Ngành Cửa Nhôm Kính',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'CÔNG TY TNHH CÔNG NGHỆ FEDI',
#    'job_salary': '8 - 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Hà Nội: Hà Đông'],
#    'job_desc': '<div class="content-tab"><p>- Trực tiếp lắp đặt máy sản xuất cửa nhôm mới tại xưởng của khách hàng.\n</p><p>- Bảo hành máy sản xuất cửa nhôm tại xưởng của khách hàng theo sự phân công của công ty.</p><p>- Lắp ráp và kiểm tra sản phẩm tại trụ sở công ty.</p><p>- Thời gian làm việc: Thứ 2 - Thứ 7</p></div>',
#    'job_req': '<div class="content-tab"><p>- Tuổi : 20-35 tuổi. Tốt nghiệp trung cấp trở lên chuyên ngành kỹ thuật, xây dựng… và ngành liên quan</p><p>- Có kinh nghiệm làm việc trong lĩnh vực cơ khí, xây dựng, cửa nhôm kính, nội thất .... là một lợi thế</p><p>- Chưa có kinh nghiệm sẽ được đào tạo</p><p>- Trung thực, nhanh nhẹn, có khả năng xử lý vấn đề</p><p><br/></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/ky-su-ban-hang/1020068.html?ta_source=JobSearchList',
#    'job_title': 'Kỹ Sư Bán Hàng',
#    'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#    'company_name': 'CÔNG TY CỔ PHẦN CÔNG NGHỆ TỰ ĐỘNG TÂN TIẾN',
#    'job_salary': '15 - 20 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hồ Chí Minh: 1 Sáng tạo, P. Tân Thuận Đông, Quận 7'],
#    'job_desc': '<div class="content-tab"><p>- Phát triển kinh doanh, tìm kiếm &amp; phát triển thị trường kinh doanh sản phẩm, triển khai các hợp đồng theo hướng đảm bảo các mục tiêu kinh doanh.</p><p>- Xây dựng, duy trì và mở rộng mối quan hệ khách hàng nhằm đạt mục tiêu doanh số kế hoạch.</p><p>- Tham gia quá trình chuẩn bị hồ sơ chào giá, chào hàng và hồ sơ thầu.</p></div>',
#    'job_req': '<div class="content-tab"><p>- Tốt nghiệp Đại Học chuyên ngành điện, điện tử, tự động hóa</p><p>-\xa0 Ít nhất 1 năm kinh nghiệm, ưu tiên ứng viên có kinh nghiệm Sales sản phẩm điện, tự động hóa, đo lường trong công nghiệp.</p><p>-\xa0 Giao tiếp tốt, kỹ năng đàm phán &amp; thuyết phục tốt.</p><p>-\xa0 Kỹ năng sắp xếp, lên kế hoạch công việc, quản lý thời gian tốt và xử lý công việc nhanh.</p><p>-\xa0 Tiếng Anh tương đương bằng B</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/online-business-development-manager/809130.html?ta_source=JobSearchList',
#    'job_title': 'Online Business Development Manager',
#    'job_deadline': 'Hạn nộp hồ sơ: 01/07/2023',
#    'company_name': 'Công ty TNHH Tài Năng',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hồ Chí Minh: Vicom Mega Mall Thảo Điền, Quận 2'],
#    'job_desc': '<div class="content-tab"><p><strong><u>Description</u></strong><br>The Online Sales Manager will be responsible to drive revenue and growth through the various Online Channels of the company which includes the Futureworld Online Store, Marketplace Store, Facebook &amp; Social Store. \xa0</br></p><p><strong><u>Main Tasks</u></strong></p><ul><li>Develop online channel sales through Company’s \xa0Stores (i.e. Lazada / Shopee / Online /Tiki) to meet revenue and growth targets.</li><li>Manage the online store with 500+ SKU. Setting the KPI to drive the results.</li><li>Understand the trend / customer interests based on behavior pattern in website through Analytics, customer response &amp; suggest changes that support initiative better.</li><li>Recommend and control Marketplace Digital Merchandising, Product recommendation, Product Promotions used for the Marketplace Platform.</li><li>Conceptualize digital marketing initiatives, analyze data and measure results specific to Marketplace platform.</li><li>Recommend Digital Marketing Activities run in different social, digital platforms to promote Marketplace business.</li><li>Create and manage product descriptions, product information for online channels which include the Marketplace store.</li></ul><p>\xa0</p></div>',
#    'job_req': '<div class="content-tab"><ul><li>3-5 yrs+ experiences in Online Sales / Digital Sales / Digital Marketing would be required. Specific to online store management experience with 500+ SKUs.</li><li>Team of 3-4 head count of digital biz team management ability. In depth knowledge of market place Tiki / Shopee / Lazada</li><li>In depth knowledge of Skill in HTML, Wordpress/Magento , features and capabilities</li><li>Good communication ability in English &amp; Vietnamese.</li><li>Strong Sales Target oriented business execution skills.</li><li>Ability to set target and drive the numbers.</li><li>Apple products knowledge would be added advantage.</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-thi-truong/1020379.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh Thị Trường',
#    'job_deadline': 'Hạn nộp hồ sơ: 12/06/2023',
#    'company_name': 'CÔNG TY TNHH SX-TM TẬP ĐOÀN TÂN HUY HOÀNG',
#    'job_salary': '7 - 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hồ Chí Minh: 51/34/6 Cống Lở, Phường 15, Tân Bình'],
#    'job_desc': '<div class="content-tab"><p>• Chịu trách nhiệm phát triển các Khách hàng mới từ khu vực, chăm sóc khách hàng cũ là đại lý\n</p><p>• Thực hiện việc đi thăm, khảo sát các khách hàng.\n</p><p>• Thuyết phục khách mua hàng, đảm bảo số lượng và doanh số đơn hàng theo tháng\n</p><p>• Truyền tải và đóng góp các ý kiến phản hồi để ngày càng hoàn thiện sản phẩm cho Khách hàng\n</p><p>• Lên kế hoạch và phụ trách tổ chức các sự kiện bán và giới thiệu sản phẩm tại các điểm tiếp xúc khách hàng.</p><p>• Báo cáo, đánh giá tình hình bán hàng tại Đại lý\n</p><p>• Kiểm tra tồn kho và báo cáo tình hình hoạt động bán hàng tại nhà phân phối\n</p><p>• Đề xuất hướng xử lý các vấn đề phát sinh trong quá trình bán hàng của Đại lý</p></div>',
#    'job_req': '<div class="content-tab"><p>Trình độ học vấn : Trung cấp trở lên\n</p><p>Chuyên ngành : Thuỷ sản, chế biến, Marketing….\n</p><p>• Kỹ năng bán hàng, giao tiếp và thương lượng tốt.\n</p><p>• Nhiệt tình trong công việc.\n</p><p>• Kỹ năng quản lý, tổ chức và ưu tiên công việc.\n</p><p>• Có khả năng thuyết trình hướng tới nhu cầu của người nghe\n</p><p>• Kỹ năng quản lý các mối quan hệ và sẵn sàng tiếp nhận các ý kiến phản hồi</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/chuyen-vien-tuyen-dung-co-tieng-anh-thu-nhap-hap-dan/1020222.html?ta_source=JobSearchList',
#    'job_title': 'Chuyên Viên Tuyển Dụng (Có Tiếng Anh, Thu Nhập Hấp Dẫn)',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'CÔNG TY CỔ PHẦN TẬP ĐOÀN ĐẦU TƯ VIỆT PHƯƠNG',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hà Nội: Chu Văn An, Yết Kiêu, Hà Đông'],
#    'job_desc': '<div class="content-tab"><p>1. Thực hiện công tác tuyển dụng theo kế hoạch đã được thông qua theo từng tháng và khi công ty có phát sinh nhu cầu nhân sự.\xa0<br>2. Tiến hành tìm kiếm, đề xuất các kênh tuyển dụng hiệu quả để tuyển dụng được những ứng viên chất lượng.\xa0<br>3. Thực hiện việc sàng lọc hồ sơ ứng tuyển, liên hệ với các ứng viên và sắp xếp lịch phỏng vấn và trực tiếp tham gia phỏng vấn.\xa0<br>4. Thông báo kết quả phỏng vấn cho các ứng viên trúng tuyển và gửi thư cảm ơn đối với những ứng viên không đạt.\xa0<br>5. Công tác tiếp đón nhân sự mới (Phối hợp với các bộ phận liên quan)<br>6. Thực hiện các công việc để duy trì và cải tiến hoạt động tuyển dụng nhân sự</br></br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>1. Trình độ học vấn, kiến thức và kinh nghiệm:\xa0<br>- Tốt nghiệp Đại học trở lên, chuyên ngành Quản trị nhân lực và các chuyên ngành liên quan, …<br/>- Kinh nghiệm từ 03 năm ở vị trí nhân viên/chuyên viên tuyển dụng<br/>2. Kỹ năng:\xa0<br/>- Kỹ năng giao tiếp<br/>- Kỹ năng thương lượng, đàm phán<br/>- Kỹ năng đánh giá hành vi ứng viên<br/>- Kỹ năng thu thập và phân tích thông tin<br/>- Kỹ năng làm việc nhóm và làm việc độc lập tốt<br/>- Sử dụng thành thạo tin học văn phòng (MS Office)<br/>- Khả năng sử dụng tiếng Anh thành thạo trong công việc là một lợi thế\xa0<br/>3. Phẩm chất:\xa0<br/>- Nhanh nhẹn, tinh tế, nắm bắt được tâm lý con người<br/>- Trung thực và có đạo đức nghề nghiệp<br/>- Chủ động, trách nhiệm<br/>4. Yêu cầu khác:<br/>- Xác định gắn bó và làm việc lâu dài</br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/can-bo-ky-thuat/1019921.html?ta_source=JobSearchList',
#    'job_title': 'Cán Bộ Kỹ Thuật',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'Công ty Cổ phần đầu tư xuất nhập khẩu TKV',
#    'job_salary': '10 - 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Quảng Ninh: Tổ 1, khu Nam Sơn 1, phường Cẩm Sơn, TP Cẩm Phả'],
#    'job_desc': '<div class="content-tab"><ul><li>Tiếp nhận, xử lý các yêu cầu kỹ thuật của khách hàng về máy công trình, vật tư thiết bị mỏ</li><li>Theo dõi các đơn hàng đang thực hiện</li><li>Xử lý bảo hành sản phẩm, hỗ trợ khách hàng sau bán hàng</li><li>Xử lý thủ tục giao hàng, giao hàng cho khách hàng</li><li>Các công việc khác trao đổi thêm khi phỏng vấn</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Nam từ 23-32</li><li>Có kinh nghiệm làm việc trong lĩnh vực máy công trình, công nghiệp than tối thiểu 1 năm</li><li>Nhanh nhẹn, chăm chỉ, có trách nhiệm với công việc</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/ky-su-co-khi-thi-cong-duong-ong-cong-nghe-bon-be-co-khi/1020108.html?ta_source=JobSearchList',
#    'job_title': 'Kỹ Sư Cơ Khí Thi Công (Đường Ống Công Nghệ, Bồn Bể Cơ Khí)',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'CÔNG TY TNHH MÔI TRƯỜNG CÔNG NGHỆ CÔNG THÀNH',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hồ Chí Minh: Lô C26/1 Đường 2F, KCN Vĩnh Lộc A, Xã Vĩnh Lộc A, Huyện Bình Chánh, TP Hồ Chí Minh, Bình Chánh'],
#    'job_desc': '<div class="content-tab"><p>- Phối hợp phòng thiết kế dự án, triển khai thi công phần đường ống công nghệ, thiết bị cơ khí cho các dự án về hệ thống xử lý nước cấp/nước thải, gas, khí.<br>- Lập,theo dõi, đảm bảo về tiến độ và chất lượng công trình, xây dựng kế hoạch và triển khai biện pháp thi công.<br>- Giám sát các hạng mục thi công dự án đảm bảo đúng theo phương án thiết kế kỹ thuật .<br>- Quản lý giám sát tiến độ thi công các nhà thầu phụ.<br>- Tham gia quản lý, sắp xếp công việc nhân sự thi công, vận hành.<br>- Giải quyết các vấn đề phát sinh về khối lượng, kỹ thuật trong thực tế thi công.<br>- Lập hồ sơ nghiệm thu công trình, hồ sơ hoàn công, hồ sơ trình cơ quan có thẩm quyền xin giấy phép.<br/>- Thay mặt lãnh đạo làm việc trực tiếp với Nhà thầu phụ,Chủ Đầu Tư và cơ quan ban ngành liên quan đến công trình.<br/>- Thực hiện các công việc khác có liên quan theo sự điều động hợp lý từ cấp quản lý trực tiếp.</br></br></br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>- Tốt nghiệp Đại học chuyên ngành Cơ khí chế tạo, thiết kế cơ khí, cơ khí tự động hóa.<br/>- KN 2- 3 năm trở lên, các vị trí Kỹ Sư đường ống, quản lý dự án, giám sát thi công vận hành hệ thống cơ khí (đặc biệt là đường ống, bồn bể cho hệ thống xử lý nước, gas, khí trong các nhà máy công nghiệp hoặc các trạm xử lý)<br/>- Có khả năng lập, đọc hiểu bản vẽ kỹ thuật. Am hiểu tiêu chuẩn kỹ thuật của các loại vật tư, vật liệu, thiết bị, lắp đặt vào công trình.<br/>- Nắm vững quy định pháp luật về xây lắp, đấu thầu công trình.<br/>- Sử dụng thành thạo AutoCad &amp; các phần mềm ứng dụng khác Microsoft Office, Microsoft Project.<br/>- Đi công trình tỉnh thường xuyên theo yêu cầu công việc.\xa0<br/>- Chịu được áp lực công việc, chủ động, chịu khó.<br/>- Trung thực, năng động, nhiệt tình, hòa đồng, tính gắn bó lâu dài với công ty.</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-phu-gia-nganh-nhua/1019782.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh Phụ Gia Ngành Nhựa',
#    'job_deadline': 'Hạn nộp hồ sơ: 15/06/2023',
#    'company_name': 'CÔNG TY TNHH TONGYANG INDUSTRY VIỆT NAM',
#    'job_salary': '12 - 20 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hồ Chí Minh: 101 Bưng Ông Thoàn, phường Phú Hữu, Quận 9',
#     '- Hà Nội: 18A Ngô Tất Tố, phường Văn Miếu, Đống Đa'],
#    'job_desc': '<div class="content-tab"><ul><li>Tìm kiếm các khách hàng trong nước, khai thác và phát triển quan hệ với các khách hàng, đối tác tiềm năng.</li><li>Thực hiện hoạt động chào bán, giới thiệu và tư vấn cho khách hàng về sản phẩm Phụ Gia Kháng khuẩn mà Công ty đang phân phối</li><li>Chăm sóc các mối quan hệ với khách hàng cũ hiện có</li><li>Nhận đơn hàng của khách hàng, làm Báo giá, soan thảo Hợp đồng, quản lý hợp đồng xuất khẩu.</li><li>Giải quyết các công việc phát sinh liên quan đến khách hàng, hoạt động bán hàng.</li><li>Báo cáo định kì tình hình kinh doanh và đề xuất kế hoạch kinh doanh</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Đam mê, yêu thích kinh doanh</li><li>Có khả năng giao tiếp, đàm phán và thuyết phục tốt</li><li>Có khả năng khai thác thông tin, tư duy, sắp xếp trong công việc</li><li>Có trách nhiệm trong công việc</li><li>Sẵn sàng đi công tác theo yêu cầu công việc</li><li>Có ít nhất 01 năm kinh nghiệm/ kỹ năng kinh doanh. Ưu tiên các ứng viên có kinh nghiệm trong ngành Nhựa, Sơn, Hóa Chất, etc.</li><li>Ứng viên cần nộp CV bằng Tiếng Anh.\xa0</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-di-lam-ngay/1019475.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kỹ Thuật (Đi Làm Ngay)',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'Công Ty Cổ Phần B&Q Việt Nam',
#    'job_salary': '7 - 9 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Dưới 1 năm',
#    'job_addresses': ['- Hà Nội: NV1- 3 lô 8, KĐT Gelexia 885 Tam Trinh, Hoàng Mai, Hà Nội, Hoàng Mai'],
#    'job_desc': '<div class="content-tab"><p>- Tiếp nhận, hỗ trợ, tư vấn, xử lý kỹ thuật cho khách hàng trong quá trình sử dụng. (Sản phẩm máy rửa xe)<br>- Bảo hành &amp; sửa chữa các sản phẩm của công ty.<br>- Thực hiện các công việc khác theo chỉ đạo của trưởng phòng.</br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>- Nam giới, dưới 40 tuổi.<br>- Thành thạo tin học văn phòng.<br>- Tốt nghiệp trung cấp trở lên\xa0<br>- Không yêu cầu kinh nghiệm, Ưu tiên sinh viên mới tốt nghiệp.<br>- Chịu khó, kiên trì, yêu thích công việc. Muốn gắn bó lâu dài.</br></br></br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-ky-thuat-san-xuat-ky-thuat-cong-doan/869880.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kỹ Thuật Sản Xuất (Kỹ Thuật Công Đoạn)',
#    'job_deadline': 'Hạn nộp hồ sơ: 31/05/2024',
#    'company_name': 'CÔNG TY TNHH DOOSAN ELECTRO-MATERIALS VIỆT NAM',
#    'job_salary': '10 - 13 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hải Dương: Nhà xưởng Số 3 và nhà xưởng Số 4, Lô NQ, khu công nghiệp Đại An, Km51, Quốc lộ 5, Phường Tứ Minh, Thành phố Hải Dương, tỉnh Hải Dương., TP Hải Dương'],
# ...
#    'job_req': '<div class="content-tab"><p>- Tuổi: 22+</p><p>- Tốt nghiệp Cao đẳng, đại học ưu tiên các ngành: Marketing, Quản Trị Kinh Doanh.</p><p>- Ít nhất 02 năm kinh nghiệm ở vị trí tương đương, thế mạnh: Email MKT, kỹ năng chạy Ads, nghiên cứu thị trường.</p><p>- Ứng viên từng làm trong ngành công nghiệp, kỹ thuật, giải pháp số là 1 lợi thế.</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-ban-hang-ky-thuat-nha-may-du-an/930356.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Bán Hàng Kỹ Thuật Nhà Máy Dự Án',
#    'job_deadline': 'Hạn nộp hồ sơ: 19/05/2023',
#    'company_name': 'ECOZEN INTERNATIONAL JSC',
#    'job_salary': '9 - 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hồ Chí Minh: 41 Thép Mới, Phường 12, Tân Bình'],
#    'job_desc': '<div class="content-tab"><p><strong>- Thời gian làm việc: 08h00 - 17h00 (Thứ 2 - Thứ 6) &amp; 08h00 - 12h00 (Thứ 7)</strong></p><p><strong>1. Tiếp cận KH và giới thiệu sản phẩm</strong><br>- Hiểu rõ về thông tin về sản phẩm, dịch vụ công ty đang kinh doanh<br>- Tìm kiếm và phát triển danh sách khách hàng<br>- Liên hệ và kết nối với khách hàng</br></br></br></p><p><strong>2. Thuyết phục và tư vấn khách hàng, đảm bảo doanh số bán hàng hàng</strong><br>- Lập kế hoạch bán hàng, kế hoạch công tác tuần/ tháng/quý<br>- Theo dõi tình hình và kết quả bán hàng</br></br></p><p><strong>3. Xử lý khiếu nại &amp; chăm sóc khách hàng</strong><br>- Tiếp nhận và xử lý đơn hàng của KH đến khi hoàn tất giao hàng<br/>- Theo dõi xử lý khiếu nại của KH (nếu có).</br></p><p><strong>4. Báo cáo và đề xuất giải pháp, chiến lược kinh doanh để đạt được mục tiêu doanh số</strong></p><p>\xa0</p></div>',
#    'job_req': '<div class="content-tab"><p>- Nam, từ 23 - 36 tuổi.</p><p>- Tốt nghiệp các ngành: Tự động hóa, Cơ điện tử, Nhiệt, Điện - Điện tử , Cơ khí</p><p>- Kinh nghiệm từ 1 năm trở lên trong vị trí bán hàng kỹ thuật, công nghiệp</p><p>- Có kinh nghiệm trong kinh doanh dự án, nhà máy</p><p>- Có kiến thức về thị trường, sản phẩm, khách hàng và các đối thủ cạnh tranh cùng ngành là 01 lợi thế</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/ky-su-kinh-doanh-sales-engineer-can-tho/965118.html?ta_source=JobSearchList',
#    'job_title': 'Kỹ Sư Kinh Doanh/ Sales Engineer (Cần Thơ)',
#    'job_deadline': 'Hạn nộp hồ sơ: 19/05/2023',
#    'company_name': 'ECOZEN INTERNATIONAL JSC',
#    'job_salary': '8 - 12 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Cần Thơ'],
#    'job_desc': '<div class="content-tab"><p>- Thời gian làm việc: 08h00 - 17h00 (Thứ 2 - Thứ 6) &amp; 08h00 - 12h00 (Thứ 7)</p><p><strong>1. Tiếp cận KH và giới thiệu sản phẩm</strong></p><p>- Hiểu rõ về thông tin về sản phẩm, dịch vụ công ty đang kinh doanh</p><p>- Tìm kiếm và phát triển danh sách khách hàng</p><p>- Liên hệ và kết nối với khách hàng</p><p><strong>2. Thuyết phục và tư vấn khách hàng, đảm bảo doanh số bán hàng hàng</strong></p><p>- Lập kế hoạch bán hàng, kế hoạch công tác tuần/ tháng/quý</p><p>- Theo dõi tình hình và kết quả bán hàng</p><p><strong>3. Xử lý khiếu nại &amp; chăm sóc khách hàng</strong></p><p>- Tiếp nhận và xử lý đơn hàng của KH đến khi hoàn tất giao hàng</p><p>- Theo dõi xử lý khiếu nại của KH (nếu có).</p><p><strong>4. Báo cáo và đề xuất giải pháp, chiến lược kinh doanh để đạt được mục tiêu doanh số</strong></p><p>\xa0</p></div>',
#    'job_req': '<div class="content-tab"><p>- Nam, từ 24 - 36 tuổi.<br>- Tốt nghiệp các ngành: Tự động hóa, Cơ điện tử, Nhiệt, Điện - Điện tử , Cơ khí<br>- Kinh nghiệm từ 1 năm trở lên trong vị trí bán hàng kỹ thuật, công nghiệp<br>- Có kinh nghiệm trong kinh doanh dự án, nhà máy<br>- Có kiến thức về thị trường, sản phẩm, khách hàng và các đối thủ cạnh tranh cùng ngành là 01 lợi thế<br>- Kỹ năng khảo sát, thống kê, truyền đạt, thuyết phục, có khả năng làm việc độc lập.<br>- Có tố chất nhạy bén, trách nhiệm, chủ động và trách nhiệm</br></br></br></br></br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-sale-thi-truong-nhot-cong-nghiep-vung-tau-khanh-hoa/997674.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Sale Thị Trường - Nhớt Công Nghiệp - Vũng Tàu/Khánh Hòa',
#    'job_deadline': 'Hạn nộp hồ sơ: 03/06/2023',
#    'company_name': 'Công Ty Cổ Phần Hóa Dầu MEKONG PETRO',
#    'job_salary': 'Tới 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Dưới 1 năm',
#    'job_addresses': ['- Bà Rịa-Vũng Tàu: TP Bà Rịa',
#     '- Bà Rịa-Vũng Tàu: Phú Mỹ',
#     '- Bà Rịa-Vũng Tàu: Châu Đức'],
#    'job_desc': '<div class="content-tab"><ul><li>Bán các sản phẩm dầu nhớt đến các cửa hàng, đại lý, nhà phân phối, tại khu vực được phân công\xa0</li><li>Viếng thăm, lấy đơn hàng tại các cửa hàng trên tuyến có trên hệ thống DMS\xa0</li><li>Giới thiệu các chương trình khuyến mãi đến KH</li><li>Phát triển thêm các điểm bán hàng mới</li><li>Quản lý và thu hồi công nợ.</li><li>Báo cáo định kỳ đến cấp trên</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>Nam từ 23 đến 35 tuổi;</li><li>Kinh nghiệm: Từ 6 tháng - 1 năm bán hàng thị trường, chưa có kinh nghiệm được đào tạo;</li><li>Trung thực, chịu khó ( công việc di chuyển nhiều); Sức khỏe tốt</li><li>Có xe máy</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/thuc-tap-sinh-kinh-doanh-tai-tien-giang-khanh-hoa-ho-tro-phu-cap-dau-moc-do/997506.html?ta_source=JobSearchList',
#    'job_title': 'Thực Tập Sinh Kinh Doanh - Tại Tiền Giang/ Khánh Hòa (Hỗ Trợ Phụ Cấp + Dấu Mộc Đỏ)',
#    'job_deadline': 'Hạn nộp hồ sơ: 07/06/2023',
#    'company_name': 'CÔNG TY CỔ PHẦN DNP HOLDING',
#    'job_salary': '3 - 6 triệu',
#    'job_type': 'Thực tập',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Khánh Hoà: Các Khu Vực Tỉnh Khánh Hòa , Nha Trang, TP Nha Trang',
#     '- Tiền Giang: Các Khu Vực tỉnh Tiền Giang, TP Mỹ Tho'],
#    'job_desc': '<div class="content-tab"><p>Chăm sóc khách hàng cũ.</p><p>\xa0Tìm kiếm khách hàng mới.\xa0</p><p>Tư vấn và đưa sản phẩm của công ty tới tay nhà phân phối và khách hàng.</p></div>',
#    'job_req': '<div class="content-tab"><p>Có khả năng giao tiếp tốt, tự tin, nhanh nhẹn<br>Có mong muốn phát triển sự nghiệp theo hướng nhân viên kinh doanh<br>Sinh viên năm cuối hoặc mới tốt nghiệp các trường thuộc khối kinh tế. (ngành quản trị kinh doanh, cấp thoát nước....)</br></br></p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-frontend-developer-vuejs/841089.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Frontend Developer Vuejs',
#    'job_deadline': 'Hạn nộp hồ sơ: 31/05/2023',
#    'company_name': 'CÔNG TY TNHH TRUYỀN THÔNG VÀ DỊCH VỤ DU LỊCH CẢM XÚC VIỆT',
#    'job_salary': '20 - 50 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hà Nội: Số 18/599 Phạm Văn Đồng, Phường Cổ Nhuế 1, Quận Bắc Từ Liêm, Thành Phố Hà Nội, Việt Nam, Bắc Từ Liêm'],
#    'job_desc': '<div class="content-tab"><p>Job Description<br>You will work with us to build websites with millions of views per month for well-known brands around the world.<br>Your main responsibilities include:<br>Turn designs into responsive, functional, and accessible HTML / CSS / JavaScript code.<br>Learn and ensure best practices in terms of accessibility, performance, and code standard.<br>Work closely with the team leader and project manager to ensure your projects are on track.<br>Work with technical lead to research and stay on top of front-end web development best practices.</br></br></br></br></br></br></p></div>',
#    'job_req': '<div class="content-tab"><p>3+ years of experiences<br/>English (reading comprehension level at least).<br/>Can write SEO-friendly, semantic HTML5 code.<br/>Experienced with CSS3 using Flexbox, Grid, Transforms, Animation.<br/>Experienced with native Javascript ES5 &amp; ES6 (without jQuery).<br/>Basic understanding of Vue.js or React.<br/>Basic knowledge of code versioning tools such as Git with GitHub or GitLab or BitBucket.<br/>Must have work samples - Demo projects, GitHub, Code snippets, etc<br/><br/>The following skills are NOT REQUIRED:\xa0<br/>If you don’t have these skills yet, don’t worry, you’ll get trained on the job. But if you do have some of these skills, they will be huge bonus points:\xa0<br/>Sass, Less or postCSS.<br/>JavaScript ES7/8/9<br/>Gulp / Grunt / Webpack / Babel.<br/>WordPress and PHP.<br/>Shopify and Liquid.</p><ul><li>Chỉ lấy các bạn 1996 đến 1988.</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/giam-sat-san-xuat/994902.html?ta_source=JobSearchList',
#    'job_title': 'Giám Sát Sản Xuất',
#    'job_deadline': 'Hạn nộp hồ sơ: 31/05/2023',
#    'company_name': 'Công ty TNHH Panasonic Appliances Việt Nam',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '3 năm',
#    'job_addresses': ['- Hà Nội: Lô B-6, KCN Thăng Long, X.Võng La, H. Đông Anh, Tp. Hà Nội, Đông Anh'],
#    'job_desc': '<div class="content-tab"><p>- Responsibility in all ISO documents of Production Department</p><p>- Make monthly report: man-time, machine-time, KPI, Manufacturing cost</p><p>- Responsibility in Safety activities of Production Department</p><p>- Handle training system &amp; worker skill map of Production Department (apply digitalization)</p><p>- Create &amp; Proceed CR Idea in process</p><p>- Responsibility for Paper less project</p><p>- Improve production to increase productivity</p><p>- Other tasks assigned by Manager</p></div>',
#    'job_req': '<div class="content-tab"><p>- University degree, major in technical field</p><p>- Have from 3-4 years of experience in production management</p><p>- Intermediate English skills, knowing Japanese is an advantage</p><p>- Good command of Microsoft Office</p><p>- Hardworking, agile and able to work under high pressure</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-kenh-gt/864171.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh (Kênh Gt)',
#    'job_deadline': 'Hạn nộp hồ sơ: 20/05/2023',
#    'company_name': 'CTY TNHH TM SX ĐT NHÔM AN LẬP PHÁT',
#    'job_salary': '8 - 15 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hồ Chí Minh', '- Bình Dương', '- Đồng Nai'],
#    'job_desc': '<div class="content-tab"><p>Với thị trường đang mở rộng, Công ty cần tuyển nhân viên Kinh doanh<br>- 1 bạn phụ trách 2 tỉnh: Bình Dương, Đồng Nai<br>- 1 bạn phụ trách Hồ Chí Minh</br></br></p><p>Công việc:</p><ul><li>Chăm sóc và mở rộng thị trường tại khu vực mình quản lý;</li><li>Tìm kiếm khách hàng mới, xây dựng mối quan hệ thân thiết với khách hàng.</li><li>Tư vấn cho khách hàng về sản phẩm Công ty, cập nhật và triển khai các chương trình bán hàng, khuyến mãi đến các đại lý</li><li>Theo dõi công nợ, giải quyết kịp thời các khó khăn khi khách hàng cần.</li><li>Phân tích, nắm rõ tình hình thị trường và đối thủ cạnh tranh</li><li>Các công việc khác liên quan do quản lý phân công.</li></ul></div>',
#    'job_req': '<div class="content-tab"><ul><li>1 năm kinh nghiệm làm tại vị trí nhân viên kinh doanh thị trường trở lên.</li><li>Có kinh nghiệm làm chăm sóc khách hàng, đi thị trường hoặc hiểu về sản phẩm công nghiệp là lợi thế.</li><li>Chăm chỉ, nhanh nhẹn, cầu tiến, năng lực tư duy và xử lý tình huống tốt</li><li>Kỹ năng giao tiếp tốt.</li><li>Đam mê lĩnh vực kinh doanh kênh thị trường.</li></ul></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-ke-toan-tong-hop/827916.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kế Toán Tổng Hợp',
#    'job_deadline': 'Hạn nộp hồ sơ: 10/06/2023',
#    'company_name': 'CÔNG TY TNHH LOGISTICS AMG VIỆT NAM',
#    'job_salary': 'Trên 8 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hà Nội: Nhà 15, Đường 1, Sunrise A, The Manor Central Park, Đường Nguyễn xiển, Hoàng Mai'],
#    'job_desc': '<div class="content-tab"><p>- Tập hợp các hóa đơn, chứng từ phát sinh cũng như hạch toán và ghi sổ sách các nghiệp vụ phát sinh hàng ngày</p><p>- Theo dõi công nợ với khách hàng, công nợ với nhà cung cấp</p><p>- Lập báo cáo tài chính định kỳ theo quy định</p><p>- Kiểm tra sự cân đối giữa số liệu kế toán chi tiết và tổng hợp</p><p>- Thực hiện cung cấp hồ sơ, số liệu cho cơ quan thuế, kiểm toán, thanh tra kiểm tra theo yêu cầu của cấp trên</p><p>- Thực hiện các nhiệm vụ khác theo yêu cầu của Cấp quản lý</p></div>',
#    'job_req': '<div class="content-tab"><p>. Sử dụng excel thành thạo (bắt buộc )\n</p><p>. Độ tuổi từ 1990-1999\n</p><p>· Biết sử dụng phầm mềm Misa/Fast\n</p><p>· Từng có kinh nghiệm làm về thuế các giấy tờ liên quan ( ít nhất 1 năm )\n</p><p>· Xử lý tình huống tốt, luôn bám sát công việc\n</p><p>· Hòa đồng, nhẫn nại, kiên trì, cẩn thận, tỉ mỉ, trung thực, bảo mật\n</p><p>· Có kinh nghiệm kế toán về sản xuất xuất nhập khẩu là một lợi thế.\n</p><p>. Được đào tạo thêm nghiệp vụ với Kế toán trưởng</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-telesales-part-time/760302.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Telesales (Part-Time)',
#    'job_deadline': 'Hạn nộp hồ sơ: 16/06/2023',
#    'company_name': 'Công ty TNHH Thiết bị Công nghiệp và Giáo dục Tân Tiến',
#    'job_salary': 'Thoả thuận',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': '1 năm',
#    'job_addresses': ['- Hà Nội: HongKong Tower, 243A Đê La Thành, Phường Láng Thượng, Đống Đa'],
#    'job_desc': '<div class="content-tab"><p>-\tTìm hiểu và nắm bắt tất cả các thông tin liên quan đến sản phẩm/ dịch vụ của công ty (thiết bị đo lường chính xác: Optical 3D Scanners, Multisensor Measuring Machines, CT Scanners…máy in 3D, phần mềm công nghệ 3D,…)\n</p><p>-\tGọi điện thoại cho khách hàng để giới thiệu sản phẩm, khai thác nhu cầu, thông tin.\n</p><p>-\tTiếp nhận và giải quyết các thắc mắc, khiếu nại của khách hàng liên quan tới sản phẩm, dịch vụ\n</p><p>-\tChăm sóc khách hàng sau khi bán hàng, duy trì mối quan hệ với khách hàng hiện tại\n</p><p>-\tTiến hành báo cáo với cấp trên tiến độ công việc và các kết quả đạt được</p></div>',
#    'job_req': '<div class="content-tab"><p>-\tTuổi: 22 – 35\n</p><p>-\tTối thiểu 1 năm kinh nghiệm ở vị trí telesales. Ưu tiên có kinh nghiệm trong lĩnh vực sản xuất công nghiệp, công nghệ 3D,...</p><p>-\tCó kỹ năng giao tiếp qua điện thoại, kỹ năng khai thác thông tin khách hàng\n</p><p>-\tĐam mê kinh doanh, có định hướng rõ ràng theo ngành telesales</p></div>'},
#   {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-thu-nhap-len-den-30-trieu/865073.html?ta_source=JobSearchList',
#    'job_title': 'Nhân Viên Kinh Doanh (Thu Nhập Lên Đến 30 Triệu)',
#    'job_deadline': 'Hạn nộp hồ sơ: 17/06/2023',
#    'company_name': 'Công ty Cổ phần Công nghệ Đánh bóng Kim loại Leka',
#    'job_salary': '15 - 30 triệu',
#    'job_type': 'Toàn thời gian',
#    'job_yoe': 'Không yêu cầu kinh nghiệm',
#    'job_addresses': ['- Bình Dương: Đường D7, KCN Nam Tân Uyên, Khánh Bình, Tân Uyên'],
#    'job_desc': '<div class="content-tab"><p>- Khai thác, mở rộng, thiết lập khách hàng theo kênh bán hàng đảm trách.</p><p>- Vai trò đại diện thương hiệu Công ty giao dịch với khách hàng bằng việc cung cấp giải pháp, công nghệ, sản phẩm, dịch vụ...</p><p>- Thực hiện trực tiếp hoạt động bán hàng, triển khai các chương trình xúc tiến thương mại theo kế hoạch, định hướng của Công ty.</p><p>- Duy trì, phát triển mối quan hệ bền vững với từng đối tượng khách hàng phụ trách bằng các phương pháp cụ thể, khác nhau.</p><p>- Xây dựng kế hoạch kinh doanh tháng/quý/năm dựa trên các chiến lược kinh doanh ngắn/trung/dài hạn.</p></div>',
#    'job_req': '<div class="content-tab"><p>- Nam, tuổi từ 24 trở lên;<br>- Yêu thích kinh doanh và kiếm tiền. Chưa có kinh nghiệm nhưng có tố chất kinh doanh, yêu thích tiếp xúc khách hàng, đam mê phát triển mối quan hệ bán hàng thì sẽ được đào tạo.<br>- Có kinh nghiệm khách hàng B2B là một lợi thế.</br></br></p><p>- Có bằng lái xe ô tô là 1 lợi thế.</p></div>'}]}

# %% [markdown]
# Collecting 'Phi chính phủ / Phi lợi nhuận'

# %%
ngo_raw, exc_urls_ngo = get_jobs_by_industry('Phi chính phủ / Phi lợi nhuận', '/tim-viec-lam-phi-chinh-phu-phi-loi-nhuan-c10124',
                                            save_name='ngo')
save_json(exc_urls_ngo, 'exc_urls_ngo')
# Out:
# Collecting industry:  Phi chính phủ / Phi lợi nhuận
# Total page:  1
# https://www.topcv.vn/tim-viec-lam-phi-chinh-phu-phi-loi-nhuan-c10124?page=1
# Finished page 1 / 1
# ----------------Saved all Phi chính phủ / Phi lợi nhuận records.----------------

# %% [markdown]
# Collecting 'Địa chất / Khoáng sản'

# %%
dcks_raw, exc_urls_dcks = get_jobs_by_industry('Địa chất / Khoáng sản', '/tim-viec-lam-dia-chat-khoang-san-c10111',
                                            save_name='dcks')
save_json(exc_urls_dcks, 'exc_urls_dcks')
# Out:
# Collecting industry:  Địa chất / Khoáng sản
# Total page:  2
# https://www.topcv.vn/tim-viec-lam-dia-chat-khoang-san-c10111?page=1
# Finished page 1 / 2
# https://www.topcv.vn/tim-viec-lam-dia-chat-khoang-san-c10111?page=2
# Finished page 2 / 2
# ----------------Saved all Địa chất / Khoáng sản records.----------------

# %% [markdown]
# Collecting 'NGO / Phi chính phủ / Phi lợi nhuận'

# %%
ngo2_raw, exc_urls_ngo2 = get_jobs_by_industry('NGO / Phi chính phủ / Phi lợi nhuận', '/tim-viec-lam-ngo-phi-chinh-phu-phi-loi-nhuan-c10132',
                                            save_name='ngo2')
save_json(exc_urls_ngo2, 'exc_urls_ngo2')
# Out:
# Collecting industry:  NGO / Phi chính phủ / Phi lợi nhuận
# Total page:  1
# https://www.topcv.vn/tim-viec-lam-ngo-phi-chinh-phu-phi-loi-nhuan-c10132?page=1
# Finished page 1 / 1
# ----------------Saved all NGO / Phi chính phủ / Phi lợi nhuận records.----------------

# %% [markdown]
# Collecting 'Hàng không'

# %%
hangkhong_raw, exc_urls_hangkhong = get_jobs_by_industry('Hàng không', '/tim-viec-lam-hang-khong-c10022',
                                            save_name=None)
save_json(exc_urls_hangkhong, 'exc_urls_hangkhong')
# Out:
# Collecting industry:  Hàng không
# Total page:  3
# https://www.topcv.vn/tim-viec-lam-hang-khong-c10022?page=1
# Finished page 1 / 3
# https://www.topcv.vn/tim-viec-lam-hang-khong-c10022?page=2
# Finished page 2 / 3
# https://www.topcv.vn/tim-viec-lam-hang-khong-c10022?page=3
# Finished page 3 / 3
# ----------------Saved all Hàng không records.----------------

# %% [markdown]
# Collecting 'In ấn / Xuất bản'

# %%
inanxb_raw, exc_urls_inanxb = get_jobs_by_industry('In ấn / Xuất bản', '/tim-viec-lam-in-an-xuat-ban-c10024',
                                            save_name='printing')
save_json(exc_urls_inanxb, 'exc_urls_printing')
# Out:
# Collecting industry:  In ấn / Xuất bản
# Total page:  6
# https://www.topcv.vn/tim-viec-lam-in-an-xuat-ban-c10024?page=1
# Finished page 1 / 6
# https://www.topcv.vn/tim-viec-lam-in-an-xuat-ban-c10024?page=2
# Finished page 2 / 6
# https://www.topcv.vn/tim-viec-lam-in-an-xuat-ban-c10024?page=3
# Finished page 3 / 6
# https://www.topcv.vn/tim-viec-lam-in-an-xuat-ban-c10024?page=4
# Finished page 4 / 6
# https://www.topcv.vn/tim-viec-lam-in-an-xuat-ban-c10024?page=5
# Finished page 5 / 6
# https://www.topcv.vn/tim-viec-lam-in-an-xuat-ban-c10024?page=6
# Finished page 6 / 6
# ----------------Saved all In ấn / Xuất bản records.----------------

# %%
missed_industries = []
for i in range(0, 60):
    industry = industries[i]
    job_count = int(industry['job_category_count'].replace('.',''))
    if job_count > 1000:
        continue
    try:
        js_raw, exc_urls_i = get_jobs_by_industry(industry_name=industry['name'],
                                                industry_url=industry['access_url'],
                                                 save_name=str(i))
        save_json(exc_urls_i, f'exc_urls_{i}')
    except Exception as e:
        print(e, '-', i)
        missed_industries.append(i)
# Out:
# Collecting industry:  Vận tải / Kho vận
# Total page:  37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=1
# Finished page 1 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=2
# Finished page 2 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=3
# Finished page 3 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=4
# Finished page 4 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=5
# Finished page 5 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=6
# Finished page 6 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=7
# Finished page 7 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=8
# Finished page 8 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=9
# Finished page 9 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=10
# Finished page 10 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=11
# Finished page 11 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=12
# Finished page 12 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=13
# Finished page 13 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=14
# Finished page 14 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=15
# Finished page 15 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=16
# Finished page 16 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=17
# Finished page 17 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=18
# Finished page 18 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=19
# Finished page 19 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=20
# Finished page 20 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=21
# Finished page 21 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=22
# Finished page 22 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=23
# Finished page 23 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=24
# Finished page 24 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=25
# Finished page 25 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=26
# Finished page 26 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=27
# Finished page 27 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=28
# Finished page 28 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=29
# Finished page 29 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=30
# Finished page 30 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=31
# Finished page 31 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=32
# Finished page 32 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=33
# Finished page 33 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=34
# Finished page 34 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=35
# Finished page 35 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=36
# Finished page 36 / 37
# https://www.topcv.vn/tim-viec-lam-van-tai-kho-van-c10047?page=37
# Finished page 37 / 37
# ----------------Saved all Vận tải / Kho vận records.----------------
# Collecting industry:  Quản lý chất lượng (QA/QC)
# Total page:  24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=1
# Finished page 1 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=2
# Finished page 2 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=3
# Finished page 3 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=4
# Finished page 4 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=5
# Finished page 5 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=6
# Finished page 6 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=7
# Finished page 7 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=8
# Finished page 8 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=9
# Finished page 9 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=10
# Finished page 10 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=11
# Finished page 11 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=12
# Finished page 12 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=13
# Finished page 13 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=14
# Finished page 14 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=15
# Finished page 15 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=16
# Finished page 16 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=17
# Finished page 17 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=18
# Finished page 18 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=19
# Finished page 19 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=20
# Finished page 20 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=21
# Finished page 21 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=22
# Finished page 22 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=23
# Finished page 23 / 24
# https://www.topcv.vn/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037?page=24
# Finished page 24 / 24
# ----------------Saved all Quản lý chất lượng (QA/QC) records.----------------
# Collecting industry:  Thư ký / Trợ lý
# Total page:  28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=1
# Finished page 1 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=2
# Finished page 2 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=3
# Finished page 3 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=4
# Finished page 4 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=5
# Finished page 5 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=6
# Finished page 6 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=7
# Finished page 7 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=8
# Finished page 8 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=9
# Finished page 9 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=10
# Finished page 10 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=11
# Finished page 11 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=12
# Finished page 12 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=13
# Finished page 13 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=14
# Finished page 14 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=15
# Finished page 15 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=16
# Finished page 16 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=17
# Finished page 17 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=18
# Finished page 18 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=19
# Finished page 19 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=20
# Finished page 20 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=21
# Finished page 21 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=22
# Finished page 22 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=23
# Finished page 23 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=24
# Finished page 24 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=25
# Finished page 25 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=26
# Finished page 26 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=27
# Finished page 27 / 28
# https://www.topcv.vn/tim-viec-lam-thu-ky-tro-ly-c10129?page=28
# Finished page 28 / 28
# ----------------Saved all Thư ký / Trợ lý records.----------------
# Collecting industry:  Thời trang
# Total page:  35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=1
# Finished page 1 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=2
# Finished page 2 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=3
# Finished page 3 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=4
# Finished page 4 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=5
# Finished page 5 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=6
# Finished page 6 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=7
# Finished page 7 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=8
# Finished page 8 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=9
# Finished page 9 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=10
# Finished page 10 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=11
# Finished page 11 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=12
# Finished page 12 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=13
# Finished page 13 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=14
# Finished page 14 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=15
# Finished page 15 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=16
# Finished page 16 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=17
# Finished page 17 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=18
# Finished page 18 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=19
# Finished page 19 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=20
# Finished page 20 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=21
# Finished page 21 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=22
# Finished page 22 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=23
# Finished page 23 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=24
# Finished page 24 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=25
# Finished page 25 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=26
# Finished page 26 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=27
# Finished page 27 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=28
# Finished page 28 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=29
# Finished page 29 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=30
# Finished page 30 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=31
# Finished page 31 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=32
# Finished page 32 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=33
# Finished page 33 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=34
# Finished page 34 / 35
# https://www.topcv.vn/tim-viec-lam-thoi-trang-c10042?page=35
# Finished page 35 / 35
# ----------------Saved all Thời trang records.----------------
# Collecting industry:  Tổ chức sự kiện / Quà tặng
# Total page:  15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=1
# Finished page 1 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=2
# Finished page 2 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=3
# Finished page 3 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=4
# Finished page 4 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=5
# Finished page 5 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=6
# Finished page 6 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=7
# Finished page 7 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=8
# Finished page 8 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=9
# Finished page 9 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=10
# Finished page 10 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=11
# Finished page 11 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=12
# Finished page 12 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=13
# Finished page 13 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=14
# Finished page 14 / 15
# https://www.topcv.vn/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046?page=15
# Finished page 15 / 15
# ----------------Saved all Tổ chức sự kiện / Quà tặng records.----------------
# Collecting industry:  Thực phẩm / Đồ uống
# Total page:  39
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11052\758740752.py in <module>
#       6         continue
#       7     try:
# ----> 8         js_raw, exc_urls_i = get_jobs_by_industry(industry_name=industry['name'],
#       9                                                 industry_url=industry['access_url'],
#      10                                                  save_name=str(i))
#
# ~\AppData\Local\Temp\ipykernel_11052\777003919.py in get_jobs_by_industry(industry_name, industry_url, max_count, save_name)
#      32                 job_dict['url'] = job_url
#      33                 resp1 = requests.get(job_url)
# ---> 34                 jb_bs = BeautifulSoup(resp1.text, 'html.parser')
#      35                 job_header = jb_bs.find('div',{'class':'box-detail-job'}).find('div',{'class':'box-header'})
#      36                 company_name = job_header.find('a',{'class':'company-logo'}).get('title')
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331             self.builder.initialize_soup(self)
#     332             try:
# --> 333                 self._feed()
#     334                 success = True
#     335                 break
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     449         self.builder.reset()
#     450
# --> 451         self.builder.feed(self.markup)
#     452         # Close out any unfinished strings and close all the open tags.
#     453         self.endData()
#
# ~\anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     397         parser.soup = self.soup
#     398         try:
# --> 399             parser.feed(markup)
#     400             parser.close()
#     401         except HTMLParseError as e:
#
# ~\anaconda3\lib\html\parser.py in feed(self, data)
#     108         """
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#     112     def close(self):
#
# ~\anaconda3\lib\html\parser.py in goahead(self, end)
#     168             if startswith('<', i):
#     169                 if starttagopen.match(rawdata, i): # < + letter
# --> 170                     k = self.parse_starttag(i)
#     171                 elif startswith("</", i):
#     172                     k = self.parse_endtag(i)
#
# ~\anaconda3\lib\html\parser.py in parse_starttag(self, i)
#     342             self.handle_startendtag(tag, attrs)
#     343         else:
# --> 344             self.handle_starttag(tag, attrs)
#     345             if tag in self.CDATA_CONTENT_ELEMENTS:
#     346                 self.set_cdata_mode(tag)
#
# ~\anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     152         #print("START", name)
#     153         sourceline, sourcepos = self.getpos()
# --> 154         tag = self.soup.handle_starttag(
#     155             name, None, None, attr_dict, sourceline=sourceline,
#     156             sourcepos=sourcepos
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     719             return None
#     720
# --> 721         tag = self.element_classes.get(Tag, Tag)(
#     722             self, self.builder, name, namespace, nsprefix, attrs,
#     723             self.currentTag, self._most_recent_element,
#
# KeyboardInterrupt:

# %% [markdown]
# Saved at Tổ chức sự kiện / Quà tặng records
#
# Index 14

# %%
missed_industries = []
for i in range(15, 60):
    industry = industries[i]
    job_count = int(industry['job_category_count'].replace('.',''))
    if job_count > 1000:
        continue
    try:
        js_raw, exc_urls_i = get_jobs_by_industry(industry_name=industry['name'],
                                                industry_url=industry['access_url'],
                                                 save_name=str(i))
        save_json(exc_urls_i, f'exc_urls_{i}')
    except Exception as e:
        print(e, '-', i)
        missed_industries.append(i)
# Out:
# Collecting industry:  Thực phẩm / Đồ uống
# Total page:  38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=1
# Finished page 1 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=2
# Finished page 2 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=3
# Finished page 3 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=4
# Finished page 4 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=5
# Finished page 5 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=6
# Finished page 6 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=7
# Finished page 7 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=8
# Finished page 8 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=9
# Finished page 9 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=10
# Finished page 10 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=11
# Finished page 11 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=12
# Finished page 12 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=13
# Finished page 13 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=14
# Finished page 14 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=15
# Finished page 15 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=16
# Finished page 16 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=17
# Finished page 17 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=18
# Finished page 18 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=19
# Finished page 19 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=20
# Finished page 20 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=21
# Finished page 21 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=22
# Finished page 22 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=23
# Finished page 23 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=24
# Finished page 24 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=25
# Finished page 25 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=26
# Finished page 26 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=27
# Finished page 27 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=28
# Finished page 28 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=29
# Finished page 29 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=30
# Finished page 30 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=31
# Finished page 31 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=32
# Finished page 32 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=33
# Finished page 33 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=34
# Finished page 34 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=35
# Finished page 35 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=36
# Finished page 36 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=37
# Finished page 37 / 38
# https://www.topcv.vn/tim-viec-lam-thuc-pham-do-uong-c10043?page=38
# Finished page 38 / 38
# ----------------Saved all Thực phẩm / Đồ uống records.----------------
# Collecting industry:  Luật/Pháp lý
# Total page:  19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=1
# Finished page 1 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=2
# Finished page 2 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=3
# Finished page 3 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=4
# Finished page 4 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=5
# Finished page 5 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=6
# Finished page 6 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=7
# Finished page 7 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=8
# Finished page 8 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=9
# Finished page 9 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=10
# Finished page 10 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=11
# Finished page 11 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=12
# Finished page 12 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=13
# Finished page 13 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=14
# Finished page 14 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=15
# Finished page 15 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=16
# Finished page 16 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=17
# Finished page 17 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=18
# Finished page 18 / 19
# https://www.topcv.vn/tim-viec-lam-luat-phap-ly-c10036?page=19
# Finished page 19 / 19
# ----------------Saved all Luật/Pháp lý records.----------------
# Collecting industry:  Điện tử viễn thông
# Total page:  23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=1
# Finished page 1 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=2
# Finished page 2 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=3
# Finished page 3 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=4
# Finished page 4 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=5
# Finished page 5 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=6
# Finished page 6 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=7
# Finished page 7 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=8
# Finished page 8 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=9
# Finished page 9 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=10
# Finished page 10 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=11
# Finished page 11 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=12
# Finished page 12 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=13
# Finished page 13 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=14
# Finished page 14 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=15
# Finished page 15 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=16
# Finished page 16 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=17
# Finished page 17 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=18
# Finished page 18 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=19
# Finished page 19 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=20
# Finished page 20 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=21
# Finished page 21 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=22
# Finished page 22 / 23
# https://www.topcv.vn/tim-viec-lam-dien-tu-vien-thong-c10015?page=23
# Finished page 23 / 23
# ----------------Saved all Điện tử viễn thông records.----------------
# Collecting industry:  Xuất nhập khẩu
# Total page:  37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=1
# Finished page 1 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=2
# Finished page 2 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=3
# Finished page 3 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=4
# Finished page 4 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=5
# Finished page 5 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=6
# Finished page 6 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=7
# Finished page 7 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=8
# Finished page 8 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=9
# Finished page 9 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=10
# Finished page 10 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=11
# Finished page 11 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=12
# Finished page 12 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=13
# Finished page 13 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=14
# Finished page 14 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=15
# Finished page 15 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=16
# Finished page 16 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=17
# Finished page 17 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=18
# Finished page 18 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=19
# Finished page 19 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=20
# Finished page 20 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=21
# Finished page 21 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=22
# Finished page 22 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=23
# Finished page 23 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=24
# Finished page 24 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=25
# Finished page 25 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=26
# Finished page 26 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=27
# Finished page 27 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=28
# Finished page 28 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=29
# Finished page 29 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=30
# Finished page 30 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=31
# Finished page 31 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=32
# Finished page 32 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=33
# Finished page 33 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=34
# Finished page 34 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=35
# Finished page 35 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=36
# Finished page 36 / 37
# https://www.topcv.vn/tim-viec-lam-xuat-nhap-khau-c10049?page=37
# Finished page 37 / 37
# ----------------Saved all Xuất nhập khẩu records.----------------
# Collecting industry:  Du lịch
# Total page:  28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=1
# Finished page 1 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=2
# Finished page 2 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=3
# Finished page 3 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=4
# Finished page 4 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=5
# Finished page 5 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=6
# Finished page 6 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=7
# Finished page 7 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=8
# Finished page 8 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=9
# Finished page 9 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=10
# Finished page 10 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=11
# Finished page 11 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=12
# Finished page 12 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=13
# Finished page 13 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=14
# Finished page 14 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=15
# Finished page 15 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=16
# Finished page 16 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=17
# Finished page 17 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=18
# Finished page 18 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=19
# Finished page 19 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=20
# Finished page 20 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=21
# Finished page 21 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=22
# Finished page 22 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=23
# Finished page 23 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=24
# Finished page 24 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=25
# Finished page 25 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=26
# Finished page 26 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=27
# Finished page 27 / 28
# https://www.topcv.vn/tim-viec-lam-du-lich-c10011?page=28
# Finished page 28 / 28
# ----------------Saved all Du lịch records.----------------
# Collecting industry:  Chứng khoán / Vàng / Ngoại tệ
# Total page:  15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=1
# Finished page 1 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=2
# Finished page 2 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=3
# Finished page 3 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=4
# Finished page 4 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=5
# Finished page 5 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=6
# Finished page 6 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=7
# Finished page 7 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=8
# Finished page 8 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=9
# Finished page 9 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=10
# Finished page 10 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=11
# Finished page 11 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=12
# Finished page 12 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=13
# Finished page 13 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=14
# Finished page 14 / 15
# https://www.topcv.vn/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008?page=15
# Finished page 15 / 15
# ----------------Saved all Chứng khoán / Vàng / Ngoại tệ records.----------------
# Collecting industry:  Hoạch định/Dự án
# Total page:  12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=1
# Finished page 1 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=2
# Finished page 2 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=3
# Finished page 3 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=4
# Finished page 4 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=5
# Finished page 5 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=6
# Finished page 6 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=7
# Finished page 7 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=8
# Finished page 8 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=9
# Finished page 9 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=10
# Finished page 10 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=11
# Finished page 11 / 12
# https://www.topcv.vn/tim-viec-lam-hoach-dinh-du-an-c10019?page=12
# Finished page 12 / 12
# ----------------Saved all Hoạch định/Dự án records.----------------
# Collecting industry:  Công nghệ Ô tô
# Total page:  13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=1
# Finished page 1 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=2
# Finished page 2 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=3
# Finished page 3 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=4
# Finished page 4 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=5
# Finished page 5 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=6
# Finished page 6 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=7
# Finished page 7 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=8
# Finished page 8 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=9
# Finished page 9 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=10
# Finished page 10 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=11
# Finished page 11 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=12
# Finished page 12 / 13
# https://www.topcv.vn/tim-viec-lam-cong-nghe-o-to-c10052?page=13
# Finished page 13 / 13
# ----------------Saved all Công nghệ Ô tô records.----------------
# Collecting industry:  Mỹ phẩm / Trang sức
# Total page:  21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=1
# Finished page 1 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=2
# Finished page 2 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=3
# Finished page 3 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=4
# Finished page 4 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=5
# Finished page 5 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=6
# Finished page 6 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=7
# Finished page 7 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=8
# Finished page 8 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=9
# Finished page 9 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=10
# Finished page 10 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=11
# Finished page 11 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=12
# Finished page 12 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=13
# Finished page 13 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=14
# Finished page 14 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=15
# Finished page 15 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=16
# Finished page 16 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=17
# Finished page 17 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=18
# Finished page 18 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=19
# Finished page 19 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=20
# Finished page 20 / 21
# https://www.topcv.vn/tim-viec-lam-my-pham-trang-suc-c10031?page=21
# Finished page 21 / 21
# ----------------Saved all Mỹ phẩm / Trang sức records.----------------
# Collecting industry:  Kiến trúc
# Total page:  19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=1
# Finished page 1 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=2
# Finished page 2 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=3
# Finished page 3 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=4
# Finished page 4 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=5
# Finished page 5 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=6
# Finished page 6 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=7
# Finished page 7 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=8
# Finished page 8 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=9
# Finished page 9 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=10
# Finished page 10 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=11
# Finished page 11 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=12
# Finished page 12 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=13
# Finished page 13 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=14
# Finished page 14 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=15
# Finished page 15 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=16
# Finished page 16 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=17
# Finished page 17 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=18
# Finished page 18 / 19
# https://www.topcv.vn/tim-viec-lam-kien-truc-c10120?page=19
# Finished page 19 / 19
# ----------------Saved all Kiến trúc records.----------------
# Collecting industry:  Thiết kế nội thất
# Total page:  23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=1
# Finished page 1 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=2
# Finished page 2 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=3
# Finished page 3 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=4
# Finished page 4 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=5
# Finished page 5 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=6
# Finished page 6 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=7
# Finished page 7 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=8
# Finished page 8 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=9
# Finished page 9 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=10
# Finished page 10 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=11
# Finished page 11 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=12
# Finished page 12 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=13
# Finished page 13 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=14
# Finished page 14 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=15
# Finished page 15 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=16
# Finished page 16 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=17
# Finished page 17 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=18
# Finished page 18 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=19
# Finished page 19 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=20
# Finished page 20 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=21
# Finished page 21 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=22
# Finished page 22 / 23
# https://www.topcv.vn/tim-viec-lam-thiet-ke-noi-that-c10128?page=23
# Finished page 23 / 23
# ----------------Saved all Thiết kế nội thất records.----------------
# Collecting industry:  Sản xuất
# Total page:  33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=1
# Finished page 1 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=2
# Finished page 2 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=3
# Finished page 3 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=4
# Finished page 4 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=5
# Finished page 5 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=6
# Finished page 6 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=7
# Finished page 7 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=8
# Finished page 8 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=9
# Finished page 9 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=10
# Finished page 10 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=11
# Finished page 11 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=12
# Finished page 12 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=13
# Finished page 13 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=14
# Finished page 14 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=15
# Finished page 15 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=16
# Finished page 16 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=17
# Finished page 17 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=18
# Finished page 18 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=19
# Finished page 19 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=20
# Finished page 20 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=21
# Finished page 21 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=22
# Finished page 22 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=23
# Finished page 23 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=24
# Finished page 24 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=25
# Finished page 25 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=26
# Finished page 26 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=27
# Finished page 27 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=28
# Finished page 28 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=29
# Finished page 29 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=30
# Finished page 30 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=31
# Finished page 31 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=32
# Finished page 32 / 33
# https://www.topcv.vn/tim-viec-lam-san-xuat-c10126?page=33
# Finished page 33 / 33
# ----------------Saved all Sản xuất records.----------------
# Collecting industry:  Mỹ thuật / Nghệ thuật / Điện ảnh
# Total page:  21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=1
# Finished page 1 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=2
# Finished page 2 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=3
# Finished page 3 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=4
# Finished page 4 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=5
# Finished page 5 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=6
# Finished page 6 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=7
# Finished page 7 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=8
# Finished page 8 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=9
# Finished page 9 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=10
# Finished page 10 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=11
# Finished page 11 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=12
# Finished page 12 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=13
# Finished page 13 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=14
# Finished page 14 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=15
# Finished page 15 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=16
# Finished page 16 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=17
# Finished page 17 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=18
# Finished page 18 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=19
# Finished page 19 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=20
# Finished page 20 / 21
# https://www.topcv.vn/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032?page=21
# Finished page 21 / 21
# ----------------Saved all Mỹ thuật / Nghệ thuật / Điện ảnh records.----------------
# Collecting industry:  Công nghệ cao
# Total page:  18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=1
# Finished page 1 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=2
# Finished page 2 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=3
# Finished page 3 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=4
# Finished page 4 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=5
# Finished page 5 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=6
# Finished page 6 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=7
# Finished page 7 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=8
# Finished page 8 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=9
# Finished page 9 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=10
# Finished page 10 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=11
# Finished page 11 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=12
# Finished page 12 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=13
# Finished page 13 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=14
# Finished page 14 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=15
# Finished page 15 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=16
# Finished page 16 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=17
# Finished page 17 / 18
# https://www.topcv.vn/tim-viec-lam-cong-nghe-cao-c10009?page=18
# Finished page 18 / 18
# ----------------Saved all Công nghệ cao records.----------------
# Collecting industry:  Nông / Lâm / Ngư nghiệp
# Total page:  9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=1
# Finished page 1 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=2
# Finished page 2 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=3
# Finished page 3 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=4
# Finished page 4 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=5
# Finished page 5 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=6
# Finished page 6 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=7
# Finished page 7 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=8
# Finished page 8 / 9
# https://www.topcv.vn/tim-viec-lam-nong-lam-ngu-nghiep-c10035?page=9
# Finished page 9 / 9
# ----------------Saved all Nông / Lâm / Ngư nghiệp records.----------------
# Collecting industry:  Dược phẩm / Công nghệ sinh học
# Total page:  24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=1
# Finished page 1 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=2
# Finished page 2 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=3
# Finished page 3 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=4
# Finished page 4 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=5
# Finished page 5 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=6
# Finished page 6 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=7
# Finished page 7 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=8
# Finished page 8 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=9
# Finished page 9 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=10
# Finished page 10 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=11
# Finished page 11 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=12
# Finished page 12 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=13
# Finished page 13 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=14
# Finished page 14 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=15
# Finished page 15 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=16
# Finished page 16 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=17
# Finished page 17 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=18
# Finished page 18 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=19
# Finished page 19 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=20
# Finished page 20 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=21
# Finished page 21 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=22
# Finished page 22 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=23
# Finished page 23 / 24
# https://www.topcv.vn/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110?page=24
# Finished page 24 / 24
# ----------------Saved all Dược phẩm / Công nghệ sinh học records.----------------
# Collecting industry:  Spa / Làm đẹp
# Total page:  27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=1
# Finished page 1 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=2
# Finished page 2 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=3
# Finished page 3 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=4
# Finished page 4 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=5
# Finished page 5 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=6
# Finished page 6 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=7
# Finished page 7 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=8
# Finished page 8 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=9
# Finished page 9 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=10
# Finished page 10 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=11
# Finished page 11 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=12
# Finished page 12 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=13
# Finished page 13 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=14
# Finished page 14 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=15
# Finished page 15 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=16
# Finished page 16 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=17
# Finished page 17 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=18
# Finished page 18 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=19
# Finished page 19 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=20
# Finished page 20 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=21
# Finished page 21 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=22
# Finished page 22 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=23
# Finished page 23 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=24
# Finished page 24 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=25
# Finished page 25 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=26
# Finished page 26 / 27
# https://www.topcv.vn/tim-viec-lam-spa-lam-dep-c10130?page=27
# Finished page 27 / 27
# ----------------Saved all Spa / Làm đẹp records.----------------
# Collecting industry:  Hàng tiêu dùng
# Total page:  12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=1
# Finished page 1 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=2
# Finished page 2 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=3
# Finished page 3 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=4
# Finished page 4 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=5
# Finished page 5 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=6
# Finished page 6 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=7
# Finished page 7 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=8
# Finished page 8 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=9
# Finished page 9 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=10
# Finished page 10 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=11
# Finished page 11 / 12
# https://www.topcv.vn/tim-viec-lam-hang-tieu-dung-c10117?page=12
# Finished page 12 / 12
# ----------------Saved all Hàng tiêu dùng records.----------------
# Collecting industry:  Dệt may / Da giày
# Total page:  11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=1
# Finished page 1 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=2
# Finished page 2 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=3
# Finished page 3 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=4
# Finished page 4 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=5
# Finished page 5 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=6
# Finished page 6 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=7
# Finished page 7 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=8
# Finished page 8 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=9
# Finished page 9 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=10
# Finished page 10 / 11
# https://www.topcv.vn/tim-viec-lam-det-may-da-giay-c10013?page=11
# Finished page 11 / 11
# ----------------Saved all Dệt may / Da giày records.----------------
# Collecting industry:  Hàng hải
# Total page:  2
# https://www.topcv.vn/tim-viec-lam-hang-hai-c10021?page=1
# Finished page 1 / 2
# https://www.topcv.vn/tim-viec-lam-hang-hai-c10021?page=2
# Finished page 2 / 2
# ----------------Saved all Hàng hải records.----------------
# Collecting industry:  An toàn lao động
# Total page:  3
# https://www.topcv.vn/tim-viec-lam-an-toan-lao-dong-c10101?page=1
# Finished page 1 / 3
# https://www.topcv.vn/tim-viec-lam-an-toan-lao-dong-c10101?page=2
# Finished page 2 / 3
# https://www.topcv.vn/tim-viec-lam-an-toan-lao-dong-c10101?page=3
# Finished page 3 / 3
# ----------------Saved all An toàn lao động records.----------------
# Collecting industry:  Hoá học / Sinh học
# Total page:  9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=1
# Finished page 1 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=2
# Finished page 2 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=3
# Finished page 3 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=4
# Finished page 4 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=5
# Finished page 5 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=6
# Finished page 6 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=7
# Finished page 7 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=8
# Finished page 8 / 9
# https://www.topcv.vn/tim-viec-lam-hoa-hoc-sinh-hoc-c10018?page=9
# Finished page 9 / 9
# ----------------Saved all Hoá học / Sinh học records.----------------
# Collecting industry:  Bảo trì / Sửa chữa
# Total page:  19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=1
# Finished page 1 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=2
# Finished page 2 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=3
# Finished page 3 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=4
# Finished page 4 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=5
# Finished page 5 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=6
# Finished page 6 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=7
# Finished page 7 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=8
# Finished page 8 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=9
# Finished page 9 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=10
# Finished page 10 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=11
# Finished page 11 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=12
# Finished page 12 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=13
# Finished page 13 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=14
# Finished page 14 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=15
# Finished page 15 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=16
# Finished page 16 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=17
# Finished page 17 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=18
# Finished page 18 / 19
# https://www.topcv.vn/tim-viec-lam-bao-tri-sua-chua-c10104?page=19
# Finished page 19 / 19
# ----------------Saved all Bảo trì / Sửa chữa records.----------------
# Collecting industry:  Môi trường / Xử lý chất thải
# Total page:  7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=1
# Finished page 1 / 7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=2
# Finished page 2 / 7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=3
# Finished page 3 / 7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=4
# Finished page 4 / 7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=5
# Finished page 5 / 7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=6
# Finished page 6 / 7
# https://www.topcv.vn/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030?page=7
# Finished page 7 / 7
# ----------------Saved all Môi trường / Xử lý chất thải records.----------------
# Collecting industry:  Bưu chính - Viễn thông
# Total page:  15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=1
# Finished page 1 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=2
# Finished page 2 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=3
# Finished page 3 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=4
# Finished page 4 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=5
# Finished page 5 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=6
# Finished page 6 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=7
# Finished page 7 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=8
# Finished page 8 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=9
# Finished page 9 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=10
# Finished page 10 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=11
# Finished page 11 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=12
# Finished page 12 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=13
# Finished page 13 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=14
# Finished page 14 / 15
# https://www.topcv.vn/tim-viec-lam-buu-chinh-vien-thong-c10005?page=15
# Finished page 15 / 15
# ----------------Saved all Bưu chính - Viễn thông records.----------------
# Collecting industry:  Hàng gia dụng
# Total page:  10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=1
# Finished page 1 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=2
# Finished page 2 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=3
# Finished page 3 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=4
# Finished page 4 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=5
# Finished page 5 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=6
# Finished page 6 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=7
# Finished page 7 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=8
# Finished page 8 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=9
# Finished page 9 / 10
# https://www.topcv.vn/tim-viec-lam-hang-gia-dung-c10020?page=10
# Finished page 10 / 10
# ----------------Saved all Hàng gia dụng records.----------------
# Collecting industry:  Bán hàng kỹ thuật
# Total page:  25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=1
# Finished page 1 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=2
# Finished page 2 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=3
# Finished page 3 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=4
# Finished page 4 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=5
# Finished page 5 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=6
# Finished page 6 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=7
# Finished page 7 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=8
# Finished page 8 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=9
# Finished page 9 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=10
# Finished page 10 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=11
# Finished page 11 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=12
# Finished page 12 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=13
# Finished page 13 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=14
# Finished page 14 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=15
# Finished page 15 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=16
# Finished page 16 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=17
# Finished page 17 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=18
# Finished page 18 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=19
# Finished page 19 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=20
# Finished page 20 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=21
# Finished page 21 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=22
# Finished page 22 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=23
# Finished page 23 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=24
# Finished page 24 / 25
# https://www.topcv.vn/tim-viec-lam-ban-hang-ky-thuat-c10102?page=25
# Finished page 25 / 25
# ----------------Saved all Bán hàng kỹ thuật records.----------------
# Collecting industry:  Bảo hiểm
# Total page:  36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=1
# Finished page 1 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=2
# Finished page 2 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=3
# Finished page 3 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=4
# Finished page 4 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=5
# Finished page 5 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=6
# Finished page 6 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=7
# Finished page 7 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=8
# Finished page 8 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=9
# Finished page 9 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=10
# Finished page 10 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=11
# Finished page 11 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=12
# Finished page 12 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=13
# Finished page 13 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=14
# Finished page 14 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=15
# Finished page 15 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=16
# Finished page 16 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=17
# Finished page 17 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=18
# Finished page 18 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=19
# Finished page 19 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=20
# Finished page 20 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=21
# Finished page 21 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=22
# Finished page 22 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=23
# Finished page 23 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=24
# Finished page 24 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=25
# Finished page 25 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=26
# Finished page 26 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=27
# Finished page 27 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=28
# Finished page 28 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=29
# Finished page 29 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=30
# Finished page 30 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=31
# Finished page 31 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=32
# Finished page 32 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=33
# Finished page 33 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=34
# Finished page 34 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=35
# Finished page 35 / 36
# https://www.topcv.vn/tim-viec-lam-bao-hiem-c10006?page=36
# Finished page 36 / 36
# ----------------Saved all Bảo hiểm records.----------------
# Collecting industry:  Dầu khí/Hóa chất
# Total page:  4
# https://www.topcv.vn/tim-viec-lam-dau-khi-hoa-chat-c10012?page=1
# Finished page 1 / 4
# https://www.topcv.vn/tim-viec-lam-dau-khi-hoa-chat-c10012?page=2
# Finished page 2 / 4
# https://www.topcv.vn/tim-viec-lam-dau-khi-hoa-chat-c10012?page=3
# Finished page 3 / 4
# https://www.topcv.vn/tim-viec-lam-dau-khi-hoa-chat-c10012?page=4
# Finished page 4 / 4
# ----------------Saved all Dầu khí/Hóa chất records.----------------

# %%
for ind,industry in enumerate(industries):
    print(ind, '-', industry)
# Out:
# 0 - {'id': 10001, 'name': 'Kinh doanh / Bán hàng', 'alias': 'kinh-doanh-ban-hang', 'access_url': '/tim-viec-lam-kinh-doanh-ban-hang-c10001', 'job_category_count': '11.119'}
# 1 - {'id': 10026, 'name': 'IT phần mềm', 'alias': 'it-phan-mem', 'access_url': '/tim-viec-lam-it-phan-mem-c10026', 'job_category_count': '3.248'}
# 2 - {'id': 10023, 'name': 'Hành chính / Văn phòng', 'alias': 'hanh-chinh-van-phong', 'access_url': '/tim-viec-lam-hanh-chinh-van-phong-c10023', 'job_category_count': '3.996'}
# 3 - {'id': 10017, 'name': 'Giáo dục / Đào tạo', 'alias': 'giao-duc-dao-tao', 'access_url': '/tim-viec-lam-giao-duc-dao-tao-c10017', 'job_category_count': '2.856'}
# 4 - {'id': 10045, 'name': 'Tư vấn', 'alias': 'tu-van', 'access_url': '/tim-viec-lam-tu-van-c10045', 'job_category_count': '4.092'}
# 5 - {'id': 10029, 'name': 'Marketing / Truyền thông / Quảng cáo', 'alias': 'marketing-truyen-thong-quang-cao', 'access_url': '/tim-viec-lam-marketing-truyen-thong-quang-cao-c10029', 'job_category_count': '5.453'}
# 6 - {'id': 10047, 'name': 'Vận tải / Kho vận', 'alias': 'van-tai-kho-van', 'access_url': '/tim-viec-lam-van-tai-kho-van-c10047', 'job_category_count': '902'}
# 7 - {'id': 10028, 'name': 'Kế toán / Kiểm toán', 'alias': 'ke-toan-kiem-toan', 'access_url': '/tim-viec-lam-ke-toan-kiem-toan-c10028', 'job_category_count': '2.879'}
# 8 - {'id': 10037, 'name': 'Quản lý chất lượng (QA/QC)', 'alias': 'quan-ly-chat-luong-qa-qc', 'access_url': '/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037', 'job_category_count': '577'}
# 9 - {'id': 10131, 'name': 'Công nghệ thông tin', 'alias': 'cong-nghe-thong-tin', 'access_url': '/tim-viec-lam-cong-nghe-thong-tin-c10131', 'job_category_count': '2.893'}
# 10 - {'id': 10129, 'name': 'Thư ký / Trợ lý', 'alias': 'thu-ky-tro-ly', 'access_url': '/tim-viec-lam-thu-ky-tro-ly-c10129', 'job_category_count': '669'}
# 11 - {'id': 10042, 'name': 'Thời trang', 'alias': 'thoi-trang', 'access_url': '/tim-viec-lam-thoi-trang-c10042', 'job_category_count': '856'}
# 12 - {'id': 10039, 'name': 'Thiết kế đồ họa', 'alias': 'thiet-ke-do-hoa', 'access_url': '/tim-viec-lam-thiet-ke-do-hoa-c10039', 'job_category_count': '1.157'}
# 13 - {'id': 10034, 'name': 'Nhân sự', 'alias': 'nhan-su', 'access_url': '/tim-viec-lam-nhan-su-c10034', 'job_category_count': '1.672'}
# 14 - {'id': 10046, 'name': 'Tổ chức sự kiện / Quà tặng', 'alias': 'to-chuc-su-kien-qua-tang', 'access_url': '/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046', 'job_category_count': '351'}
# 15 - {'id': 10050, 'name': 'Xây dựng', 'alias': 'xay-dung', 'access_url': '/tim-viec-lam-xay-dung-c10050', 'job_category_count': '1.186'}
# 16 - {'id': 10051, 'name': 'Y tế / Dược', 'alias': 'y-te-duoc', 'access_url': '/tim-viec-lam-y-te-duoc-c10051', 'job_category_count': '1.436'}
# 17 - {'id': 10016, 'name': 'Điện / Điện tử / Điện lạnh', 'alias': 'dien-dien-tu-dien-lanh', 'access_url': '/tim-viec-lam-dien-dien-tu-dien-lanh-c10016', 'job_category_count': '1.233'}
# 18 - {'id': 10003, 'name': 'Biên / Phiên dịch', 'alias': 'bien-phien-dich', 'access_url': '/tim-viec-lam-bien-phien-dich-c10003', 'job_category_count': '1.068'}
# 19 - {'id': 10010, 'name': 'Cơ khí / Chế tạo / Tự động hóa', 'alias': 'co-khi-che-tao-tu-dong-hoa', 'access_url': '/tim-viec-lam-co-khi-che-tao-tu-dong-hoa-c10010', 'job_category_count': '1.109'}
# 20 - {'id': 10033, 'name': 'Ngân hàng / Tài chính', 'alias': 'ngan-hang-tai-chinh', 'access_url': '/tim-viec-lam-ngan-hang-tai-chinh-c10033', 'job_category_count': '2.624'}
# 21 - {'id': 10043, 'name': 'Thực phẩm / Đồ uống', 'alias': 'thuc-pham-do-uong', 'access_url': '/tim-viec-lam-thuc-pham-do-uong-c10043', 'job_category_count': '953'}
# 22 - {'id': 10036, 'name': 'Luật/Pháp lý', 'alias': 'luat-phap-ly', 'access_url': '/tim-viec-lam-luat-phap-ly-c10036', 'job_category_count': '471'}
# 23 - {'id': 10004, 'name': 'Báo chí / Truyền hình', 'alias': 'bao-chi-truyen-hinh', 'access_url': '/tim-viec-lam-bao-chi-truyen-hinh-c10004', 'job_category_count': '1.498'}
# 24 - {'id': 10038, 'name': 'Quản lý điều hành', 'alias': 'quan-ly-dieu-hanh', 'access_url': '/tim-viec-lam-quan-ly-dieu-hanh-c10038', 'job_category_count': '1.073'}
# 25 - {'id': 11000, 'name': 'Ngành nghề khác', 'alias': 'nganh-nghe-khac', 'access_url': '/tim-viec-lam-nganh-nghe-khac-c11000', 'job_category_count': '1.344'}
# 26 - {'id': 10015, 'name': 'Điện tử viễn thông', 'alias': 'dien-tu-vien-thong', 'access_url': '/tim-viec-lam-dien-tu-vien-thong-c10015', 'job_category_count': '553'}
# 27 - {'id': 10048, 'name': 'Logistics', 'alias': 'logistics', 'access_url': '/tim-viec-lam-logistics-c10048', 'job_category_count': '1.008'}
# 28 - {'id': 10027, 'name': 'Khách sạn / Nhà hàng', 'alias': 'khach-san-nha-hang', 'access_url': '/tim-viec-lam-khach-san-nha-hang-c10027', 'job_category_count': '1.009'}
# 29 - {'id': 10049, 'name': 'Xuất nhập khẩu', 'alias': 'xuat-nhap-khau', 'access_url': '/tim-viec-lam-xuat-nhap-khau-c10049', 'job_category_count': '923'}
# 30 - {'id': 10025, 'name': 'IT Phần cứng / Mạng', 'alias': 'it-phan-cung-mang', 'access_url': '/tim-viec-lam-it-phan-cung-mang-c10025', 'job_category_count': '1.045'}
# 31 - {'id': 10011, 'name': 'Du lịch', 'alias': 'du-lich', 'access_url': '/tim-viec-lam-du-lich-c10011', 'job_category_count': '695'}
# 32 - {'id': 10008, 'name': 'Chứng khoán / Vàng / Ngoại tệ', 'alias': 'chung-khoan-vang-ngoai-te', 'access_url': '/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008', 'job_category_count': '362'}
# 33 - {'id': 10014, 'name': 'Dịch vụ khách hàng', 'alias': 'dich-vu-khach-hang', 'access_url': '/tim-viec-lam-dich-vu-khach-hang-c10014', 'job_category_count': '4.184'}
# 34 - {'id': 10019, 'name': 'Hoạch định/Dự án', 'alias': 'hoach-dinh-du-an', 'access_url': '/tim-viec-lam-hoach-dinh-du-an-c10019', 'job_category_count': '294'}
# 35 - {'id': 10127, 'name': 'Tài chính / Đầu tư', 'alias': 'tai-chinh-dau-tu', 'access_url': '/tim-viec-lam-tai-chinh-dau-tu-c10127', 'job_category_count': '1.364'}
# 36 - {'id': 10052, 'name': 'Công nghệ Ô tô', 'alias': 'cong-nghe-o-to', 'access_url': '/tim-viec-lam-cong-nghe-o-to-c10052', 'job_category_count': '306'}
# 37 - {'id': 10031, 'name': 'Mỹ phẩm / Trang sức', 'alias': 'my-pham-trang-suc', 'access_url': '/tim-viec-lam-my-pham-trang-suc-c10031', 'job_category_count': '532'}
# 38 - {'id': 10120, 'name': 'Kiến trúc', 'alias': 'kien-truc', 'access_url': '/tim-viec-lam-kien-truc-c10120', 'job_category_count': '449'}
# 39 - {'id': 10007, 'name': 'Bất động sản', 'alias': 'bat-dong-san', 'access_url': '/tim-viec-lam-bat-dong-san-c10007', 'job_category_count': '1.071'}
# 40 - {'id': 10128, 'name': 'Thiết kế nội thất', 'alias': 'thiet-ke-noi-that', 'access_url': '/tim-viec-lam-thiet-ke-noi-that-c10128', 'job_category_count': '576'}
# 41 - {'id': 10126, 'name': 'Sản xuất', 'alias': 'san-xuat', 'access_url': '/tim-viec-lam-san-xuat-c10126', 'job_category_count': '797'}
# 42 - {'id': 10032, 'name': 'Mỹ thuật / Nghệ thuật / Điện ảnh', 'alias': 'my-thuat-nghe-thuat-dien-anh', 'access_url': '/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032', 'job_category_count': '515'}
# 43 - {'id': 10009, 'name': 'Công nghệ cao', 'alias': 'cong-nghe-cao', 'access_url': '/tim-viec-lam-cong-nghe-cao-c10009', 'job_category_count': '442'}
# 44 - {'id': 10035, 'name': 'Nông / Lâm / Ngư nghiệp', 'alias': 'nong-lam-ngu-nghiep', 'access_url': '/tim-viec-lam-nong-lam-ngu-nghiep-c10035', 'job_category_count': '219'}
# 45 - {'id': 10110, 'name': 'Dược phẩm / Công nghệ sinh học', 'alias': 'duoc-pham-cong-nghe-sinh-hoc', 'access_url': '/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110', 'job_category_count': '571'}
# 46 - {'id': 10130, 'name': 'Spa / Làm đẹp', 'alias': 'spa-lam-dep', 'access_url': '/tim-viec-lam-spa-lam-dep-c10130', 'job_category_count': '665'}
# 47 - {'id': 10117, 'name': 'Hàng tiêu dùng', 'alias': 'hang-tieu-dung', 'access_url': '/tim-viec-lam-hang-tieu-dung-c10117', 'job_category_count': '287'}
# 48 - {'id': 10013, 'name': 'Dệt may / Da giày', 'alias': 'det-may-da-giay', 'access_url': '/tim-viec-lam-det-may-da-giay-c10013', 'job_category_count': '267'}
# 49 - {'id': 10021, 'name': 'Hàng hải', 'alias': 'hang-hai', 'access_url': '/tim-viec-lam-hang-hai-c10021', 'job_category_count': '32'}
# 50 - {'id': 10101, 'name': 'An toàn lao động', 'alias': 'an-toan-lao-dong', 'access_url': '/tim-viec-lam-an-toan-lao-dong-c10101', 'job_category_count': '66'}
# 51 - {'id': 10018, 'name': 'Hoá học / Sinh học', 'alias': 'hoa-hoc-sinh-hoc', 'access_url': '/tim-viec-lam-hoa-hoc-sinh-hoc-c10018', 'job_category_count': '211'}
# 52 - {'id': 10104, 'name': 'Bảo trì / Sửa chữa', 'alias': 'bao-tri-sua-chua', 'access_url': '/tim-viec-lam-bao-tri-sua-chua-c10104', 'job_category_count': '488'}
# 53 - {'id': 10030, 'name': 'Môi trường / Xử lý chất thải', 'alias': 'moi-truong-xu-ly-chat-thai', 'access_url': '/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030', 'job_category_count': '175'}
# 54 - {'id': 10005, 'name': 'Bưu chính - Viễn thông', 'alias': 'buu-chinh-vien-thong', 'access_url': '/tim-viec-lam-buu-chinh-vien-thong-c10005', 'job_category_count': '381'}
# 55 - {'id': 10020, 'name': 'Hàng gia dụng', 'alias': 'hang-gia-dung', 'access_url': '/tim-viec-lam-hang-gia-dung-c10020', 'job_category_count': '233'}
# 56 - {'id': 10102, 'name': 'Bán hàng kỹ thuật', 'alias': 'ban-hang-ky-thuat', 'access_url': '/tim-viec-lam-ban-hang-ky-thuat-c10102', 'job_category_count': '623'}
# 57 - {'id': 10103, 'name': 'Bán lẻ / bán sỉ', 'alias': 'ban-le-ban-si', 'access_url': '/tim-viec-lam-ban-le-ban-si-c10103', 'job_category_count': '1.656'}
# 58 - {'id': 10006, 'name': 'Bảo hiểm', 'alias': 'bao-hiem', 'access_url': '/tim-viec-lam-bao-hiem-c10006', 'job_category_count': '896'}
# 59 - {'id': 10012, 'name': 'Dầu khí/Hóa chất', 'alias': 'dau-khi-hoa-chat', 'access_url': '/tim-viec-lam-dau-khi-hoa-chat-c10012', 'job_category_count': '85'}
# 60 - {'id': 10024, 'name': 'In ấn / Xuất bản', 'alias': 'in-an-xuat-ban', 'access_url': '/tim-viec-lam-in-an-xuat-ban-c10024', 'job_category_count': '143'}
# 61 - {'id': 10022, 'name': 'Hàng không', 'alias': 'hang-khong', 'access_url': '/tim-viec-lam-hang-khong-c10022', 'job_category_count': '68'}
# 62 - {'id': 10132, 'name': 'NGO / Phi chính phủ / Phi lợi nhuận', 'alias': 'ngo-phi-chinh-phu-phi-loi-nhuan', 'access_url': '/tim-viec-lam-ngo-phi-chinh-phu-phi-loi-nhuan-c10132', 'job_category_count': '15'}
# 63 - {'id': 10111, 'name': 'Địa chất / Khoáng sản', 'alias': 'dia-chat-khoang-san', 'access_url': '/tim-viec-lam-dia-chat-khoang-san-c10111', 'job_category_count': '42'}
# 64 - {'id': 10124, 'name': 'Phi chính phủ / Phi lợi nhuận', 'alias': 'phi-chinh-phu-phi-loi-nhuan', 'access_url': '/tim-viec-lam-phi-chinh-phu-phi-loi-nhuan-c10124', 'job_category_count': '7'}
# 65 - {'id': 10125, 'name': 'Sản phẩm công nghiệp', 'alias': 'san-pham-cong-nghiep', 'access_url': '/tim-viec-lam-san-pham-cong-nghiep-c10125', 'job_category_count': '187'}
# 66 - {'id': 10113, 'name': 'Hàng cao cấp', 'alias': 'hang-cao-cap', 'access_url': '/tim-viec-lam-hang-cao-cap-c10113', 'job_category_count': '53'}

# %% [markdown]
# Collecting industries with > 1000 jobs

# %%
num_cores = cpu_count() # number of CPU cores 

async def extract_details(page, session, save_name_exc_urls): 
    # concatenate page number to base URL 
    async with session.get(f"{page}") as resp:
        jobs_by_industries = []
        except_urls = []
        print(f'{page}')
        pg_bs = BeautifulSoup(resp.text, 'html.parser')
        job_body = pg_bs.find("div",{'class':'job-body'})
        job_list = job_body.find('div', {'class':'job-list-default'})
        job_items = job_list.find_all('div',{'class':'job-item-default'})
        for job_item in job_items:
            job_dict = {}
            job_item_ = job_item.find('div',{'class':'body'})
            job_url = job_item_.find('a').get('href')
            try:
                job_dict['url'] = job_url
                resp1 = requests.get(job_url)
                jb_bs = BeautifulSoup(resp1.text, 'html.parser')
                job_header = jb_bs.find('div',{'class':'box-detail-job'}).find('div',{'class':'box-header'})
                company_name = job_header.find('a',{'class':'company-logo'}).get('title')
                job_title = job_header.find('div',{'class':'box-info-job'}).find('h1',{'class':'job-title'}).getText().strip()
                job_deadline = job_header.find('div',{'class':'job-deadline'}).getText().strip()
                job_info = jb_bs.find('div',{'id':'tab-info'})

                general_info = job_info.find_all('div',{'class':'box-info'})[-1].find_all('div',{'class':'box-item'})
                job_salary = general_info[0].find('span').getText().strip()
                job_type = general_info[2].find('span').getText().strip()
                job_level = general_info[3].find('span').getText().strip()
                job_yoe = general_info[-1].find('span').getText().strip()
                job_addresses = [item.text.strip() for item in job_info.find('div',{'class':'box-address'}).find_all('div')[1:]]

                job_data = job_info.find('div',{'class':'job-data'})
                job_details = job_data.find_all('div',{'class':'content-tab'})
                job_desc = str(job_details[0])
                job_req = str(job_details[1])

                job_dict['job_title'] = job_title
                job_dict['job_deadline'] = job_deadline
                job_dict['company_name'] = company_name
                job_dict['job_salary'] = job_salary
                job_dict['job_type'] = job_type
                job_dict['job_yoe'] = job_yoe
                job_dict['job_addresses'] = job_addresses
                job_dict['job_desc'] = job_desc
                job_dict['job_req'] = job_req
                jobs_by_industries.append(job_dict)
#                 print(f'{len(job_title)} - {len(job_salary)} - {len(job_type)} - {len(job_addresses)} - {len(job_desc)} - {len(job_req)}')
            except Exception as e:
                except_urls.append(job_url)
        append_text(except_urls, save_name_exc_urls)
        return jobs_by_industries

async def extract_details_task(pages_for_task, save_name_exc_urls): 
    async with aiohttp.ClientSession() as session: 
        tasks = [ 
            extract_details(page, session, save_name_exc_urls) 
            for page in pages_for_task 
        ] 
        list_of_lists = await asyncio.gather(*tasks) 
        return sum(list_of_lists, []) 
 
 
def asyncio_wrapper(pages_for_task, save_name_exc_urls): 
    return asyncio.run(extract_details_task(pages_for_task, save_name_exc_urls))

def execute_parallel_scrape(pages, save_name, save_name_exc_urls): 
    executor = ProcessPoolExecutor(max_workers=num_cores) 
    tasks = [ 
        executor.submit(asyncio_wrapper, pages_for_task, save_name_exc_urls) 
        for pages_for_task in np.array_split(pages, num_cores) 
    ] 
    doneTasks, _ = concurrent.futures.wait(tasks) 
 
    results = [ 
        item.result() 
        for item in doneTasks 
    ] 
    save_json(results, save_name) 
    
def parallel_get_jobs_by_industry(industry_name, industry_url, save_name=None):
    base_url = "https://www.topcv.vn"
    ind_url = industry_url
    if save_name is None:
        save_name = industry_name
    save_name_exc_urls = f'exc_urls_{save_name}' 
    print("Collecting industry: ", industry_name)
    
    resp = requests.get(f'{base_url}{ind_url}')
    pg_bs = BeautifulSoup(resp.text, 'html.parser')
    try:
        max_page = int(pg_bs.find('ul',{'class':'pagination'}).find_all('li')[-2].text.strip())
    except Exception as e:
        max_page = 1
    print("Total page: ", max_page)
    pages_to_scrape = [f'{base_url}{ind_url}?page={i}' for i in range(1,max_page+1)]
    
    execute_parallel_scrape(pages_to_scrape, save_name, save_name_exc_urls)

# %% [markdown]
# Collecting IT Phần mềm

# %%
industries
# Out:
# [{'id': 10001,
#   'name': 'Kinh doanh / Bán hàng',
#   'alias': 'kinh-doanh-ban-hang',
#   'access_url': '/tim-viec-lam-kinh-doanh-ban-hang-c10001',
#   'job_category_count': '11.119'},
#  {'id': 10026,
#   'name': 'IT phần mềm',
#   'alias': 'it-phan-mem',
#   'access_url': '/tim-viec-lam-it-phan-mem-c10026',
#   'job_category_count': '3.248'},
#  {'id': 10023,
#   'name': 'Hành chính / Văn phòng',
#   'alias': 'hanh-chinh-van-phong',
#   'access_url': '/tim-viec-lam-hanh-chinh-van-phong-c10023',
#   'job_category_count': '3.996'},
#  {'id': 10017,
#   'name': 'Giáo dục / Đào tạo',
#   'alias': 'giao-duc-dao-tao',
#   'access_url': '/tim-viec-lam-giao-duc-dao-tao-c10017',
#   'job_category_count': '2.856'},
#  {'id': 10045,
#   'name': 'Tư vấn',
#   'alias': 'tu-van',
#   'access_url': '/tim-viec-lam-tu-van-c10045',
#   'job_category_count': '4.092'},
#  {'id': 10029,
#   'name': 'Marketing / Truyền thông / Quảng cáo',
#   'alias': 'marketing-truyen-thong-quang-cao',
#   'access_url': '/tim-viec-lam-marketing-truyen-thong-quang-cao-c10029',
#   'job_category_count': '5.453'},
#  {'id': 10047,
#   'name': 'Vận tải / Kho vận',
#   'alias': 'van-tai-kho-van',
#   'access_url': '/tim-viec-lam-van-tai-kho-van-c10047',
#   'job_category_count': '902'},
#  {'id': 10028,
#   'name': 'Kế toán / Kiểm toán',
#   'alias': 'ke-toan-kiem-toan',
#   'access_url': '/tim-viec-lam-ke-toan-kiem-toan-c10028',
#   'job_category_count': '2.879'},
#  {'id': 10037,
#   'name': 'Quản lý chất lượng (QA/QC)',
#   'alias': 'quan-ly-chat-luong-qa-qc',
#   'access_url': '/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037',
#   'job_category_count': '577'},
#  {'id': 10131,
#   'name': 'Công nghệ thông tin',
#   'alias': 'cong-nghe-thong-tin',
#   'access_url': '/tim-viec-lam-cong-nghe-thong-tin-c10131',
#   'job_category_count': '2.893'},
#  {'id': 10129,
#   'name': 'Thư ký / Trợ lý',
#   'alias': 'thu-ky-tro-ly',
#   'access_url': '/tim-viec-lam-thu-ky-tro-ly-c10129',
#   'job_category_count': '669'},
#  {'id': 10042,
#   'name': 'Thời trang',
#   'alias': 'thoi-trang',
#   'access_url': '/tim-viec-lam-thoi-trang-c10042',
#   'job_category_count': '856'},
#  {'id': 10039,
#   'name': 'Thiết kế đồ họa',
#   'alias': 'thiet-ke-do-hoa',
#   'access_url': '/tim-viec-lam-thiet-ke-do-hoa-c10039',
#   'job_category_count': '1.157'},
#  {'id': 10034,
#   'name': 'Nhân sự',
#   'alias': 'nhan-su',
#   'access_url': '/tim-viec-lam-nhan-su-c10034',
#   'job_category_count': '1.672'},
#  {'id': 10046,
#   'name': 'Tổ chức sự kiện / Quà tặng',
#   'alias': 'to-chuc-su-kien-qua-tang',
#   'access_url': '/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046',
#   'job_category_count': '351'},
#  {'id': 10050,
#   'name': 'Xây dựng',
#   'alias': 'xay-dung',
#   'access_url': '/tim-viec-lam-xay-dung-c10050',
#   'job_category_count': '1.186'},
#  {'id': 10051,
#   'name': 'Y tế / Dược',
#   'alias': 'y-te-duoc',
#   'access_url': '/tim-viec-lam-y-te-duoc-c10051',
#   'job_category_count': '1.436'},
#  {'id': 10016,
#   'name': 'Điện / Điện tử / Điện lạnh',
#   'alias': 'dien-dien-tu-dien-lanh',
#   'access_url': '/tim-viec-lam-dien-dien-tu-dien-lanh-c10016',
#   'job_category_count': '1.233'},
#  {'id': 10003,
#   'name': 'Biên / Phiên dịch',
#   'alias': 'bien-phien-dich',
#   'access_url': '/tim-viec-lam-bien-phien-dich-c10003',
#   'job_category_count': '1.068'},
#  {'id': 10010,
#   'name': 'Cơ khí / Chế tạo / Tự động hóa',
#   'alias': 'co-khi-che-tao-tu-dong-hoa',
#   'access_url': '/tim-viec-lam-co-khi-che-tao-tu-dong-hoa-c10010',
#   'job_category_count': '1.109'},
#  {'id': 10033,
#   'name': 'Ngân hàng / Tài chính',
#   'alias': 'ngan-hang-tai-chinh',
#   'access_url': '/tim-viec-lam-ngan-hang-tai-chinh-c10033',
#   'job_category_count': '2.624'},
#  {'id': 10043,
#   'name': 'Thực phẩm / Đồ uống',
#   'alias': 'thuc-pham-do-uong',
#   'access_url': '/tim-viec-lam-thuc-pham-do-uong-c10043',
#   'job_category_count': '953'},
#  {'id': 10036,
#   'name': 'Luật/Pháp lý',
#   'alias': 'luat-phap-ly',
#   'access_url': '/tim-viec-lam-luat-phap-ly-c10036',
#   'job_category_count': '471'},
#  {'id': 10004,
#   'name': 'Báo chí / Truyền hình',
#   'alias': 'bao-chi-truyen-hinh',
#   'access_url': '/tim-viec-lam-bao-chi-truyen-hinh-c10004',
#   'job_category_count': '1.498'},
#  {'id': 10038,
#   'name': 'Quản lý điều hành',
#   'alias': 'quan-ly-dieu-hanh',
#   'access_url': '/tim-viec-lam-quan-ly-dieu-hanh-c10038',
#   'job_category_count': '1.073'},
#  {'id': 11000,
#   'name': 'Ngành nghề khác',
#   'alias': 'nganh-nghe-khac',
#   'access_url': '/tim-viec-lam-nganh-nghe-khac-c11000',
#   'job_category_count': '1.344'},
#  {'id': 10015,
#   'name': 'Điện tử viễn thông',
#   'alias': 'dien-tu-vien-thong',
#   'access_url': '/tim-viec-lam-dien-tu-vien-thong-c10015',
#   'job_category_count': '553'},
#  {'id': 10048,
#   'name': 'Logistics',
#   'alias': 'logistics',
#   'access_url': '/tim-viec-lam-logistics-c10048',
#   'job_category_count': '1.008'},
#  {'id': 10027,
#   'name': 'Khách sạn / Nhà hàng',
#   'alias': 'khach-san-nha-hang',
#   'access_url': '/tim-viec-lam-khach-san-nha-hang-c10027',
#   'job_category_count': '1.009'},
#  {'id': 10049,
#   'name': 'Xuất nhập khẩu',
#   'alias': 'xuat-nhap-khau',
#   'access_url': '/tim-viec-lam-xuat-nhap-khau-c10049',
#   'job_category_count': '923'},
#  {'id': 10025,
#   'name': 'IT Phần cứng / Mạng',
#   'alias': 'it-phan-cung-mang',
#   'access_url': '/tim-viec-lam-it-phan-cung-mang-c10025',
#   'job_category_count': '1.045'},
#  {'id': 10011,
#   'name': 'Du lịch',
#   'alias': 'du-lich',
#   'access_url': '/tim-viec-lam-du-lich-c10011',
#   'job_category_count': '695'},
#  {'id': 10008,
#   'name': 'Chứng khoán / Vàng / Ngoại tệ',
#   'alias': 'chung-khoan-vang-ngoai-te',
#   'access_url': '/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008',
#   'job_category_count': '362'},
#  {'id': 10014,
#   'name': 'Dịch vụ khách hàng',
#   'alias': 'dich-vu-khach-hang',
#   'access_url': '/tim-viec-lam-dich-vu-khach-hang-c10014',
#   'job_category_count': '4.184'},
#  {'id': 10019,
#   'name': 'Hoạch định/Dự án',
#   'alias': 'hoach-dinh-du-an',
#   'access_url': '/tim-viec-lam-hoach-dinh-du-an-c10019',
#   'job_category_count': '294'},
#  {'id': 10127,
#   'name': 'Tài chính / Đầu tư',
#   'alias': 'tai-chinh-dau-tu',
#   'access_url': '/tim-viec-lam-tai-chinh-dau-tu-c10127',
#   'job_category_count': '1.364'},
#  {'id': 10052,
#   'name': 'Công nghệ Ô tô',
#   'alias': 'cong-nghe-o-to',
#   'access_url': '/tim-viec-lam-cong-nghe-o-to-c10052',
#   'job_category_count': '306'},
#  {'id': 10031,
#   'name': 'Mỹ phẩm / Trang sức',
#   'alias': 'my-pham-trang-suc',
#   'access_url': '/tim-viec-lam-my-pham-trang-suc-c10031',
#   'job_category_count': '532'},
#  {'id': 10120,
#   'name': 'Kiến trúc',
#   'alias': 'kien-truc',
#   'access_url': '/tim-viec-lam-kien-truc-c10120',
#   'job_category_count': '449'},
#  {'id': 10007,
#   'name': 'Bất động sản',
#   'alias': 'bat-dong-san',
#   'access_url': '/tim-viec-lam-bat-dong-san-c10007',
#   'job_category_count': '1.071'},
#  {'id': 10128,
#   'name': 'Thiết kế nội thất',
#   'alias': 'thiet-ke-noi-that',
#   'access_url': '/tim-viec-lam-thiet-ke-noi-that-c10128',
#   'job_category_count': '576'},
#  {'id': 10126,
#   'name': 'Sản xuất',
#   'alias': 'san-xuat',
#   'access_url': '/tim-viec-lam-san-xuat-c10126',
#   'job_category_count': '797'},
#  {'id': 10032,
#   'name': 'Mỹ thuật / Nghệ thuật / Điện ảnh',
#   'alias': 'my-thuat-nghe-thuat-dien-anh',
#   'access_url': '/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032',
#   'job_category_count': '515'},
#  {'id': 10009,
#   'name': 'Công nghệ cao',
#   'alias': 'cong-nghe-cao',
#   'access_url': '/tim-viec-lam-cong-nghe-cao-c10009',
#   'job_category_count': '442'},
#  {'id': 10035,
#   'name': 'Nông / Lâm / Ngư nghiệp',
#   'alias': 'nong-lam-ngu-nghiep',
#   'access_url': '/tim-viec-lam-nong-lam-ngu-nghiep-c10035',
#   'job_category_count': '219'},
#  {'id': 10110,
#   'name': 'Dược phẩm / Công nghệ sinh học',
#   'alias': 'duoc-pham-cong-nghe-sinh-hoc',
#   'access_url': '/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110',
#   'job_category_count': '571'},
#  {'id': 10130,
#   'name': 'Spa / Làm đẹp',
#   'alias': 'spa-lam-dep',
#   'access_url': '/tim-viec-lam-spa-lam-dep-c10130',
#   'job_category_count': '665'},
#  {'id': 10117,
#   'name': 'Hàng tiêu dùng',
#   'alias': 'hang-tieu-dung',
#   'access_url': '/tim-viec-lam-hang-tieu-dung-c10117',
#   'job_category_count': '287'},
#  {'id': 10013,
#   'name': 'Dệt may / Da giày',
#   'alias': 'det-may-da-giay',
#   'access_url': '/tim-viec-lam-det-may-da-giay-c10013',
#   'job_category_count': '267'},
#  {'id': 10021,
#   'name': 'Hàng hải',
#   'alias': 'hang-hai',
#   'access_url': '/tim-viec-lam-hang-hai-c10021',
#   'job_category_count': '32'},
#  {'id': 10101,
#   'name': 'An toàn lao động',
#   'alias': 'an-toan-lao-dong',
#   'access_url': '/tim-viec-lam-an-toan-lao-dong-c10101',
#   'job_category_count': '66'},
#  {'id': 10018,
#   'name': 'Hoá học / Sinh học',
#   'alias': 'hoa-hoc-sinh-hoc',
#   'access_url': '/tim-viec-lam-hoa-hoc-sinh-hoc-c10018',
#   'job_category_count': '211'},
#  {'id': 10104,
#   'name': 'Bảo trì / Sửa chữa',
#   'alias': 'bao-tri-sua-chua',
#   'access_url': '/tim-viec-lam-bao-tri-sua-chua-c10104',
#   'job_category_count': '488'},
#  {'id': 10030,
#   'name': 'Môi trường / Xử lý chất thải',
#   'alias': 'moi-truong-xu-ly-chat-thai',
#   'access_url': '/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030',
#   'job_category_count': '175'},
#  {'id': 10005,
#   'name': 'Bưu chính - Viễn thông',
#   'alias': 'buu-chinh-vien-thong',
#   'access_url': '/tim-viec-lam-buu-chinh-vien-thong-c10005',
#   'job_category_count': '381'},
#  {'id': 10020,
#   'name': 'Hàng gia dụng',
#   'alias': 'hang-gia-dung',
#   'access_url': '/tim-viec-lam-hang-gia-dung-c10020',
#   'job_category_count': '233'},
#  {'id': 10102,
#   'name': 'Bán hàng kỹ thuật',
#   'alias': 'ban-hang-ky-thuat',
#   'access_url': '/tim-viec-lam-ban-hang-ky-thuat-c10102',
#   'job_category_count': '623'},
#  {'id': 10103,
#   'name': 'Bán lẻ / bán sỉ',
#   'alias': 'ban-le-ban-si',
#   'access_url': '/tim-viec-lam-ban-le-ban-si-c10103',
#   'job_category_count': '1.656'},
#  {'id': 10006,
#   'name': 'Bảo hiểm',
#   'alias': 'bao-hiem',
#   'access_url': '/tim-viec-lam-bao-hiem-c10006',
#   'job_category_count': '896'},
#  {'id': 10012,
#   'name': 'Dầu khí/Hóa chất',
#   'alias': 'dau-khi-hoa-chat',
#   'access_url': '/tim-viec-lam-dau-khi-hoa-chat-c10012',
#   'job_category_count': '85'},
#  {'id': 10024,
#   'name': 'In ấn / Xuất bản',
#   'alias': 'in-an-xuat-ban',
#   'access_url': '/tim-viec-lam-in-an-xuat-ban-c10024',
#   'job_category_count': '143'},
#  {'id': 10022,
#   'name': 'Hàng không',
#   'alias': 'hang-khong',
#   'access_url': '/tim-viec-lam-hang-khong-c10022',
#   'job_category_count': '68'},
#  {'id': 10132,
#   'name': 'NGO / Phi chính phủ / Phi lợi nhuận',
#   'alias': 'ngo-phi-chinh-phu-phi-loi-nhuan',
#   'access_url': '/tim-viec-lam-ngo-phi-chinh-phu-phi-loi-nhuan-c10132',
#   'job_category_count': '15'},
#  {'id': 10111,
#   'name': 'Địa chất / Khoáng sản',
#   'alias': 'dia-chat-khoang-san',
#   'access_url': '/tim-viec-lam-dia-chat-khoang-san-c10111',
#   'job_category_count': '42'},
#  {'id': 10124,
#   'name': 'Phi chính phủ / Phi lợi nhuận',
#   'alias': 'phi-chinh-phu-phi-loi-nhuan',
#   'access_url': '/tim-viec-lam-phi-chinh-phu-phi-loi-nhuan-c10124',
#   'job_category_count': '7'},
#  {'id': 10125,
#   'name': 'Sản phẩm công nghiệp',
#   'alias': 'san-pham-cong-nghiep',
#   'access_url': '/tim-viec-lam-san-pham-cong-nghiep-c10125',
#   'job_category_count': '187'},
#  {'id': 10113,
#   'name': 'Hàng cao cấp',
#   'alias': 'hang-cao-cap',
#   'access_url': '/tim-viec-lam-hang-cao-cap-c10113',
#   'job_category_count': '53'}]

# %%
itpm_js = read_json('itphanmem')

# %%
sum([len(item) for item in itpm_js])
# Out:
# 3075

# %%
itpm_js[0]
# Out:
# [{'url': 'https://www.topcv.vn/viec-lam/nhan-vien-seo-web/1011826.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên SEO Web',
#   'job_deadline': 'Hạn nộp hồ sơ: 07/06/2023',
#   'company_name': 'CÔNG TY TNHH XUẤT NHẬP KHẨU THƯƠNG MẠI YÊN PHÁT',
#   'job_salary': '10 - 15 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hà Nội: Nhà A14 ngõ 20 Phố Huy Du, Phường Cầu Diễn, Quận Nam Từ Liêm, Nam Từ Liêm'],
#   'job_desc': '<div class="content-tab"><p>- Tối ưu website với các công cụ tìm kiếm Google\xa0<br>- Seo từ khóa website trên các công cụ tìm kiếm….\xa0<br>- Seo mạng xã hội, thiết lập và quản trị các trang mạng xã hội của công ty…<br>- Quảng bá dịch vụ sản phẩm của công ty trên các diễn đàn, blog, mạng xã hội,...\xa0<br>- Lập kế hoạch phân tích đánh giá từ khóa, đánh giá thị trường thông qua mức độ tìm kiếm từ khóa\xa0<br>- Thực hiện chiến dịch xây dựng link liên kết, hệ thống website của công ty\xa0<br>- Sử dụng các công cụ hỗ trợ để đẩy mạnh kết quả SEO\xa0<br/>- Theo dõi thứ hạng từ khóa, lập báo cáo thứ hạng từ khóa</br></br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Có kiến thức cơ bản về kỹ năng onpage, offpage)\xa0<br/>- Sử dụng thành thạo các công cụ, mạng xã hội bloger, facebook,\xa0<br/>- Có kỹ năng làm việc với wordpress, blogsport,..<br/>- Kinh nghiệm làm trong lĩnh vực SEO từ 1 năm \xa0trở lên<br/>- Đã từng SEO lên top các từ khóa trước đó(Trình bày trong CV)\xa0<br/>- Trung thực, nhiệt tình, năng động và có trách nhiệm với công việc - Khả năng làm việc độc lập, theo nhóm</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/middle-java-developer/1011456.html?ta_source=JobSearchList',
#   'job_title': 'Middle Java Developer',
#   'job_deadline': 'Hạn nộp hồ sơ: 07/06/2023',
#   'company_name': 'Công ty Cổ Phần Giải pháp Công nghệ ITE',
#   'job_salary': '15 - 25 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '2 năm',
#   'job_addresses': ['- Hà Nội: Tầng 5, tòa Anh Minh, 36 Hoàng Cầu, Đống Đa'],
#   'job_desc': '<div class="content-tab"><p>- Thiết kế, triển khai, vận hành và bảo trì các phần mềm hệ thống<br>- Xây dựng tài liệu đặc tả kỹ thuật<br>- Phối hợp chặt chẽ với các bộ phận khác (QA, Tech Support,...) để phát hiện và xử lý lỗi phần mềm một cách hiệu quả</br></br></p></div>',
#   'job_req': '<div class="content-tab"><p><strong>Yêu cầu tối thiểu:</strong><br>- Có từ 2 năm kinh nghiệm lập trình Java, có hiểu biết về các Framework: Spring, Hibernate<br>- Có kiến thức về System, Monitoring, Logging là 1 lợi thế<br>- Có kinh nghiệm với NoSQL (Redis, MongoDB), các hệ thống Message Queue (Kafka, RabbitMQ) là 1 lợi thế<br>- Có kinh nghiệm làm việc với hệ thống cơ sở dữ liệu SQL Server / MySQL / MongoDB / ElasticSearch là 1 lợi thế<br/>- Có kinh nghiệm làm việc trên môi trường UNIX / Linux là 1 lợi thế</br></br></br></br></p><p><strong>Khuyến khích:</strong><br/>- Ưu tiên ứng viên có kinh nghiệm làm việc với Microservices<br/>- Có kiến thức về Docker và Kubernetes<br/>- Có kiến thức về bảo mật và tối ưu hệ thống<br/>- Đã từng tham gia dự án trong ngành tài chính, ngân hàng, viễn thông\xa0<br/></p><p><strong>Kỹ năng mềm:\xa0</strong><br/>- Tư duy lập trình hướng đối tượng tốt<br/>- Sẵn sàng và tích cực học hỏi công nghệ và kiến thức mới<br/>- Có kỹ năng làm việc độc lập và theo nhóm<br/>- Có khả năng sử dụng Tiếng Anh trong công việc.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/lap-trinh-vien-frontend-frontend-developer-thu-nhap-upto-25m-hoac-thoa-thuan/923318.html?ta_source=JobSearchList',
#   'job_title': 'Lập Trình Viên Frontend - Frontend Developer (Thu Nhập Upto 25M Hoặc Thỏa Thuận)',
#   'job_deadline': 'Hạn nộp hồ sơ: 15/06/2023',
#   'company_name': 'Công ty cổ phần truyền thông đa phương tiện Gia Minh',
#   'job_salary': 'Tới 25 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hà Nội: Tòa Hội nhà báo Việt Nam, Dương Đình Nghệ, Yên Hòa, Cầu Giấy, Hà Nội, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p>• Tham gia phát triển các sản phẩm phục vụ cho hàng trăm nghìn khách hàng về các mảng website thương mại điện tử, quản lý bán hàng.</p><p>• Tham gia xây dựng sản phẩm product của công ty, build hệ thống web tự động cho các shop bán hàng</p><p>• Xây dựng và tối ưu hóa ứng dụng website để mang lại trải nghiệm tuyệt vời cho hàng triệu người dùng.</p><p>• Tham gia nghiên cứu và ứng dụng các công nghệ mới vào sản phẩm.</p><p>• Phối hợp cùng đội ngũ BA phân tích, thiết kế, đưa ra giải pháp để phát triển sản phẩm đáp ứng đúng, đủ, tiện các yêu cầu của người dùng.</p><p>• Phát triển các ứng dụng trên nền tảng bán hàng Shopify</p></div>',
#   'job_req': '<div class="content-tab"><p>• Có ít nhất 01 năm kinh nghiệm làm việc với ReactJS, Hooks, Redux, Fetch/ Axios, Functional Programing.</p><p>• Sử dụng thành thạo JavaScript ES5/ES6+, HTML5, CSS3 , Bootstrap 3/4, Webpack.</p><p>• Có kinh nghiệm làm việc với APIs.</p><p>• Hiểu biết về thiết kế giao diện và các công nghệ phát triển web hiện đại.</p><p>• Sử dụng thành thạo GIT các phần mềm liên quan phục vụ công việc lập trình.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/mobile-developers/999774.html?ta_source=JobSearchList',
#   'job_title': 'Mobile Developers',
#   'job_deadline': 'Hạn nộp hồ sơ: 10/06/2023',
#   'company_name': 'VNPT Technology - Công ty Cổ phần Công nghệ Công nghiệp Bưu chính viễn thông',
#   'job_salary': 'Tới 30 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Không yêu cầu kinh nghiệm',
#   'job_addresses': ['- Hà Nội: 124 Hoàng Quốc Việt, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p>- Nghiên cứu phát triển nền tảng, ứng dụng và hệ sinh thái IoT: ONE IoT Platform, Smart Home, Smart Farm\n</p><p>- Nghiên cứu phát triển các phần mềm hệ thống viễn thông và doanh nghiệp: Telco platform &amp; gateway, Enterprise platform, nền tảng Chuyển đổi số Doanh nghiệp\n</p><p>- Thiết kế &amp; phát triển hệ thống tải cao, hiệu năng cao quản lý 6.000.000 node mạng, đáp ứng 34.000.000 thuê bao và xử lý trên 1000 tỉ VND giao dịch mỗi tháng\n</p><p><br/></p><p>\n</p><p>\n</p><p>\n</p></div>',
#   'job_req': '<div class="content-tab"><p>- Tốt nghiệp ĐH chuyên ngành CNTT hoặc ĐTVT hoặc tương đương\n</p><p>- Thuần thục trong lĩnh vực lập trình di động: iOS (Objective-C,Swift) hoặc Android (Java, Kotlin), submit app lên store\n</p><p>- Hiểu sâu về thread, multi-threading và quản lý Memory\n</p><p>- Có hiểu biết về protocol, delegate và higher order functions, GCD\n</p><p>- Có hiểu biết về thiết kế UI, hiểu biết sâu về AFNetworking, Alamofire, JSON encoder, decoder\n</p><p>- Có khả năng lập trình Cross-platform (Flutter hoặc tương đương) là một lợi thế\n</p><p>- Có thể sử dụng tiếng Anh trong công việc\n</p><p>- Đam mê công nghệ\n</p><p>- Đọc và hiểu tài liệu kỹ thuật tiếng Anh\n</p><p>- Làm việc nhóm hiệu quả linh hoạt\n</p><p>- Trung thực và có tinh thần trách nhiệm\n</p><p>- Chủ động sáng tạo</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-marketing-online-google-ads-luong-cung-tu-9-15tr-thuong/92372.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Marketing Online (Google Ads) - Lương Cứng Từ 9 - 15Tr + Thưởng',
#   'job_deadline': 'Hạn nộp hồ sơ: 15/06/2023',
#   'company_name': 'CÔNG TY TNHH TRUYỀN THÔNG MEDIA POWER',
#   'job_salary': '10 - 15 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: số 1 Lương Yên, Hai Bà Trưng, Hà Nội, Hai Bà Trưng'],
#   'job_desc': '<div class="content-tab"><p>-\xa0 Xây dựng chiến lược quảng cáo trực tuyến, kế hoạch quảng cáo Google Adword (kế hoạch chi tiết từ chọn lọc key words, phân loại key words theo nhóm, chủ đề..)\xa0</p><p>- Theo dõi và tối ưu chiến dịch quảng cáo, tối ưu giá bid và tỷ lệ chuyển đổi</p><p>- Kiểm tra, đánh giá chất lượng viết quảng cáo, chất lượng website</p><p>- Rà soát, đánh giá và thay đổi để phù hợp với từng chiến dịch quảng cáo</p><p>- Trao đổi thêm khi phỏng vấn</p></div>',
#   'job_req': '<div class="content-tab"><p>- Có kinh nghiệm 06 tháng ở vị trí tương đương.\n</p><p>- Ưu tiên các bạn đã chạy ngân sách lớn.\n</p><p>- Biết cách thống kê, phân tích số liệu Adw để có điều chỉnh hợp lý, giúp giảm thiểu chi phí Adw, tăng hiệu quả quảng cáo\n</p><p>- Chăm chỉ, nhiệt huyết với công việc và có mong muốn gắn bó lâu dài với công ty\n</p><p>- Khả năng lập kế hoạch, triển khai &amp; hoàn thành công việc.\n</p><p>- Đạo đức tốt, nhiệt tình, yêu nghề, có trách nhiệm cao với công việc.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/sales-nhan-vien-kinh-doanh-cntt-phan-cung-va-phan-mem-lcb-10-15tr-hh/941688.html?ta_source=JobSearchList',
#   'job_title': 'Sales/ Nhân Viên Kinh Doanh CNTT Phần Cứng Và Phần Mềm (Lcb 10-15Tr + Hh)',
#   'job_deadline': 'Hạn nộp hồ sơ: 30/05/2023',
#   'company_name': 'Công ty Cổ phần Đầu tư và Phát triển Công nghệ TABViet',
#   'job_salary': 'Thoả thuận',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hồ Chí Minh: Tòa nhà Phương Nam – 219 Quốc lộ 13, Phường 26, Bình Thạnh'],
#   'job_desc': '<div class="content-tab"><p>- Xây dựng danh sách khách hàng, phụ trách các dự án độc lập\n</p><p>- Tìm kiếm và xúc tiến cơ hội kinh doanh\n</p><p>- Lập đơn đặt hàng/ hợp đồng cho khách hàng và thương lượng để ký kết đơn hàng/ hợp đồng\n</p><p>- Chăm sóc khách hàng và theo suốt quá trình thực hiện việc bán hàng\n</p><p>- Báo cáo kế hoạch và doanh số thực tế\n</p><p>- Hoàn thành mục tiêu doanh số theo chính sách kinh doanh\n</p><p>- Thực hiện sự phân công của cấp quản lý</p></div>',
#   'job_req': '<div class="content-tab"><p>- Tốt nghiệp các trường ĐH/CĐ khối ngành kinh tế hoặc các ngành nghề liên quan\n</p><p>- Đam mê kinh doanh, ưu tiên thành thạo tiếng Anh\n</p><p>- Tư duy nhanh nhạy, nắm bắt các vấn đề, nội dung mới tốt; khả năng xử lý tình huống tốt\n</p><p>- Có khả năng làm việc độc lập, theo nhóm, nhiệt tình, ham học hỏi\n</p><p>- Khả năng giao tiếp tốt, tự tin\n</p><p>- Kỹ năng sử dụng tin học văn phòng\n</p><p>- Kinh nghiệm: ít nhất 1 năm tại vị trí tương đương</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-phan-mem-sales-ban-le-cong-nghe-thong-tin-quan-7-thu-nhap-hap-dan-open-all-level/998323.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Kinh Doanh Phần Mềm/ Sales Bán Lẻ Công Nghệ Thông Tin - Quận 7 (Thu Nhập Hấp Dẫn, Open All Level)',
#   'job_deadline': 'Hạn nộp hồ sơ: 18/06/2023',
#   'company_name': 'CÔNG TY CỔ PHẦN CÔNG NGHỆ TIÊN PHONG - ITD GROUP',
#   'job_salary': 'Thoả thuận',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hồ Chí Minh: ITD Building, số 1 đường Sáng Tạo, KCX Tân Thuận, Quận 7'],
#   'job_desc': '<div class="content-tab"><p>Theo định hướng kinh doanh mới, song song việc kinh doanh về các giải pháp/ dự án tích hợp hệ thống, chúng tôi thành lập 1 team để tập trung vào thị trường cung cấp phần mềm/ bán lẻ thuộc lĩnh vực CNTT. Chúng tôi tìm kiếm người đồng hành ở <strong>cả 2 level: sales thực chiến và leader (trưởng nhóm/ trưởng phòng).</strong></p><p>Và đây là công việc bạn phụ trách:</p><ul><li><strong>Bạn có thể lựa chọn chỉ tập trung kinh doanh về bán lẻ/ phần mềm hoặc cả mảng dự án</strong></li><li>Lập kế hoạch và triển khai kinh doanh sản phẩm (hoặc dự án) CNTT cho khách hàng doanh nghiệp (hoặc chính phủ) lĩnh vực: viễn thông, sản xuất, bán lẻ, giao thông vận tải, ngân hàng, tiêu dùng nhanh ...</li><li>Thiết lập và duy trì các mối quan hệ hỗ trợ, hợp tác với cơ quan ban ngành, hãng/ đại lý phân phối sản phẩm</li><li>Quản trị hồ sơ thầu và hợp đồng (Ký hợp đồng, theo dõi quản lý quá trình triển khai dự án, xuất hóa đơn, thu hồi công nợ,…)</li><li>Đảm bảo các chỉ số kinh doanh được giao về doanh số, lợi nhuận, khách hàng</li><li>Thực hiện các nhiệm vụ khác theo phân công và điều động của GĐ Kinh doanh</li></ul></div>',
#   'job_req': '<div class="content-tab"><p><strong>Must have:</strong></p><ul><li><strong>Có kinh nghiệm làm việc tại công ty bán phần mềm hoặc công ty bán lẻ thiết bị CNTT\xa0</strong></li><li>Khi nêu vấn đề luôn kèm giải pháp</li><li>Giao tiếp tốt, tác phong tạo sự thiện cảm, tin tưởng cho khách hàng</li><li>Tự tin làm proposal, thuyết trình với khách hàng</li><li>Nếu ở level team leader/ manager: build/ manage team</li></ul><p><strong>Should have:</strong></p><ul><li>Giao tiếp tiếng Anh</li><li>Có sẵn mối quan hệ tốt với tệp khách hàng B2B</li></ul><p><strong>Nice have:</strong></p><ul><li>Có kinh nghiệm bán giải pháp/ dự án tích hợp (phần cứng và phần mềm)</li><li>Đã từng tham gia các gói thầu về cung cấp thiết bị CNTT</li><li>Có kiến thức về tech (giúp bạn dễ dàng tiếp cận khách hàng)</li></ul></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-content-marketing/1011710.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Content Marketing',
#   'job_deadline': 'Hạn nộp hồ sơ: 31/05/2023',
#   'company_name': 'CÔNG TY TNHH CASA BELLA',
#   'job_salary': 'Thoả thuận',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hồ Chí Minh: 102-104-106 Đường B2, Khu Đô Thị Sala, phường An Lợi Đô, Thủ Đức'],
#   'job_desc': '<div class="content-tab"><p>- Xây dựng, quản lý nội dung (bao gồm viết nội dung, trình bày nội dung, ý tưởng về hình ảnh) trên Fanpage, Website và nền tảng mạng xã hội khác;\n</p><p>- Biên tập nội dung truyền thông trên các kênh truyền thông của Công ty (Tin tức nội dung trên website, Nội dung trên mạng xã hội, Nội dung seeding, bài PR,…);\n</p><p>- Tham gia cùng team xây dựng và quản lý các chiến dịch Marketing, đóng góp các ý tưởng nội dung sáng tạo cho chiến dịch Marketing (online/offline);\n</p><p>- Cập nhật thường xuyên các tin tức mới để bổ sung vào ý tưởng và tăng thêm kho nội dung viết bài;\n</p><p>- Viết bài tối ưu SEO;.\n</p><p>- Tìm hiểu và update xu hướng content - Social trend nhằm sáng tạo nội dung phù hợp với hành vi của người dùng;\n</p><p>- Theo dõi, phân tích, và đánh giá các chỉ số đo lường hiệu quả của content marketing, và nghiên cứu insight khách hàng để tối ưu hiệu quả;\n</p><p>- Phối hợp với bộ phận thiết kế và các đơn vị khác có liên quan, để thực hiện các ấn phẩm POSM, ấn phẩm quảng cáo và những ấn phẩm truyền thông khác;\n</p><p>- Thực hiện theo yêu cầu quản lý trực tiếp. Báo cáo công việc tuần/tháng.</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p></div>',
#   'job_req': '<div class="content-tab"><p>- Kinh nghiệm 1-2 năm ở vị trí tương tự . Ưu tiên có kinh nghiệm trong ngành nội thất;\n</p><p>- Có khả năng học hỏi và khả năng tự học cao;\n</p><p>- Kỹ năng viết, biên tập\n</p><p>- Kỹ năng SEO\n</p><p>- Sáng tạo, tư duy ngôn ngữ và hình ảnh tốt\n</p><p>- Có khiếu thẩm mỹ, nhiều ý tưởng sáng tạo là một lợi thế\n</p><p>- Kỹ năng tổ chức, lập kế hoạch, quản lý và báo cáo\n</p><p>- Kỹ năng giao tiếp và làm việc nhóm tốt</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p><p>\n</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-quan-tri-he-thong-system-admin/1011478.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Quản Trị Hệ Thống/ System Admin',
#   'job_deadline': 'Hạn nộp hồ sơ: 05/06/2023',
#   'company_name': 'Công ty CP Công nghệ phần mềm và nội dung số OSP',
#   'job_salary': 'Tới 25 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '2 năm',
#   'job_addresses': ['- Hà Nội: Tầng 4, Tòa Garden Hill, 99 Trần Bình, Nam Từ Liêm'],
#   'job_desc': '<div class="content-tab"><p>- Quản trị các hạ tầng hệ thống phần cứng CNTT bao gồm các thiết bị máy chủ (Dell, HP, Super Micro, DGX), firewall, switch<br>- Quản trị, vận hành và triển khai các hệ thống máy chủ trên nền tảng Linux, Windows và hệ thống ảo hóa VMWare, XenCitrix. Đảm bảo các hệ thống hoạt động ổn định, an toàn và liên tục<br>- Tham gia triển khai các dự án nâng cấp các hệ thống công nghệ đáp ứng nhu cầu phát triển của công ty<br>- Giám sát và xử lý các sự cố của các thiết bị mạng, máy chủ, CSDL.<br>- Định kỳ rà soát, tối ưu hệ thống<br>- Các công việc khác theo yêu cầu của quản lý cấp trên</br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Có ít nhất 2 năm kinh nghiệm ở vị trí System Admin<br>- Có kiến thức cơ bản tốt Linux, Windows, Network. Cài đặt, vận hành, tối ưu HĐH Linux (CentOS, Ubuntu Server), các phần mềm OpenSource trên môi trường Linux<br/>- Thành thạo về các hệ thống ảo hóa: VMWare, Xen Citrix<br/>- Có kiến thức về ứng dụng: web server, cache/queue server (Redis, Kafka), database (Oracle, MySQL, MongoDB)<br/>- Có kinh nghiệm làm việc với các automation tools: Ansible, Salt<br/>- Có kinh nghiệm triển khai các hệ thống monitoring: Nagios, Icinga, Grafana, Zabbix.<br/>- Có kinh nghiệm tối ưu hệ thống, bảo mật hệ thống, cân bằng tải và xử lý sự cố.<br/>- Thành thạo ít nhất 1 ngôn ngữ lập trình: Bash, Python, PHP.\xa0<br/>- Hiểu biết về Cloud, Container, Kubernetes; các chính sách bảo mật, bản quyền và luật pháp;<br/>- Chủ động và có tinh thần trách nhiệm cao trong công việc;</br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nlp-engineer-mid-senior/889448.html?ta_source=JobSearchList',
#   'job_title': 'Nlp Engineer (Mid-Senior)',
#   'job_deadline': 'Hạn nộp hồ sơ: 05/06/2023',
#   'company_name': 'CÔNG TY TNHH CÔNG NGHỆ GIA ĐÌNH (FTECH CO., LTD)',
#   'job_salary': 'Tới 2,500 USD',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 434 Trần Khát Chân, Phố Huế, Hai Bà Trưng',
#    '- Đà Nẵng: Tầng 17, tòa nhà Thành Lợi 2, số 3 Lê Đình Lý, Vĩnh Trung, Thanh Khê'],
#   'job_desc': '<div class="content-tab"><p>• Design, implement and maintain libraries, and develop new algorithms and services for: Named Entity Extraction, Language Detection, Emotion/Sentiment Prediction, Keyword and Topic Extraction</p><p>• Deep-learning Chatbots and dialog modeling</p><p>• Intent detection, Query Parsing, Semantic mapping</p><p>• Manage interdisciplinary projects combining different teams within the AI Center and the company.</p><p>• Implement and provide best practices for maintainable software development, including deployment process, documentation, and adherence to and improvement of coding standards.</p><p>• Mentor interns.</p></div>',
#   'job_req': '<div class="content-tab"><p>• BSc or MSc in computer science or a related degree, with strong software engineering and modern NLP components.</p><p>• 1+ years of industrial experience in NLP and modern machine learning algorithms, such as deep learning.</p><p>• Solid experience in software engineering: modern software development practices and tools, concurrent and distributed programming, operating systems, computer networks, database systems.</p><p>• Fully proficient in Python and/or modern C++ with exposure to functional &amp; object-oriented programming paradigms.</p><p>• Experienced with high performance / GPU computing and/ or real-time systems.</p><p>Our Software Stack:</p><p>• Languages for scientific computing: Python</p><p>• Frameworks: OpenCV, CUDA, FFmpeg, Tensorflow, PyTorch, NumPy, scikit-learn, Caffe</p><p>• Code base: Git with GitLab</p><p>• Productivity: Notion, Google Apps</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/it-manager/1010297.html?ta_source=JobSearchList',
#   'job_title': 'IT Manager',
#   'job_deadline': 'Hạn nộp hồ sơ: 05/06/2023',
#   'company_name': 'Công ty Cổ phần Quốc tế Telehouse Việt nam',
#   'job_salary': 'Trên 18 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '4 năm',
#   'job_addresses': ['- Hà Nội: Công ty cổ phần quốc tế Telehouse Việt Nam - Tầng 4, Tòa nhà FPT, số 17 Phố Duy Tân, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p>- Quản trị, vận hành toàn bộ hệ thống CNTT của công ty để đảm bảo phục vụ công việc sản xuất và kinh doanh.<br>o Khắc phục sự cố lớn về hệ thống mạng, bảo mật.<br>o Đảm bảo và cải thiện hệ thống bảo mật CNTT (Firewall / IDS / IPS ..)<br>o Khắc phục các sự cố hệ thống máy chủ, ảo hóa, lưu trữ của công ty.<br>o Quản trị các hệ thống giám sát của công ty như Solarwinds, Centreon…<br>o Kết hợp với bộ phận CNTT của công ty liên quan để đảm bảo hệ thống CNTT của công ty được hoạt động liền mạch.<br>o Xây dựng qui trình thực hiện cho L1 support và chuyển giao, đào tạo cho cán bộ IT NOC để thực hiện công việc.<br/>o Hỗ trợ với vai trò L2, L3 support cho các cán bộ L1 support.\xa0<br/>- Hoạch định, xây dựng, đề xuất và triển khai các hệ thống mới phục vụ việc phát triển của công ty.<br/>- Nghiên cứu Công nghệ mới và xây dựng các dịch vụ mới để cung cấp cho khách\xa0<br/>- Hỗ trợ khách hàng khi có yêu cầu về dịch vụ công nghệ.<br/>- Thực hiện các công việc khác liên quan đến công nghệ và dịch vụ được phân công.</br></br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Giới tính: Nam<br/>- Kinh nghiệm: từ 4 năm trở lên \xa0trong lĩnh vực công nghệ. \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0<br/>- Sử dụng tiếng Anh thành thạo (nói, viết).\xa0<br/>- Có kỹ năng thuyết trình tốt.</p></div>',
#   'job_level': 'Trưởng nhóm'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-quan-tri-website/1010663.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Quản Trị Website',
#   'job_deadline': 'Hạn nộp hồ sơ: 05/06/2023',
#   'company_name': 'Công ty CP Chiếu Sáng Shine Light Việt Nam',
#   'job_salary': '7 - 10 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: C902 KĐT Gleximco Lê Trọng Tấn - Dương Nội - Hà Đông, Hà Đông'],
#   'job_desc': '<div class="content-tab"><p>Quản trị website:<br>Bạn cần cập nhật nội dung mới, chính sách hoặc thông tin về sản phẩm/dịch vụ của công ty lên trang web.<br>Bạn cần điều chỉnh giao diện, cài đặt các plugin và thực hiện các bảo trì định kỳ cho trang web để đảm bảo trang web hoạt động một cách trơn tru và hiệu quả.<br>Làm hình ảnh sản phẩm:<br>Sử dụng thành thạo Photoshop<br>Sử dụng hình ảnh đã có sẵn và chỉnh sửa lại hình ảnh chuẩn SEO</br></br></br></br></br></p><p>Được hướng dẫn cách chọn lọc hình ảnh phù hợp với website</p><p>\xa0</p></div>',
#   'job_req': '<div class="content-tab"><ul><li>Giới tính : Nam giới</li><li>Đã có kinh nghiệm dưới 1 năm trong lĩnh vực thiết kế website trên nền tảng wordfress</li><li>Quản trị website và chăm sóc website</li><li>Tính cánh: Thật thà, ham học hỏi, có đam mê về công nghệ mới</li></ul></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/unity-game-developer-upto-1500-ha-noi/684524.html?ta_source=JobSearchList',
#   'job_title': 'Unity Game Developer (Upto 1500$) Ha Noi',
#   'job_deadline': 'Hạn nộp hồ sơ: 05/06/2023',
#   'company_name': 'BBOLD JSC',
#   'job_salary': '400 - 1,500 USD',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: 78 Nguyễn Khang - Cầu Giấy - Hà Nội, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p><b>- Công ty BBOLD mở đợt tuyển dụng vị trí UNITY GAME DEVELOPER cho tất cả các level: Intern, Fresher, Junior, Senior</b></p><p>-Xây dựng và phát triển các dự án mobile game bằng Unity trên Android, iOS.\n</p><p>-Tham gia đóng góp xây dựng, cải tiến ý tưởng sản phẩm game để tăng trải nghiệm người dùng.\n</p><p>-Kết hợp với các bộ phận Artist, Product owner, GD để sản xuất các game mobile chất lượng và hữu ích đến người dùng</p></div>',
#   'job_req': '<div class="content-tab"><p>\xa0- Có đam mê, tư duy và khả năng tự học tốt.</p><p>- Ưu tiên ứng viên có kinh nghiệm làm việc với UNITY 3 tháng trở lên.</p><p>- Đã có sản phẩm Game Product demo là một điểm cộng.</p><p>- Đọc hiểu tài liệu tiếng Anh tốt.</p><p>- Có khả năng làm việc nhóm.</p><p>- Tốt nghiệp CNTT ĐH Bách Khoa, ĐH KHTN, ĐH Công nghệ, HV Bưu Chính Viễn Thông và các trường CNTT …</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/web-frontend-developer-upto-28m/1011461.html?ta_source=JobSearchList',
#   'job_title': 'Web Frontend Developer Upto 28M',
#   'job_deadline': 'Hạn nộp hồ sơ: 10/06/2023',
#   'company_name': 'Công ty trách nhiệm hữu hạn Reviewty',
#   'job_salary': 'Tới 28 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: loor 13, Office Building 1 – Sun Square building, No. 21 Le Duc Tho Street, My Dinh 2 Ward, Nam Tu Liem District, Hanoi City, Nam Từ Liêm'],
#   'job_desc': '<div class="content-tab"><p>• Develop user-facing web applications using HTML, CSS, JavaScript, and TypeScript (Next.js, React, etc.).<br>• Collaborate with UX/UI designers to translate designs into high-quality, responsive web interfaces.<br>• Write, review, and maintain code, ensuring adherence to the company\'s established coding quality standards.<br>• Develop and execute unit tests, ensuring all test cases are tested and passed before release for testing.<br>• Proactively recommend innovative solutions for clients\' projects.<br>• Optimize application performance, quality, and responsiveness.<br>• Assist in maintaining code quality and organization.</br></br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>• Minimum of 3 years of experience working as a Frontend (Web) Developer.<br/>• Strong knowledge of CSS, JavaScript, and TypeScript (Next.js, React, etc.).<br/>• Great sense of design is a plus.<br/>• Experience working with GraphQL is a plus.<br/>• Experience in a start-up company is a plus.<br/>• Intermediate level of reading and speaking English is a plus.<br/>• Familiarity with Agile Development methodologies is preferred.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/frontend-developer-reactjs/1010790.html?ta_source=JobSearchList',
#   'job_title': 'Frontend Developer ( Reactjs)',
#   'job_deadline': 'Hạn nộp hồ sơ: 05/06/2023',
#   'company_name': 'CÔNG TY CỔ PHẦN INTELLIFE',
#   'job_salary': '15 - 25 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: Tầng 4, Tháp B, số 19 Nguyễn Trãi, Thanh Xuân'],
#   'job_desc': '<div class="content-tab"><p>- Tham gia phát triển website TMĐT và các websites khác của công ty \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0<br>- Duy trì vận hành, vá lỗi cho các website của công ty \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0<br>- Cập nhật xu hướng công nghệ phục vụ cho công việc \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0<br>- Định kỳ báo cáo tiến độ theo yêu cầu</br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Tốt nghiệp đại học chuyên ngành CNTT \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0<br>- Tối thiểu 01 năm kinh nghiệm lập trình Front-End<br>- Có kinh nghiệm làm việc thực tế và sử dụng hiệu quả ReactJS, React Hooks, Redux<br>- Có kiến thức vững chắc về JavaScript, ES6+, HTML5, CSS3.<br/>- Có kinh nghiệm làm việc với Rest API, GraphQL.<br/>- Có kinh nghiệm lập trình Responsive Design, Accessibility.<br/>- Thành thạo công cụ quản lý code git/svn.<br/>- Hiểu về hệ thống kho vận, sản phẩm và dịch vụ bán lẻ, có kinh nghiệm triển khai các sản phẩm TMĐT là lợi thế</br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/cong-tac-vien-mobile-flutter/762718.html?ta_source=JobSearchList',
#   'job_title': 'Cộng Tác Viên Mobile (Flutter)',
#   'job_deadline': 'Hạn nộp hồ sơ: 30/06/2023',
#   'company_name': 'Công ty Cổ phần đầu tư Công Nghệ và Thương Mại Softdreams',
#   'job_salary': '4 - 8 triệu',
#   'job_type': 'Bán thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: Nhà khách ATS, Số 8 Phạm Hùng, Nam Từ Liêm, HN, Nam Từ Liêm'],
#   'job_desc': '<div class="content-tab"><p>- Tham gia xây dựng sản phẩm phần mềm của công ty, bao gồm:<br>+ Phát triển, nâng cấp ứng dụng Mobile đang triển khai cho hơn 150.000 người dùng cá nhân tại Việt Nam.<br>+ Xây dựng các ứng dụng Mobile phục vụ cho hơn 100.000 khách hàng doanh nghiệp Việt Nam đang sử dụng sản phẩm, dịch vụ phần mềm của SDS, cụ thể Phần mềm Hóa đơn điện tử EasyInvoice, Phần mềm Kế toán EasyBooks, Phần mềm chữ ký số trên Mobile EasyCA<br>- Đồng thời tham gia nghiên cứu, đề xuất, phát triển (R&amp;D) các giải pháp kỹ thuật, các công nghệ áp dụng cho ứng dụng Mobile, đặc biệt là các công nghệ trên Framework Flutter.<br>- Tham gia cùng phòng phát triển Mobile trong việc định hình, đề xuất, xây dựng các kế hoạch công việc cho phòng. Tham gia định hướng chiến lược và phát triển sản phẩm của công ty.<br>- Nhận công việc, báo cáo kết quả làm việc với Quản lý trực tiếp.</br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Ít nhất 3 tháng kinh nghiệm<br>- Hiểu biết ít nhất một trong những ngôn ngữ lập trình sau: Dart/Flutter, java/kotlin/android; Objective C,/Swift/iOS.<br/>- Có tư duy logic, thiết kế cho ứng dụng Mobile.<br/>- Có tinh thần trách nhiệm cao, đảm bảo hoàn thành công việc hiệu quả, đúng tiến độ.<br/>- Có khả năng làm việc theo nhóm và làm việc độc lập. Ưu tiên ứng viên có kinh nghiệm làm việc với các quy trình như Scrum, Agile, OKRs.<br/>- Có khả năng đọc hiểu, tìm kiếm thông tin bằng tiếng Anh.<br/>- Sẵn sàng làm việc trong môi trường đa văn hóa, áp lực cao.<br/>- Chủ động, sáng tạo trong công việc.<br/>- Sẵn sàng tiếp cận và học hỏi những công nghệ mới.<br/>- Có sản phẩm trên AppStore/CHPlay là 1 lợi thế.<br/>- Ưu tiên ứng viên có kinh nghiệm phát triển hybrid app bằng React Native, Flutter,...</br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/lap-trinh-vien-app-mobile-react-native/1011083.html?ta_source=JobSearchList',
#   'job_title': 'Lập Trình Viên App Mobile React Native',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'CÔNG TY CỔ PHẦN TẬP ĐOÀN CÔNG NGHỆ BATTECH',
#   'job_salary': 'Tới 35 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '2 năm',
#   'job_addresses': ['- Hà Nội'],
#   'job_desc': '<div class="content-tab"><ul><li>Tham gia team phát triển phần mềm ứng dụng trên nền tảng Mobile</li><li>Khắc phục sự cố giao diện phần mềm.</li><li>Phối hợp với đội ngũ Back-end trong thiết kế API.</li><li>Tham gia vào quá trình nghiên cứu và phát triển tính năng phần mềm.</li><li>Thực hiện các công việc được phân công bởi quản lý trực tiếp.</li></ul></div>',
#   'job_req': '<div class="content-tab"><p>- Có từ 2 năm kinh nghiệm trở lên phát triển ứng dụng di động (React Native)<br>- Có kiến thức về ngôn ngữ JavaScript và TypeScript<br>- Có kinh nghiệm với các thư viện quản lý state (Redux), Restful API, Push notification…<br>- Có kinh nghiệm với các quy trình xây dựng về thiết lập, định cấu hình và xuất bản ứng dụng React Native lên App Store và Google Play<br>- Kiến thức vững chắc về các nguyên tắc, mẫu thiết kế UI trên thiết bị di động và các phương pháp hay nhất<br>- Kiến thức vững chắc về SDK Android hoặc iOS và cách xử lý các kích thước màn hình khác nhau<br>- Làm quen với các công cụ phiên bản mã (Git)</br></br></br></br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/frontend-developer-mobile-ios/1010941.html?ta_source=JobSearchList',
#   'job_title': 'Frontend Developer (Mobile/IOS)',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 45 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>Nghiên cứu, phát triển các công nghệ mới và ứng dụng vào các dự án Mobile của Khách hàng<br>Hỗ trợ QA/Tester và khách hàng trong quá trình kiểm tra &amp; nghiệm thu ứng dụng mobile<br>Tham gia trao đổi và làm việc với khách hàng</br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>Hơn 3 năm kinh nghiệm phát triển iOS sử dụng Swift, RxSwift<br>Am hiểu về design pattern, architecture<br>Có kiến \u200b\u200bthức Unit Testing, RESTful api và các thư viện của bên thứ ba</br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/frontend-developer-mobile-android/1010943.html?ta_source=JobSearchList',
#   'job_title': 'Frontend Developer (Mobile/Android)',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 45 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>Nghiên cứu, phát triển các công nghệ mới và ứng dụng vào các dự án Mobile của Khách hàng<br>Hỗ trợ QA/Tester và khách hàng trong quá trình kiểm tra &amp; nghiệm thu ứng dụng mobile<br>Tham gia trao đổi và làm việc với khách hàng</br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>Hơn 3 năm kinh nghiệm phát triển Android sử dụng Kotlin<br>Có kinh nghiệm với các framework và thư viện Android (ví dụ: Android SDK, Jetpack, Retrofit)<br>Am hiểu về design pattern, architecture<br>Có kiến \u200b\u200bthức về Unit Testing, RESTful api và các thư viện của bên thứ ba</br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/business-analyst/1010964.html?ta_source=JobSearchList',
#   'job_title': 'Business Analyst',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 35 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>● Thu thập, tìm hiểu nghiệp vụ và yêu cầu hệ thống từ phía khách hàng/nội bộ công ty</p><p>● Hỗ trợ, khuyến nghị khách hàng/nội bộ công ty trong việc định hướng yêu cầu của sản phẩm</p><p>● Tạo, quản lý hệ thống tài liệu: tài liệu đặc tả hệ thống (System Requirement Specification), danh sách các tính năng (Feature List), danh sách kịch bản sử dụng (Use case list), kịch bản chi tiết (Use case detail), ràng buộc nghiệp vụ (General Business Rules), bố cục sản phẩm (Wireframe),...</p><p>● Hỗ trợ Quản lý dự án trong việc xác định phạm vi công việc, lập kế hoạch, trong quá trình nghiệm thu sản phẩm, xác định phân tích phản hồi của khách hàng/nội bộ công ty</p><p>● Làm cầu nối giữa bộ phận sản xuất, phát triển sản phẩm với khách hàng và ngược lại.</p></div>',
#   'job_req': '<div class="content-tab"><p>Tốt nghiệp Đại học các ngành liên quan đến toán, kinh tế, khoa học máy tính, công nghệ thông tin, hoặc tương đương trong và ngoài nước.<br>Có từ 3 năm kinh nghiệm ở vị trí chuyên viên phân tích nghiệp vụ mảng phần mềm. Trên 1 năm kinh nghiệm làm việc với domain Banking.<br>Có kiến thức cơ bản về dữ liệu và truy vấn dữ liệu.<br>Ưu tiên ứng viên có kinh nghiệm triển khai, quản lý dự án;<br>Khả năng giao tiếp, truyền tải thông tin.<br>Tiếng Anh thành thạo 4 kỹ năng.</br></br></br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/manual-tester/1010983.html?ta_source=JobSearchList',
#   'job_title': 'Manual Tester',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 35 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 119 Trần Duy Hưng, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p>• Tìm hiểu và phân tích yêu cầu của dự án.<br>• Viết test case, chuẩn bị và thực hiện integration test, system test.<br>• Tổng hợp lỗi và phối hợp với đội phát triển thực hiện sửa lỗi.<br>• Đánh giá chất lượng của dự án dựa vào kết quả kiểm thử.</br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>Có từ 3 năm kinh nghiệm trong việc kiểm thử phần mềm.\xa01 năm kinh nghiệm trở lên trong lĩnh vực Ngân hàng.<br>Có kinh nghiệm với thử nghiệm hệ thống, E2E và API<br>Có kinh nghiệm với Mobile testing<br>Quen thuộc với Test Management tool như Jira, Xray</br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/technical-leader/1011061.html?ta_source=JobSearchList',
#   'job_title': 'Technical Leader',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 45 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Trên 5 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>• Develop and drives the product development from IT side.<br>• Provide constant feedback to the team and helps the team to follow this vision by Business PO.<br>• Ensure that the team knows with accurate detail what they are expected to build.<br>• Must develop a deep understanding of the target market/industry, build close relationships with key stakeholders, and define clearly the business strategy for the product with business.<br>• Set clear product vision and communicate ‘the story’ effectively to key stakeholders, developers and the test of the team<br>• Own the end-to-end product strategy from inception, and determine business value once solution enters production<br>• Build backlog of product features, i.e. write user stories and acceptance criteria together with his/her work-cell team<br/>• Continuously develop backlog ensuring all items are clearly described, estimated and prioritized<br/>• Drive sprints and release plans together with Scrum Master<br/>• Exercise strong decision making mandate from business stakeholders and IT team for technical feasibility<br/>• Work with Digital Solution Architect to build a modular &amp; reusable solution</br></br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>Skill:<br/>- 8-10 years experience in technical leadership<br/>- Experience in leading and managing technical teams in the delivery of system/software development project<br/>- Mastering in programming language related to application development (HTML/CSS, Javascript, React, nodeJS, Java)<br/>- Experience in developing/deploying AWS service<br/>- Experience in the full development life cycle from requirements analysis through coding and release<br/>- Experience in both architecture and implementation-level software design<br/>- Knowledge in Martech would be a plus<br/>- Collaborating effectively with the Product team, IT team, stakeholder, and management team<br/>- Proficient in Agile Methodology, Scrum framework<br/>- Project management experience</p><p>Qualifications:<br/>- Bachelor\'s degree or higher in computer science or related fields</p></div>',
#   'job_level': 'Trưởng nhóm'},
#  {'url': 'https://www.topcv.vn/viec-lam/chuyen-vien-phan-tich-nghiep-vu-business-analyst/1011074.html?ta_source=JobSearchList',
#   'job_title': 'Chuyên Viên Phân Tích Nghiệp Vụ ( Business Analyst )',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 35 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Trên 5 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>- Receive requests to develop and improve products, processes, and features from business units. Analyze and advise business units the most effective plan to fulfill requirements.<br>- Talk to the development department to design a solution for these requirements. Develop detailed requirements specification in a language suitable for programmers (developer); Ensure development requirements are clear and technologically feasible.<br>- Participate in coordination with the professional unit to check the development results, to ensure that the application meets the requirements agreed with the business unit.<br>- Prepare and issue user manuals for technology products.<br>- Participate in direct training on products and technology features for IT support department and professional staff if necessary.</br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>Skill:<br>- Excellent in verbal and written skill<br>- Base IT<br/>- A good understanding of business and respective functional domain<br/>- Good skill at Using tool for business modelling, business and technical workflow/diagram, creating mockup/wireframe.<br/>- Experience in Martech is an advance<br/>- Good skill at Analysis, design, communication and presentation<br/>- Experience with Agile methodology, scrum framework<br/>Qualification:<br/>- Graduated from University or above<br/>- Business analysis certificate preferred<br/>- TOEIC 600+ or equivalent<br/>Work Experience<br/>- Minimum 5 years in a related field</br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/fullstack-developer/1011124.html?ta_source=JobSearchList',
#   'job_title': 'Fullstack Developer',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 45 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>- Nghiên cứu, phát triển, xây dựng hệ thống.</p><p>- Tham gia vào phân tích, thiết kế các tính năng của phần mềm.</p><p>- Hỗ trợ, cải thiện, tối ưu hóa hệ thống trong quá trình vận hành.</p></div>',
#   'job_req': '<div class="content-tab"><p>- 3 đến 5 năm kinh nghiệm làm việc có liên quan về Java, Javascript, Angular JS or React JS, HTML/HTML5 and CSS<br>- Có kinh nghiệm về Microservice<br>- Hiểu biết vững chắc về thiết kế và triển khai API<br>- Có kinh nghiệm về JWT và OAuth2.<br>- Có kinh nghiệm về Phát triển phần mềm Agile với sự hiểu biết sâu sắc về các nguyên tắc, thực tiễn và phương pháp Scrum của Agile.<br>- Có kinh nghiệm về OOP và design pattern<br>- Ưu tiên nếu bạn có kinh nghiệm phát triển/triển khai AWS<br/>Trình độ bắt buộc:<br/>- Bằng cử nhân trở lên về khoa học máy tính hoặc các lĩnh vực liên quan.</br></br></br></br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/mobile-developer-android-ios/1011268.html?ta_source=JobSearchList',
#   'job_title': 'Mobile Developer (Android/IOS)',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty CP Phần mềm MOR',
#   'job_salary': 'Tới 45 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 6 Quang Trung, Hoàn Kiếm'],
#   'job_desc': '<div class="content-tab"><p>• Tham gia phân tích requirement, thiết kế hệ thống; Nghiên cứu và áp dụng các công nghệ mới</p><p>• Tham gia vào các dự án với nhiều đối tác lớn cũng như phát triển sản phẩm công ty</p><p>• Làm việc trong môi trường chuyên nghiệp, nhiều cơ hội thăng tiến</p><p>• Cải tiến, nâng cao chất lượng các dự án hiện có</p></div>',
#   'job_req': '<div class="content-tab"><p>- Có 3-5 năm kinh nghiệm về Android/IOS<br>- Có kinh nghiệm lập trình Android Java, Kotlin hoặc iOS Swift/Object C Cocoa<br>- Kiến thức về các công nghệ, kiến \u200b\u200btrúc và xu hướng di động mới nhất.<br>- Kinh nghiệm làm việc trong một nguồn được kiểm soát<br>- Kiến thức tốt về vòng đời phát triển ứng dụng di động<br>- Hiểu biết vững chắc về thiết kế và triển khai API<br>- Có kinh nghiệm về các giao thức xác thực (JWT và OAuth2)<br/>- Có kinh nghiệm về Phát triển phần mềm Agile với sự hiểu biết sâu sắc về các nguyên tắc, thực tiễn và phương pháp Scrum của Agile.<br/>- Có kinh nghiệm về OOP và design pattern<br/>trình độ:<br/>- Bằng cử nhân trở lên về khoa học máy tính hoặc các lĩnh vực liên quan</br></br></br></br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/technical-lead-frontend/1011258.html?ta_source=JobSearchList',
#   'job_title': 'Technical Lead Frontend',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'VNDIRECT',
#   'job_salary': 'Thoả thuận',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '5 năm',
#   'job_addresses': ['- Hà Nội'],
#   'job_desc': '<div class="content-tab"><p><strong>JOB DESCRIPTION</strong></p><p>• Lead a team of developers in building and maintaining web applications using modern frontend technologies.</p><p>• Collaborate with cross-functional teams to develop and implement new features.</p><p>• Develop and maintain coding standards, best practices, and documentation.</p><p>• Manage project timelines and deliverables, ensuring on-time delivery of high-quality products.</p><p>• Conduct code reviews to maintain code quality and ensure adherence to coding standards.</p><p>• Implement effective development processes and tools to streamline development and improve performance.</p><p>• Mentor and coach developers to improve technical skills and ensure job satisfaction.</p></div>',
#   'job_req': '<div class="content-tab"><p><strong>JOB REQUIREMENT</strong></p><p>• Bachelor\'s degree in Computer Science, Computer Engineering or related field.</p><p>• Minimum of 5 years of experience in frontend web development.</p><p>• Experience leading a team of developers in delivering quality software products.</p><p>• Strong knowledge of frontend technologies - HTML, CSS, JavaScript, ReactJS, AngularJS, etc.</p><p>• Knowledge of UI/UX design principles.</p><p>• Familiarity with Agile software development methodologies.</p><p>• Excellent communication and leadership skills.</p><p>• Ability to work effectively in a team-oriented environment.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/ke-toan-tong-hop/1010632.html?ta_source=JobSearchList',
#   'job_title': 'Kế Toán Tổng Hợp',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'BAP SOLUTIONS CO., LTD',
#   'job_salary': '12 - 18 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hồ Chí Minh: 236/29/18 Điện Biên Phủ, phường 17, quận Bình Thạnh, HCM, Bình Thạnh'],
#   'job_desc': '<div class="content-tab"><p>Triển khai thực hiện các nghiệp vụ chuyên môn của Kế toán tổng hợp</p><p>Kiểm tra việc hạch toán chi tiết và kiểm soát các chi phí phát sinh từ các phòng ban.</p><p>Theo dõi, hướng dẫn kế toán viên</p><p>Phối hợp P. HCNS kiểm tra việc trả lương, thưởng, Bảo hiểm cho nhân viên công ty</p><p>Quản lý chứng từ, hoá đơn, sổ sách theo chuyên môn, khai thuế và quyết toán thuếs</p><p>Lập báo cáo tài chính, kê khai, báo cáo thuế, cân đối tài chính theo đúng thời hạn quy định</p><p>Theo dõi, tổng hợp, báo cáo doanh thu, chi phí định kỳ hàng tháng, quý, năm</p><p>Các công việc Tài chính- Kế toán khác theo sự phân công của kế toán trưởng</p></div>',
#   'job_req': '<div class="content-tab"><p>Nam/nữ tuổi từ 25 đến 32</p><p>Trình độ đại học chuyên ngành Kế toán</p><p>Kinh nghiệm kế toán tổng hợp ít nhất 2 năm, trong lĩnh vực IT là điểm cộng</p><p>Nắm vững các chính sách, chế độ Tài chính - Kế toán, Thuế</p><p>Trung thực, nhiệt tình, có trách nhiệm, cẩn thận</p><p>Có kỹ năng làm việc nhóm</p><p>Kỹ năng excel là bắt buộc.</p><p>Ưu tiên cá nhân mong muốn gắn bó lâu dài với công ty.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-graphic-designer/1011068.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Graphic Designer',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'Công ty TNHH Công nghệ và Truyền thông IIT',
#   'job_salary': '8 - 15 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Không yêu cầu kinh nghiệm',
#   'job_addresses': ['- Hà Nội: Tầng 4, 147 Mai Dịch, Cầu Giấy, Hà Nội, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p>- Lập kế hoạch và giám sát tiến độ thực hiện các ấn phẩm online và offline của công ty<br>- Làm việc với các team/dự án để sáng tạo và trình diễn ý tưởng mới phục vụ cho các chiến dịch marketing.<br>- Thiết kế các ấn phẩm marketing như tờ rơi, filer, sales kit, profile, catalogue …<br>- Thiết kế các ấn phẩm online marketing như banner, poster, cover …<br>- Các công việc khác dưới sự điều phối của Ban lãnh đạo</br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Thành thạo các phần mềm edit, design ảnh và video liên quan....<br>- Nhanh nhạy với mạng xã hội, trend thị trường, tư duy tốt<br>- Có mắt thẩm mỹ độc đáo, sáng tạo trong công việc<br/>- Chăm chỉ, siêng năng, chịu khó học hỏi<br/>- Có tinh thần trách nhiệm và làm việc nhóm cao, deadline chuẩn chỉnh</br></br></p></div>',
# ...
#   'job_title': '.Net Developer',
#   'job_deadline': 'Hạn nộp hồ sơ: 03/06/2023',
#   'company_name': 'CÔNG TY TNHH SOFT WORLD VIỆT NAM',
#   'job_salary': 'Thoả thuận',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hồ Chí Minh: 54/31 Phổ Quang, Phường 2, Tân Bình',
#    '- Thừa Thiên Huế: 11 Lý Thường Kiệt, Phú Nhuận, Huế, TP Huế'],
#   'job_desc': '<div class="content-tab"><ul><li>Developing Cloud-based application systems (Azure, AWS, GCP).</li><li>Participate in the development of the core microservice system.</li><li>Participate in Scrum/Agile development.</li><li>Participate in analyzing solutions for each specific problem of the project.</li><li>Ensure the assigned tasks are performed on time and with</li><li>The manager will assign other tasks.</li></ul></div>',
#   'job_req': '<div class="content-tab"><ul><li>Knowledge of OOP</li><li>Experience in developing .NET, C, Web, API</li><li>Strong Database knowledge, capable of performing complex queries, and store procedures.</li><li>Proficient in using Git.</li><li>Unit-Test skill</li><li>Nice to have:<br>- Have worked with Docker, Microservice architecture, N-Layer architecture, and Domain Driven.<br>- Have experience in developing a REST API and understand the difference between Scoped, Transient, and Singleton lifetimes<br>- The ability to approach and develop on other tech stacks (Java, Python, Node.js, etc..) is an advantage<br>- Working with open-source stacks such as Redis, Elasticsearch, and RabbitMQ is an advantage<br>- Experience in Front-end programming: HTML, CSS, Javascript with frameworks such as jQuery, Bootstrap... Especially if you have experience in React/Angular development is an advantage.</br></br></br></br></br></li></ul></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/lap-trinh-vien-net/529183.html?ta_source=JobSearchList',
#   'job_title': 'Lập Trình Viên .Net',
#   'job_deadline': 'Hạn nộp hồ sơ: 08/06/2023',
#   'company_name': 'CÔNG TY TNHH DELTATEK',
#   'job_salary': '10 - 30 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '1 năm',
#   'job_addresses': ['- Hà Nội: Hà Nội'],
#   'job_desc': '<div class="content-tab"><p>Xây dựng các hệ thống nghiệp vụ trong chiến lược chuyển đổi số của các công ty tài chính, bảo hiểm, ngân hàng.<br>Phân tích thiết kế các dịch vụ, cấu trúc cơ sở dữ liệu, thuật toán cần thiết dựa trên yêu cầu nghiệp vụ cho chức năng được giao, đảm bảo tuân thủ quy định của framework phát triển ứng dụng<br>Phát triển các chức năng của phần mềm ứng dụng theo yêu cầu nghiệp vụ được giao, thực hiện kiểm thử unit test trước khi bàn giao cho đội kiểm thử<br>Chuyển giao các chức năng đã phát triển xong cho đội kiểm thử và tiến hành sửa lỗi nếu có</br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>Tốt nghiệp chuyên ngành Công nghệ thông tin, Khoa học máy tính… hoặc có kinh nghiệm thực tiễn tương đương<br>Có từ 1 năm kinh nghiệm làm việc .net, .net core, Web API<br>Có khả năng học hỏi nhanh, tích cực và chủ động trong công việc. Khả năng làm việc độc lập và làm việc nhóm tốt.<br>Có hiểu biết về webservice, RESTful API, biết tương tác với 1 hoặc nhiều CSDL thông dụng như MySQL, Oracle, MS SQL, Postgree, có thể viết SQL để tương tác với CSDL<br/>Có hiểu biết về microservice là một lợi thế.<br/>Ưu tiên có hiểu biết và kinh nghiệm về Kafka, RabbitMQ, Redis, Mongodb<br/>Biết sử dụng các thuật toán cơ bản trong lập trình ứng dụng</br></br></br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/nhan-vien-trien-khai-phan-mem-thu-nhap-den-15-trieu/1010066.html?ta_source=JobSearchList',
#   'job_title': 'Nhân Viên Triển Khai Phần Mềm Thu Nhập Đến 15 Triệu',
#   'job_deadline': 'Hạn nộp hồ sơ: 10/09/2023',
#   'company_name': 'Công ty Cổ phần Phần mềm Trực tuyến và Thương mại Điện tử',
#   'job_salary': '8 - 15 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: Tòa Mỹ Đình Plaza 2 - số 2 Nguyễn Hoàng, Nam Từ Liêm'],
#   'job_desc': '<div class="content-tab"><p>- Triển khai các hệ thống phần mềm phục vụ ngành y tế (Phần mềm Quản lý Bệnh viện, phòng khám, bệnh án điện tử, Telemedicine…).</p><p>- Hướng dẫn sử dụng và đào tạo cho khách hàng sử dụng phần mềm.</p><p>- Ghi nhận, tổng hợp ý kiến người sử dụng.</p><p>- Khảo sát, đánh giá hiện trạng CNTT của khách hàng.</p></div>',
#   'job_req': '<div class="content-tab"><p>- Bắt buộc có kỹ năng giao tiếp tốt, tinh thần trách nhiệm cao và tuân thủ kỷ luật.</p><p>- Không yêu cầu bằng cấp. (Trung cấp/Cao đẳng/Đại học…)</p><p>- Chấp nhận và sẵn sàng đi công tác ngắn/dài ngày.</p><p>- Ưu tiên ứng viên đã có kinh nghiệm triển khai phần mềm.</p><p>- Có khả năng làm việc tập trung để đáp ứng kịp tiến độ và làm việc dưới áp lực cao.</p><p>- Cẩn thận, trung thực, hoà đồng.</p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/chuyen-vien-business-solution-consultant/867531.html?ta_source=JobSearchList',
#   'job_title': 'Chuyên Viên Business Solution Consultant',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'CÔNG TY CỔ PHẦN AGLOBAL',
#   'job_salary': '6 - 9 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: Tầng 3, tòa G2 khu trung tâm thương mại Five Star số 2 Kim Giang, Quận Thanh Xuân, Hà Nội, Thanh Xuân'],
#   'job_desc': '<div class="content-tab"><ul><li>Tìm kiếm khách hàng phù hợp sử dụng các giải pháp doanh nghiệp như: Google Workspace, Google Cloud, Google Business Messages, các giải pháp phần mềm để quản trị doanh nghiệp &amp; amp; hỗ trợ bán hàng.</li><li>Liên hệ với khách hàng qua email/ messenger/ điện thoại để tư vấn, đàm phán và thuyết phục khách hàng sử dụng các dịch vụ giải pháp dành cho doanh nghiệp</li><li>Làm việc với đối tác cũng như nội bộ để đề xuất các giải pháp phù hợp với yêu cầu của Khách hàng</li><li>Đàm phán ký kết hợp đồng và duy trì các mối liên hệ với khách hàng thông qua email/messenger/ điện thoại.</li><li>Theo dõi và hỗ trợ dịch vụ sau bán với Khách hàng cùng các bộ phận liên quan.</li><li>Chăm sóc khách hàng định kỳ hàng tuần/tháng nhằm duy trì quan hệ tốt nhất và sẵn sàng hỗ trợ khách hàng 24/7</li><li>Chi tiết công việc sẽ trao đổi cụ thể trong quá trình phỏng vấn</li></ul></div>',
#   'job_req': '<div class="content-tab"><ul><li>Nam/Nữ, độ tuổi từ 22 – 28. Tốt nghiệp chuyên ngành kinh tế, marketing, quản trị kinh doanh, ngoại thương, CNTT hoặc các ngành có liên quan</li><li>Kinh nghiệm làm kinh doanh nói chung là một lợi thế</li><li>Có khả năng thuyết trình, thương lương tốt</li><li>Chấp nhận sinh viên năm cuối/ mới ra trường.</li></ul></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/chuyen-vien-business-solution-consultant/867540.html?ta_source=JobSearchList',
#   'job_title': 'Chuyên Viên Business Solution Consultant',
#   'job_deadline': 'Hạn nộp hồ sơ: 04/06/2023',
#   'company_name': 'CÔNG TY CỔ PHẦN CMETRIC',
#   'job_salary': '6 - 9 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hà Nội: Tầng 3, tòa G2 khu trung tâm thương mại Five Star số 2 Kim Giang, Quận Thanh Xuân, Hà Nội, Thanh Xuân'],
#   'job_desc': '<div class="content-tab"><ul><li>Tìm kiếm khách hàng phù hợp sử dụng các giải pháp doanh nghiệp như: Google Workspace, Google Cloud, Google Business Messages, các giải pháp phần mềm để quản trị doanh nghiệp &amp; amp; hỗ trợ bán hàng.</li><li>Liên hệ với khách hàng qua email/ messenger/ điện thoại để tư vấn, đàm phán và thuyết phục khách hàng sử dụng các dịch vụ giải pháp dành cho doanh nghiệp</li><li>Làm việc với đối tác cũng như nội bộ để đề xuất các giải pháp phù hợp với yêu cầu của Khách hàng</li><li>Đàm phán ký kết hợp đồng và duy trì các mối liên hệ với khách hàng thông qua email/messenger/ điện thoại.</li><li>Theo dõi và hỗ trợ dịch vụ sau bán với Khách hàng cùng các bộ phận liên quan.</li><li>Chăm sóc khách hàng định kỳ hàng tuần/tháng nhằm duy trì quan hệ tốt nhất và sẵn sàng hỗ trợ khách hàng 24/7</li><li>Chi tiết công việc sẽ trao đổi cụ thể trong quá trình phỏng vấn</li></ul></div>',
#   'job_req': '<div class="content-tab"><ul><li>Nam/Nữ, độ tuổi từ 22 – 28. Tốt nghiệp chuyên ngành kinh tế, marketing, quản trị kinh doanh, ngoại thương, CNTT hoặc các ngành có liên quan</li><li>Kinh nghiệm làm kinh doanh nói chung là một lợi thế</li><li>Có khả năng thuyết trình, thương lương tốt</li><li>Chấp nhận sinh viên năm cuối/ mới ra trường.</li></ul></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/java-developer/978899.html?ta_source=JobSearchList',
#   'job_title': 'Java Developer',
#   'job_deadline': 'Hạn nộp hồ sơ: 03/06/2023',
#   'company_name': 'CÔNG TY TNHH SOFT WORLD VIỆT NAM',
#   'job_salary': 'Thoả thuận',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': 'Dưới 1 năm',
#   'job_addresses': ['- Hồ Chí Minh: 54/31 Phổ Quang, Phường 2, Tân Bình',
#    '- Thừa Thiên Huế: 11 Lý Thường Kiệt, Phú Nhuận, TP Huế'],
#   'job_desc': '<div class="content-tab"><p>- Participating in the development of Cloud-based application systems (AWS, GCP)<br>- Participating in the development of the core micro-service system<br>- Participate in the development of SCRUM/Agile. model<br>- Participate in the analysis of solutions for each specific problem of the project<br>- Ensure assigned tasks are done on time and<br>- Other tasks as assigned by the leader.</br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Graduated in Information Technology, Computer Science<br>- Good logical thinking<br/>- 1 year or more working experience<br/>- Good use of Java Core, experience working with Java Spring Boot<br/>- Knowledge of some popular frameworks such as Spring, jHipster, Hibernate, JPA, Junit, Mockito<br/>- Knowledge of databases such as MySQL, PostgreSQL<br/>- Experience in Front End programming: HTML, CSS, Javascript with frameworks like jQuery, Bootstrap... especially if you have experience in developing Single Page Apps with Angular is an advantage<br/>- Proficient in using Git.</br></p></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/php-developer-middle-senior/1009723.html?ta_source=JobSearchList',
#   'job_title': 'PHP Developer (Middle/ Senior)',
#   'job_deadline': 'Hạn nộp hồ sơ: 11/06/2023',
#   'company_name': 'CÔNG TY TNHH HAPOSOFT',
#   'job_salary': 'Tới 45 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: Mitec Building, phố Dương Đình Nghệ, Yên Hòa,, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><ul><li>Tham gia phát triển các dự án Web của công ty và khách hàng sử dụng ngôn ngữ PHP (Framework Laravel).</li><li>Tham gia phân tích yêu cầu, thiết kế hệ thống, thiết kế Database, phát triển các chức năng.</li><li>Thực hiện công việc theo mô hình Agile/ Scrum, lập kế hoạch, thực hiện, kiểm soát và báo cáo công việc theo từng Sprint.</li><li>Hỗ trợ đào tạo và chia sẻ kiến thức với các thành viên trong team.</li><li>Nghiên cứu và định hướng các công nghệ mới áp dụng vào dự án.</li></ul></div>',
#   'job_req': '<div class="content-tab"><ul><li>Tốt nghiệp chuyên ngành về công nghệ phần mềm, khoa học máy tính, hoặc các chuyên ngành liên quan tới CNTT.</li><li>Có tối thiểu 3 năm kinh nghiệm làm các dự án ngôn ngữ PHP. Thành thạo sử dụng framework Laravel.</li><li>Thành thạo công cụ quản lý mã nguồn GIT, SVN.</li><li>Thao tác tốt với HTML, CSS, jQuery, Ajax, Bootstrap,...</li><li>Thành thạo về hệ quản trị cơ sở dữ liệu MySQL, MongoDB.</li><li>Có kiến thức nền tảng tốt về MVC, OOP, RESTful, Design Pattern.</li><li>Có khả năng tư duy tốt, chủ động trong công việc; khả năng làm việc độc lập và làm việc nhóm tốt.</li><li>Có thể giao tiếp tiếng Anh hoặc tiếng Nhật là một lợi thế.</li><li>Có hiểu biết và kinh nghiệm với Node.js, React.js, Vue.js, Angular là lợi thế.</li></ul></div>',
#   'job_level': 'Nhân viên'},
#  {'url': 'https://www.topcv.vn/viec-lam/chuyen-vien-truong-bo-phan-it/1009679.html?ta_source=JobSearchList',
#   'job_title': 'Chuyên Viên/Trưởng Bộ Phận IT',
#   'job_deadline': 'Hạn nộp hồ sơ: 03/06/2023',
#   'company_name': 'CÔNG TY CỔ PHẦN TẬP ĐOÀN VINATECH VIỆT NAM',
#   'job_salary': '18 - 40 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '3 năm',
#   'job_addresses': ['- Hà Nội: 23D-A10 KĐT Nam Trung Yên, Yên Hòa, Cầu Giấy'],
#   'job_desc': '<div class="content-tab"><p>1. Lập Kế hoạch hoạt động, Vận hành &amp; Quản trị hệ thống ứng dụng</p><p>· Thiết kế, tích hợp và triển khai mô hình hệ thống ứng dụng cho tất cả các phòng ban sử dụng phần mềm trong quản lý và triển khai công việc.</p><p>· Đề xuất các giải pháp để đáp ứng yêu cầu quản lý cho Ban Giám đốc trong quá trình phân tích, triển khai với các phòng ban liên quan.</p><p>· Giám sát, phối hợp với NCC phần mềm để xây dựng và triển khai SAP cho hệ thống toàn Công ty.</p><p>· Kiểm tra, giám sát việc chấp hành các quy định cấp quyền sử dụng, quy trình kỹ thuật các chương trình của hệ thống SAP.</p><p>· Tư vấn/hỗ trợ người sử dụng giải quyết các vấn đề liên quan khi sử dụng hệ thống.</p><p>· Giám sát truy cập vào hệ thống phần mềm ứng dụng.</p><p>· Sao lưu và khôi phục dữ liệu khi phần mềm ứng dụng gặp sự cố.</p><p>· Tham gia huấn luyện, đào tạo cho người dùng.</p><p>· Soạn thảo tài liệu hướng dẫn sử dụng hệ thống.</p><p>2. Vận hành và quản trị phần cứng/mạng/server</p><p>· Quản trị hệ thống mạng/máy chủ/server mail.</p><p>· Tham gia vào việc xem xét thiết kế kiến trúc hạ tầng cơ sở công nghệ.</p><p>3. Các công việc khác theo yêu cầu của cấp trên.</p></div>',
#   'job_req': '<div class="content-tab"><p>- \xa0 \xa0 \xa0 Tốt nghiệp ĐH trở lên các ngành về công nghệ thông tin, công nghệ phần mềm, tin học hoặc các lĩnh vực có liên quan.</p><p>- \xa0 \xa0 \xa0 Có kinh nghiệm 2 năm trong việc quản lý SAP và quản trị hệ thống tại các công ty quy mô vừa trở lên.</p><p>- \xa0 \xa0 \xa0 Am hiểu về phần cứng/ phần mềm, công nghệ tin học và nắm bắt được xu hướng tin học mới nhất.</p><p>- \xa0 \xa0 \xa0 Có kiến thức tốt về ứng dụng công nghệ &amp; quản trị dữ liệu.</p><p>- \xa0 \xa0 \xa0 Trách nhiệm cao, trung thực, linh hoạt và có tâm thế “sẵn sàng phục vụ”.</p><p>- \xa0 \xa0 \xa0 Thành thạo trong việc sử dụng các chương trình/phần mềm hỗ trợ.</p><p>- \xa0 \xa0 \xa0 Thành thạo Tiếng Anh là một lợi thế.</p></div>',
#   'job_level': 'Quản lý / Giám sát'},
#  {'url': 'https://www.topcv.vn/viec-lam/senior-business-analyst-level-chuyen-gia/1009401.html?ta_source=JobSearchList',
#   'job_title': 'Senior Business Analyst (Level Chuyên Gia)',
#   'job_deadline': 'Hạn nộp hồ sơ: 10/06/2023',
#   'company_name': 'Công ty CP Vinhomes',
#   'job_salary': 'Trên 40 triệu',
#   'job_type': 'Toàn thời gian',
#   'job_yoe': '4 năm',
#   'job_addresses': ['- Hà Nội: VP Techno Park, KĐT Vinhomes Ocean Park, Đa Tốn, Gia Lâm, Hà Nội (có xe bus đưa đón CBNV miễn phí), Gia Lâm'],
#   'job_desc': '<div class="content-tab"><p>- Phân tích và làm rõ các yêu cầu của khách hàng/PO.<br>- Phân tích và đưa ra mô hình, giải pháp dựa trên yêu cầu đã thu thập được.<br>- Viết các tài liệu đặc tả yêu cầu nghiệp vụ phần mềm, tài liệu đặc tả trường hợp sử dụng (usecase); thiết kế giao diện mẫu (prototype)<br>- Tư vấn trên góc độ nghiệp vụ dựa vào các phân tích và nghiên cứu của mình.<br>- Truyền đạt nội dung, hỗ trợ các thành viên dự án, quản lý dự án để làm rõ yêu cầu của khách hàng cần đáp ứng.<br>- Tài liệu hóa hướng dẫn hệ thống.<br>- Tổ chức hướng dẫn, hỗ trợ cho người dùng sử dụng sản phẩm và xử lý sự cố khi vấn đề xảy ra.<br/>- Thực hiện một số công việc khác khi có yêu cầu của cấp trên.</br></br></br></br></br></br></p></div>',
#   'job_req': '<div class="content-tab"><p>- Tốt nghiệp Đại học các ngành liên quan<br/>- Có kinh nghiệm tối thiểu 04 năm ở vị trí Chuyên viên Phân tích nghiệp vụ, ưu tiên có kinh nghiệm làm trong các công ty sản phẩm.<br/>- Sử dụng thành thạo các phần mềm tin học văn phòng<br/>- Trung thực, cẩn thận, có trách nghiệm và chủ động trong công việc</p></div>',
#   'job_level': 'Nhân viên'}]

# %%
for index,industry in enumerate(industries):
    print(industry)
# Out:
# {'id': 10001, 'name': 'Kinh doanh / Bán hàng', 'alias': 'kinh-doanh-ban-hang', 'access_url': '/tim-viec-lam-kinh-doanh-ban-hang-c10001', 'job_category_count': '11.119'}
# {'id': 10026, 'name': 'IT phần mềm', 'alias': 'it-phan-mem', 'access_url': '/tim-viec-lam-it-phan-mem-c10026', 'job_category_count': '3.248'}
# {'id': 10023, 'name': 'Hành chính / Văn phòng', 'alias': 'hanh-chinh-van-phong', 'access_url': '/tim-viec-lam-hanh-chinh-van-phong-c10023', 'job_category_count': '3.996'}
# {'id': 10017, 'name': 'Giáo dục / Đào tạo', 'alias': 'giao-duc-dao-tao', 'access_url': '/tim-viec-lam-giao-duc-dao-tao-c10017', 'job_category_count': '2.856'}
# {'id': 10045, 'name': 'Tư vấn', 'alias': 'tu-van', 'access_url': '/tim-viec-lam-tu-van-c10045', 'job_category_count': '4.092'}
# {'id': 10029, 'name': 'Marketing / Truyền thông / Quảng cáo', 'alias': 'marketing-truyen-thong-quang-cao', 'access_url': '/tim-viec-lam-marketing-truyen-thong-quang-cao-c10029', 'job_category_count': '5.453'}
# {'id': 10047, 'name': 'Vận tải / Kho vận', 'alias': 'van-tai-kho-van', 'access_url': '/tim-viec-lam-van-tai-kho-van-c10047', 'job_category_count': '902'}
# {'id': 10028, 'name': 'Kế toán / Kiểm toán', 'alias': 'ke-toan-kiem-toan', 'access_url': '/tim-viec-lam-ke-toan-kiem-toan-c10028', 'job_category_count': '2.879'}
# {'id': 10037, 'name': 'Quản lý chất lượng (QA/QC)', 'alias': 'quan-ly-chat-luong-qa-qc', 'access_url': '/tim-viec-lam-quan-ly-chat-luong-qa-qc-c10037', 'job_category_count': '577'}
# {'id': 10131, 'name': 'Công nghệ thông tin', 'alias': 'cong-nghe-thong-tin', 'access_url': '/tim-viec-lam-cong-nghe-thong-tin-c10131', 'job_category_count': '2.893'}
# {'id': 10129, 'name': 'Thư ký / Trợ lý', 'alias': 'thu-ky-tro-ly', 'access_url': '/tim-viec-lam-thu-ky-tro-ly-c10129', 'job_category_count': '669'}
# {'id': 10042, 'name': 'Thời trang', 'alias': 'thoi-trang', 'access_url': '/tim-viec-lam-thoi-trang-c10042', 'job_category_count': '856'}
# {'id': 10039, 'name': 'Thiết kế đồ họa', 'alias': 'thiet-ke-do-hoa', 'access_url': '/tim-viec-lam-thiet-ke-do-hoa-c10039', 'job_category_count': '1.157'}
# {'id': 10034, 'name': 'Nhân sự', 'alias': 'nhan-su', 'access_url': '/tim-viec-lam-nhan-su-c10034', 'job_category_count': '1.672'}
# {'id': 10046, 'name': 'Tổ chức sự kiện / Quà tặng', 'alias': 'to-chuc-su-kien-qua-tang', 'access_url': '/tim-viec-lam-to-chuc-su-kien-qua-tang-c10046', 'job_category_count': '351'}
# {'id': 10050, 'name': 'Xây dựng', 'alias': 'xay-dung', 'access_url': '/tim-viec-lam-xay-dung-c10050', 'job_category_count': '1.186'}
# {'id': 10051, 'name': 'Y tế / Dược', 'alias': 'y-te-duoc', 'access_url': '/tim-viec-lam-y-te-duoc-c10051', 'job_category_count': '1.436'}
# {'id': 10016, 'name': 'Điện / Điện tử / Điện lạnh', 'alias': 'dien-dien-tu-dien-lanh', 'access_url': '/tim-viec-lam-dien-dien-tu-dien-lanh-c10016', 'job_category_count': '1.233'}
# {'id': 10003, 'name': 'Biên / Phiên dịch', 'alias': 'bien-phien-dich', 'access_url': '/tim-viec-lam-bien-phien-dich-c10003', 'job_category_count': '1.068'}
# {'id': 10010, 'name': 'Cơ khí / Chế tạo / Tự động hóa', 'alias': 'co-khi-che-tao-tu-dong-hoa', 'access_url': '/tim-viec-lam-co-khi-che-tao-tu-dong-hoa-c10010', 'job_category_count': '1.109'}
# {'id': 10033, 'name': 'Ngân hàng / Tài chính', 'alias': 'ngan-hang-tai-chinh', 'access_url': '/tim-viec-lam-ngan-hang-tai-chinh-c10033', 'job_category_count': '2.624'}
# {'id': 10043, 'name': 'Thực phẩm / Đồ uống', 'alias': 'thuc-pham-do-uong', 'access_url': '/tim-viec-lam-thuc-pham-do-uong-c10043', 'job_category_count': '953'}
# {'id': 10036, 'name': 'Luật/Pháp lý', 'alias': 'luat-phap-ly', 'access_url': '/tim-viec-lam-luat-phap-ly-c10036', 'job_category_count': '471'}
# {'id': 10004, 'name': 'Báo chí / Truyền hình', 'alias': 'bao-chi-truyen-hinh', 'access_url': '/tim-viec-lam-bao-chi-truyen-hinh-c10004', 'job_category_count': '1.498'}
# {'id': 10038, 'name': 'Quản lý điều hành', 'alias': 'quan-ly-dieu-hanh', 'access_url': '/tim-viec-lam-quan-ly-dieu-hanh-c10038', 'job_category_count': '1.073'}
# {'id': 11000, 'name': 'Ngành nghề khác', 'alias': 'nganh-nghe-khac', 'access_url': '/tim-viec-lam-nganh-nghe-khac-c11000', 'job_category_count': '1.344'}
# {'id': 10015, 'name': 'Điện tử viễn thông', 'alias': 'dien-tu-vien-thong', 'access_url': '/tim-viec-lam-dien-tu-vien-thong-c10015', 'job_category_count': '553'}
# {'id': 10048, 'name': 'Logistics', 'alias': 'logistics', 'access_url': '/tim-viec-lam-logistics-c10048', 'job_category_count': '1.008'}
# {'id': 10027, 'name': 'Khách sạn / Nhà hàng', 'alias': 'khach-san-nha-hang', 'access_url': '/tim-viec-lam-khach-san-nha-hang-c10027', 'job_category_count': '1.009'}
# {'id': 10049, 'name': 'Xuất nhập khẩu', 'alias': 'xuat-nhap-khau', 'access_url': '/tim-viec-lam-xuat-nhap-khau-c10049', 'job_category_count': '923'}
# {'id': 10025, 'name': 'IT Phần cứng / Mạng', 'alias': 'it-phan-cung-mang', 'access_url': '/tim-viec-lam-it-phan-cung-mang-c10025', 'job_category_count': '1.045'}
# {'id': 10011, 'name': 'Du lịch', 'alias': 'du-lich', 'access_url': '/tim-viec-lam-du-lich-c10011', 'job_category_count': '695'}
# {'id': 10008, 'name': 'Chứng khoán / Vàng / Ngoại tệ', 'alias': 'chung-khoan-vang-ngoai-te', 'access_url': '/tim-viec-lam-chung-khoan-vang-ngoai-te-c10008', 'job_category_count': '362'}
# {'id': 10014, 'name': 'Dịch vụ khách hàng', 'alias': 'dich-vu-khach-hang', 'access_url': '/tim-viec-lam-dich-vu-khach-hang-c10014', 'job_category_count': '4.184'}
# {'id': 10019, 'name': 'Hoạch định/Dự án', 'alias': 'hoach-dinh-du-an', 'access_url': '/tim-viec-lam-hoach-dinh-du-an-c10019', 'job_category_count': '294'}
# {'id': 10127, 'name': 'Tài chính / Đầu tư', 'alias': 'tai-chinh-dau-tu', 'access_url': '/tim-viec-lam-tai-chinh-dau-tu-c10127', 'job_category_count': '1.364'}
# {'id': 10052, 'name': 'Công nghệ Ô tô', 'alias': 'cong-nghe-o-to', 'access_url': '/tim-viec-lam-cong-nghe-o-to-c10052', 'job_category_count': '306'}
# {'id': 10031, 'name': 'Mỹ phẩm / Trang sức', 'alias': 'my-pham-trang-suc', 'access_url': '/tim-viec-lam-my-pham-trang-suc-c10031', 'job_category_count': '532'}
# {'id': 10120, 'name': 'Kiến trúc', 'alias': 'kien-truc', 'access_url': '/tim-viec-lam-kien-truc-c10120', 'job_category_count': '449'}
# {'id': 10007, 'name': 'Bất động sản', 'alias': 'bat-dong-san', 'access_url': '/tim-viec-lam-bat-dong-san-c10007', 'job_category_count': '1.071'}
# {'id': 10128, 'name': 'Thiết kế nội thất', 'alias': 'thiet-ke-noi-that', 'access_url': '/tim-viec-lam-thiet-ke-noi-that-c10128', 'job_category_count': '576'}
# {'id': 10126, 'name': 'Sản xuất', 'alias': 'san-xuat', 'access_url': '/tim-viec-lam-san-xuat-c10126', 'job_category_count': '797'}
# {'id': 10032, 'name': 'Mỹ thuật / Nghệ thuật / Điện ảnh', 'alias': 'my-thuat-nghe-thuat-dien-anh', 'access_url': '/tim-viec-lam-my-thuat-nghe-thuat-dien-anh-c10032', 'job_category_count': '515'}
# {'id': 10009, 'name': 'Công nghệ cao', 'alias': 'cong-nghe-cao', 'access_url': '/tim-viec-lam-cong-nghe-cao-c10009', 'job_category_count': '442'}
# {'id': 10035, 'name': 'Nông / Lâm / Ngư nghiệp', 'alias': 'nong-lam-ngu-nghiep', 'access_url': '/tim-viec-lam-nong-lam-ngu-nghiep-c10035', 'job_category_count': '219'}
# {'id': 10110, 'name': 'Dược phẩm / Công nghệ sinh học', 'alias': 'duoc-pham-cong-nghe-sinh-hoc', 'access_url': '/tim-viec-lam-duoc-pham-cong-nghe-sinh-hoc-c10110', 'job_category_count': '571'}
# {'id': 10130, 'name': 'Spa / Làm đẹp', 'alias': 'spa-lam-dep', 'access_url': '/tim-viec-lam-spa-lam-dep-c10130', 'job_category_count': '665'}
# {'id': 10117, 'name': 'Hàng tiêu dùng', 'alias': 'hang-tieu-dung', 'access_url': '/tim-viec-lam-hang-tieu-dung-c10117', 'job_category_count': '287'}
# {'id': 10013, 'name': 'Dệt may / Da giày', 'alias': 'det-may-da-giay', 'access_url': '/tim-viec-lam-det-may-da-giay-c10013', 'job_category_count': '267'}
# {'id': 10021, 'name': 'Hàng hải', 'alias': 'hang-hai', 'access_url': '/tim-viec-lam-hang-hai-c10021', 'job_category_count': '32'}
# {'id': 10101, 'name': 'An toàn lao động', 'alias': 'an-toan-lao-dong', 'access_url': '/tim-viec-lam-an-toan-lao-dong-c10101', 'job_category_count': '66'}
# {'id': 10018, 'name': 'Hoá học / Sinh học', 'alias': 'hoa-hoc-sinh-hoc', 'access_url': '/tim-viec-lam-hoa-hoc-sinh-hoc-c10018', 'job_category_count': '211'}
# {'id': 10104, 'name': 'Bảo trì / Sửa chữa', 'alias': 'bao-tri-sua-chua', 'access_url': '/tim-viec-lam-bao-tri-sua-chua-c10104', 'job_category_count': '488'}
# {'id': 10030, 'name': 'Môi trường / Xử lý chất thải', 'alias': 'moi-truong-xu-ly-chat-thai', 'access_url': '/tim-viec-lam-moi-truong-xu-ly-chat-thai-c10030', 'job_category_count': '175'}
# {'id': 10005, 'name': 'Bưu chính - Viễn thông', 'alias': 'buu-chinh-vien-thong', 'access_url': '/tim-viec-lam-buu-chinh-vien-thong-c10005', 'job_category_count': '381'}
# {'id': 10020, 'name': 'Hàng gia dụng', 'alias': 'hang-gia-dung', 'access_url': '/tim-viec-lam-hang-gia-dung-c10020', 'job_category_count': '233'}
# {'id': 10102, 'name': 'Bán hàng kỹ thuật', 'alias': 'ban-hang-ky-thuat', 'access_url': '/tim-viec-lam-ban-hang-ky-thuat-c10102', 'job_category_count': '623'}
# {'id': 10103, 'name': 'Bán lẻ / bán sỉ', 'alias': 'ban-le-ban-si', 'access_url': '/tim-viec-lam-ban-le-ban-si-c10103', 'job_category_count': '1.656'}
# {'id': 10006, 'name': 'Bảo hiểm', 'alias': 'bao-hiem', 'access_url': '/tim-viec-lam-bao-hiem-c10006', 'job_category_count': '896'}
# {'id': 10012, 'name': 'Dầu khí/Hóa chất', 'alias': 'dau-khi-hoa-chat', 'access_url': '/tim-viec-lam-dau-khi-hoa-chat-c10012', 'job_category_count': '85'}
# {'id': 10024, 'name': 'In ấn / Xuất bản', 'alias': 'in-an-xuat-ban', 'access_url': '/tim-viec-lam-in-an-xuat-ban-c10024', 'job_category_count': '143'}
# {'id': 10022, 'name': 'Hàng không', 'alias': 'hang-khong', 'access_url': '/tim-viec-lam-hang-khong-c10022', 'job_category_count': '68'}
# {'id': 10132, 'name': 'NGO / Phi chính phủ / Phi lợi nhuận', 'alias': 'ngo-phi-chinh-phu-phi-loi-nhuan', 'access_url': '/tim-viec-lam-ngo-phi-chinh-phu-phi-loi-nhuan-c10132', 'job_category_count': '15'}
# {'id': 10111, 'name': 'Địa chất / Khoáng sản', 'alias': 'dia-chat-khoang-san', 'access_url': '/tim-viec-lam-dia-chat-khoang-san-c10111', 'job_category_count': '42'}
# {'id': 10124, 'name': 'Phi chính phủ / Phi lợi nhuận', 'alias': 'phi-chinh-phu-phi-loi-nhuan', 'access_url': '/tim-viec-lam-phi-chinh-phu-phi-loi-nhuan-c10124', 'job_category_count': '7'}
# {'id': 10125, 'name': 'Sản phẩm công nghiệp', 'alias': 'san-pham-cong-nghiep', 'access_url': '/tim-viec-lam-san-pham-cong-nghiep-c10125', 'job_category_count': '187'}
# {'id': 10113, 'name': 'Hàng cao cấp', 'alias': 'hang-cao-cap', 'access_url': '/tim-viec-lam-hang-cao-cap-c10113', 'job_category_count': '53'}
